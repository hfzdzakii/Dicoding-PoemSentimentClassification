# %%
import pandas as pd
import re
import unicodedata
import contractions
import requests
from transformers import pipeline, AutoTokenizer
from nltk.corpus import words
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# 2025-03-19 20:30:49.368148: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-19 20:30:49.863424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742391050.025752   13591 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742391050.075572   13591 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-19 20:30:50.405977: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Cleaning dulu sebelum dikasih ke model HuggingFace
# Please, CLEANING INI KEWAJIBAN karena main ke model HuggingFace orang lain

english_words = set(words.words())
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def loadCustomDict(path):
    with open(path, 'r') as file:
        return set(line.strip().lower() for line in file if line.strip())

def normalizeWhitespace(text):
    text = unicodedata.normalize('NFKC', text)
    text = contractions.fix(text)
    text = re.sub(r'[\t\r]+', ' ', text) # Menghapus tab
    text = re.sub(r'\b\d+\b', '', text) # Menghilangkan angka
    text = re.sub(r'[-‐‑‒–—―]+', '', text)
    text = re.sub(r'[_﹍﹎＿]', '', text)
    text = re.sub(r'[^\w\s]', '', text) # Hilangkan symbol punctuation
    text = re.sub(r'\b(\w+)(?:\s+\1\b)+', r'\1', text)
    text = re.sub(r'\s+', ' ', text).strip().lower()
    return text

def removeNonEnglish(text_series, custom_dict):
    pattern = r'\b(?:' + '|'.join(re.escape(word) for word in custom_dict) + r')\b'
    temp_series = text_series.str.replace(pattern, '', case=False, regex=True)
    split_words = temp_series.str.split()
    exploded = split_words.explode()
    exploded = exploded[exploded.str.lower().isin(english_words)]
    filtered = exploded[~exploded.str.lower().isin(stop_words)]
    lemmatized = filtered.apply(lambda word: lemmatizer.lemmatize(word.lower()))
    cleaned_text_series = lemmatized.groupby(level=0).agg(' '.join)
    pattern2 = r'\b(\w+)(?:\s+\1\b)+' #, r'\1', text)
    ser = cleaned_text_series.reindex(text_series.index, fill_value='')
    text = ser.str.replace(pattern2, r'\1', case=False, regex=True)
    return text

def removeOtherLanguage(text):
    phrase = ' translated'
    pos = text.find(phrase)
    if pos != -1:
        text = text[:pos].rstrip()
    text = re.sub(r'\b\w*[^\x00-\x7F]\w*\b', '', text)
    text = re.sub(r'\s+', ' ', text).strip().lower()
    return text

def simpleCleaning():
    custom_dict = loadCustomDict('custom_vocab.txt')
    df = pd.read_csv('./dataset/poem_dataset.csv')
    copyDf = df.copy()
    copyDf['poem'] = copyDf['poem'].apply(normalizeWhitespace)
    copyDf['poem'] = copyDf['poem'].apply(removeOtherLanguage)
    copyDf['poem'] = removeNonEnglish(copyDf['poem'], custom_dict)
    return df, copyDf

# %%
# Cleaning dataset
df, cleanDf = simpleCleaning()

# %% [markdown]
# # Labelling Using HuggingFace Model J-Hartmann Distilroberta-base

# %%
emotion_classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
tokenizer = AutoTokenizer.from_pretrained("j-hartmann/emotion-english-distilroberta-base")
# Out:
# I0000 00:00:1739943398.443653   38238 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at j-hartmann/emotion-english-distilroberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# Device set to use 0

# %%
def predictSentimentMergeHartmann(df, cleanDf):
    labels = []
    scores = []
    for idx, poem in enumerate(cleanDf.values):
        tokens = tokenizer(poem[0], max_length=512, truncation=True, return_tensors="tf")
        result = emotion_classifier(tokenizer.decode(tokens['input_ids'][0], truncation=True))[0]
        print(f"Predict ke-{idx}. Label : {result['label']}. Score : {round(result['score'], 5)}")
        scores.append(round(result['score'], 5))
        labels.append(result['label'])

    print("Merging")
    pd.concat([df, pd.DataFrame({'label':labels, 'score':scores})], axis=1).to_csv("./dataset/labelled_poem_hartmann.csv", index=False)

# %%
final = predictSentimentMergeHartmann(df, cleanDf)
# Out:
# Predict ke-0. Label : surprise. Score : 0.83405
# Predict ke-1. Label : fear. Score : 0.57097
# Predict ke-2. Label : sadness. Score : 0.9278
# Predict ke-3. Label : sadness. Score : 0.77741
# Predict ke-4. Label : anger. Score : 0.58882
# Predict ke-5. Label : sadness. Score : 0.98263
# Predict ke-6. Label : joy. Score : 0.79546
# Predict ke-7. Label : fear. Score : 0.96828
# Predict ke-8. Label : fear. Score : 0.86059
# Predict ke-9. Label : anger. Score : 0.96589
# Predict ke-10. Label : fear. Score : 0.64629
# Predict ke-11. Label : anger. Score : 0.92384
# Predict ke-12. Label : sadness. Score : 0.92641
# Predict ke-13. Label : anger. Score : 0.93367
# Predict ke-14. Label : sadness. Score : 0.98694
# Predict ke-15. Label : fear. Score : 0.36186
# Predict ke-16. Label : sadness. Score : 0.62557
# Predict ke-17. Label : fear. Score : 0.93475
# Predict ke-18. Label : sadness. Score : 0.81315
# Predict ke-19. Label : sadness. Score : 0.92017
# Predict ke-20. Label : anger. Score : 0.66822
# Predict ke-21. Label : joy. Score : 0.80539
# Predict ke-22. Label : surprise. Score : 0.44918
# Predict ke-23. Label : sadness. Score : 0.56279
# Predict ke-24. Label : joy. Score : 0.97987
# Predict ke-25. Label : anger. Score : 0.99329
# Token indices sequence length is longer than the specified maximum sequence length for this model (514 > 512). Running this sequence through the model will result in indexing errors
# Predict ke-26. Label : neutral. Score : 0.54312
# Predict ke-27. Label : joy. Score : 0.9262
# Predict ke-28. Label : sadness. Score : 0.88566
# Predict ke-29. Label : sadness. Score : 0.64181
# Predict ke-30. Label : sadness. Score : 0.41925
# Predict ke-31. Label : fear. Score : 0.6899
# Predict ke-32. Label : sadness. Score : 0.80871
# Predict ke-33. Label : fear. Score : 0.87352
# Predict ke-34. Label : joy. Score : 0.58043
# Predict ke-35. Label : sadness. Score : 0.97432
# Predict ke-36. Label : neutral. Score : 0.32475
# Predict ke-37. Label : joy. Score : 0.49126
# Predict ke-38. Label : joy. Score : 0.95761
# Predict ke-39. Label : fear. Score : 0.99117
# Predict ke-40. Label : sadness. Score : 0.98941
# Predict ke-41. Label : anger. Score : 0.30843
# Predict ke-42. Label : joy. Score : 0.489
# Predict ke-43. Label : fear. Score : 0.48945
# Predict ke-44. Label : sadness. Score : 0.97948
# Predict ke-45. Label : sadness. Score : 0.96537
# Predict ke-46. Label : disgust. Score : 0.52583
# Predict ke-47. Label : sadness. Score : 0.51456
# Predict ke-48. Label : sadness. Score : 0.91583
# Predict ke-49. Label : fear. Score : 0.74779
# Predict ke-50. Label : sadness. Score : 0.96723
# Predict ke-51. Label : neutral. Score : 0.45633
# Predict ke-52. Label : sadness. Score : 0.98507
# Predict ke-53. Label : anger. Score : 0.98021
# Predict ke-54. Label : sadness. Score : 0.92978
# Predict ke-55. Label : joy. Score : 0.51005
# Predict ke-56. Label : sadness. Score : 0.98654
# Predict ke-57. Label : joy. Score : 0.89029
# Predict ke-58. Label : sadness. Score : 0.40904
# Predict ke-59. Label : sadness. Score : 0.96693
# Predict ke-60. Label : fear. Score : 0.44356
# Predict ke-61. Label : anger. Score : 0.83755
# Predict ke-62. Label : joy. Score : 0.32366
# Predict ke-63. Label : neutral. Score : 0.70257
# Predict ke-64. Label : fear. Score : 0.97586
# Predict ke-65. Label : fear. Score : 0.99228
# Predict ke-66. Label : anger. Score : 0.48584
# Predict ke-67. Label : joy. Score : 0.50886
# Predict ke-68. Label : sadness. Score : 0.98746
# Predict ke-69. Label : sadness. Score : 0.3548
# Predict ke-70. Label : neutral. Score : 0.37694
# Predict ke-71. Label : sadness. Score : 0.79817
# Predict ke-72. Label : joy. Score : 0.55038
# Predict ke-73. Label : sadness. Score : 0.68263
# Predict ke-74. Label : anger. Score : 0.89291
# Predict ke-75. Label : fear. Score : 0.67126
# Predict ke-76. Label : sadness. Score : 0.92113
# Predict ke-77. Label : fear. Score : 0.85352
# Predict ke-78. Label : sadness. Score : 0.95975
# Predict ke-79. Label : fear. Score : 0.38548
# Predict ke-80. Label : fear. Score : 0.65444
# Predict ke-81. Label : sadness. Score : 0.67254
# Predict ke-82. Label : anger. Score : 0.89835
# Predict ke-83. Label : sadness. Score : 0.96314
# Predict ke-84. Label : neutral. Score : 0.83228
# Predict ke-85. Label : sadness. Score : 0.98364
# Predict ke-86. Label : sadness. Score : 0.61431
# Predict ke-87. Label : fear. Score : 0.9812
# Predict ke-88. Label : joy. Score : 0.45812
# Predict ke-89. Label : sadness. Score : 0.97008
# Predict ke-90. Label : sadness. Score : 0.9359
# Predict ke-91. Label : joy. Score : 0.97471
# Predict ke-92. Label : fear. Score : 0.96686
# Predict ke-93. Label : sadness. Score : 0.98484
# Predict ke-94. Label : neutral. Score : 0.89171
# Predict ke-95. Label : sadness. Score : 0.49192
# Predict ke-96. Label : neutral. Score : 0.47984
# Predict ke-97. Label : anger. Score : 0.86798
# Predict ke-98. Label : sadness. Score : 0.98301
# Predict ke-99. Label : anger. Score : 0.5305
# Predict ke-100. Label : sadness. Score : 0.43603
# Predict ke-101. Label : sadness. Score : 0.79597
# Predict ke-102. Label : fear. Score : 0.87059
# Predict ke-103. Label : joy. Score : 0.93923
# Predict ke-104. Label : sadness. Score : 0.96997
# Predict ke-105. Label : sadness. Score : 0.51205
# Predict ke-106. Label : sadness. Score : 0.33802
# Predict ke-107. Label : fear. Score : 0.93653
# Predict ke-108. Label : sadness. Score : 0.98292
# Predict ke-109. Label : joy. Score : 0.86148
# Predict ke-110. Label : neutral. Score : 0.49156
# Predict ke-111. Label : anger. Score : 0.94858
# Predict ke-112. Label : sadness. Score : 0.5838
# Predict ke-113. Label : fear. Score : 0.24541
# Predict ke-114. Label : sadness. Score : 0.41524
# Predict ke-115. Label : sadness. Score : 0.97008
# Predict ke-116. Label : sadness. Score : 0.86176
# Predict ke-117. Label : sadness. Score : 0.96703
# Predict ke-118. Label : fear. Score : 0.98904
# Predict ke-119. Label : fear. Score : 0.87394
# Predict ke-120. Label : neutral. Score : 0.52527
# Predict ke-121. Label : fear. Score : 0.98771
# Predict ke-122. Label : fear. Score : 0.62584
# Predict ke-123. Label : sadness. Score : 0.64676
# Predict ke-124. Label : sadness. Score : 0.93843
# Predict ke-125. Label : surprise. Score : 0.53216
# Predict ke-126. Label : fear. Score : 0.7892
# Predict ke-127. Label : joy. Score : 0.40275
# Predict ke-128. Label : fear. Score : 0.72244
# Predict ke-129. Label : sadness. Score : 0.31419
# Predict ke-130. Label : joy. Score : 0.91179
# Predict ke-131. Label : anger. Score : 0.98198
# Predict ke-132. Label : fear. Score : 0.52794
# Predict ke-133. Label : sadness. Score : 0.80552
# Predict ke-134. Label : sadness. Score : 0.68002
# Predict ke-135. Label : fear. Score : 0.69236
# Predict ke-136. Label : sadness. Score : 0.89873
# Predict ke-137. Label : fear. Score : 0.78894
# Predict ke-138. Label : joy. Score : 0.63391
# Predict ke-139. Label : sadness. Score : 0.89816
# Predict ke-140. Label : fear. Score : 0.94675
# Predict ke-141. Label : fear. Score : 0.99288
# Predict ke-142. Label : anger. Score : 0.84171
# Predict ke-143. Label : fear. Score : 0.98335
# Predict ke-144. Label : joy. Score : 0.58988
# Predict ke-145. Label : anger. Score : 0.64222
# Predict ke-146. Label : sadness. Score : 0.90869
# Predict ke-147. Label : sadness. Score : 0.98819
# Predict ke-148. Label : fear. Score : 0.98804
# Predict ke-149. Label : sadness. Score : 0.49069
# Predict ke-150. Label : neutral. Score : 0.81257
# Predict ke-151. Label : sadness. Score : 0.58387
# Predict ke-152. Label : anger. Score : 0.838
# Predict ke-153. Label : joy. Score : 0.92476
# Predict ke-154. Label : fear. Score : 0.9804
# Predict ke-155. Label : fear. Score : 0.68453
# Predict ke-156. Label : fear. Score : 0.5091
# Predict ke-157. Label : joy. Score : 0.97082
# Predict ke-158. Label : sadness. Score : 0.86774
# Predict ke-159. Label : sadness. Score : 0.87198
# Predict ke-160. Label : sadness. Score : 0.43642
# Predict ke-161. Label : neutral. Score : 0.90257
# Predict ke-162. Label : sadness. Score : 0.40258
# Predict ke-163. Label : joy. Score : 0.74435
# Predict ke-164. Label : sadness. Score : 0.97907
# Predict ke-165. Label : fear. Score : 0.92603
# Predict ke-166. Label : anger. Score : 0.82741
# Predict ke-167. Label : joy. Score : 0.90856
# Predict ke-168. Label : neutral. Score : 0.57085
# Predict ke-169. Label : sadness. Score : 0.88446
# Predict ke-170. Label : joy. Score : 0.95708
# Predict ke-171. Label : neutral. Score : 0.52238
# Predict ke-172. Label : sadness. Score : 0.93457
# Predict ke-173. Label : joy. Score : 0.94838
# Predict ke-174. Label : surprise. Score : 0.84068
# Predict ke-175. Label : fear. Score : 0.8051
# Predict ke-176. Label : joy. Score : 0.87975
# Predict ke-177. Label : sadness. Score : 0.91074
# Predict ke-178. Label : sadness. Score : 0.92801
# Predict ke-179. Label : anger. Score : 0.45895
# Predict ke-180. Label : anger. Score : 0.98119
# Predict ke-181. Label : fear. Score : 0.70141
# Predict ke-182. Label : sadness. Score : 0.95683
# Predict ke-183. Label : sadness. Score : 0.89993
# Predict ke-184. Label : neutral. Score : 0.53447
# Predict ke-185. Label : anger. Score : 0.97401
# Predict ke-186. Label : sadness. Score : 0.98348
# Predict ke-187. Label : sadness. Score : 0.97201
# Predict ke-188. Label : joy. Score : 0.44205
# Predict ke-189. Label : surprise. Score : 0.46443
# Predict ke-190. Label : sadness. Score : 0.98838
# Predict ke-191. Label : sadness. Score : 0.88982
# Predict ke-192. Label : fear. Score : 0.9591
# Predict ke-193. Label : sadness. Score : 0.47394
# Predict ke-194. Label : sadness. Score : 0.76535
# Predict ke-195. Label : fear. Score : 0.97663
# Predict ke-196. Label : fear. Score : 0.75512
# Predict ke-197. Label : fear. Score : 0.59958
# Predict ke-198. Label : sadness. Score : 0.98798
# Predict ke-199. Label : neutral. Score : 0.9124
# Predict ke-200. Label : neutral. Score : 0.6592
# Predict ke-201. Label : anger. Score : 0.9459
# Predict ke-202. Label : sadness. Score : 0.44579
# Predict ke-203. Label : sadness. Score : 0.52513
# Predict ke-204. Label : neutral. Score : 0.44592
# Predict ke-205. Label : sadness. Score : 0.97021
# Predict ke-206. Label : sadness. Score : 0.4654
# Predict ke-207. Label : neutral. Score : 0.2519
# Predict ke-208. Label : sadness. Score : 0.51232
# Predict ke-209. Label : neutral. Score : 0.83732
# Predict ke-210. Label : joy. Score : 0.80538
# Predict ke-211. Label : neutral. Score : 0.50151
# Predict ke-212. Label : sadness. Score : 0.70979
# Predict ke-213. Label : fear. Score : 0.82371
# Predict ke-214. Label : sadness. Score : 0.52312
# Predict ke-215. Label : fear. Score : 0.90722
# Predict ke-216. Label : sadness. Score : 0.81511
# Predict ke-217. Label : sadness. Score : 0.98852
# Predict ke-218. Label : sadness. Score : 0.60917
# Predict ke-219. Label : anger. Score : 0.23475
# Predict ke-220. Label : surprise. Score : 0.62253
# Predict ke-221. Label : fear. Score : 0.98279
# Predict ke-222. Label : sadness. Score : 0.87472
# Predict ke-223. Label : sadness. Score : 0.73142
# Predict ke-224. Label : joy. Score : 0.87165
# Predict ke-225. Label : disgust. Score : 0.29849
# Predict ke-226. Label : fear. Score : 0.97588
# Predict ke-227. Label : anger. Score : 0.88465
# Predict ke-228. Label : sadness. Score : 0.76619
# Predict ke-229. Label : fear. Score : 0.93374
# Predict ke-230. Label : fear. Score : 0.86209
# Predict ke-231. Label : sadness. Score : 0.96043
# Predict ke-232. Label : sadness. Score : 0.97519
# Predict ke-233. Label : joy. Score : 0.87228
# Predict ke-234. Label : sadness. Score : 0.87484
# Predict ke-235. Label : fear. Score : 0.695
# Predict ke-236. Label : anger. Score : 0.65115
# Predict ke-237. Label : sadness. Score : 0.47407
# Predict ke-238. Label : anger. Score : 0.48029
# Predict ke-239. Label : anger. Score : 0.76843
# Predict ke-240. Label : fear. Score : 0.96901
# Predict ke-241. Label : sadness. Score : 0.61676
# Predict ke-242. Label : joy. Score : 0.83309
# Predict ke-243. Label : fear. Score : 0.98104
# Predict ke-244. Label : anger. Score : 0.34461
# Predict ke-245. Label : fear. Score : 0.86623
# Predict ke-246. Label : sadness. Score : 0.94842
# Predict ke-247. Label : sadness. Score : 0.9177
# Predict ke-248. Label : sadness. Score : 0.71078
# Predict ke-249. Label : fear. Score : 0.65138
# Predict ke-250. Label : neutral. Score : 0.62265
# Predict ke-251. Label : sadness. Score : 0.98076
# Predict ke-252. Label : sadness. Score : 0.97314
# Predict ke-253. Label : joy. Score : 0.80414
# Predict ke-254. Label : joy. Score : 0.77847
# Predict ke-255. Label : joy. Score : 0.98866
# Predict ke-256. Label : fear. Score : 0.89283
# Predict ke-257. Label : joy. Score : 0.7615
# Predict ke-258. Label : sadness. Score : 0.83783
# Predict ke-259. Label : joy. Score : 0.69611
# Predict ke-260. Label : joy. Score : 0.63963
# Predict ke-261. Label : neutral. Score : 0.62288
# Predict ke-262. Label : sadness. Score : 0.90726
# Predict ke-263. Label : joy. Score : 0.31743
# Predict ke-264. Label : neutral. Score : 0.73285
# Predict ke-265. Label : anger. Score : 0.61375
# Predict ke-266. Label : fear. Score : 0.90136
# Predict ke-267. Label : fear. Score : 0.37376
# Predict ke-268. Label : anger. Score : 0.85346
# Predict ke-269. Label : sadness. Score : 0.98891
# Predict ke-270. Label : sadness. Score : 0.97387
# Predict ke-271. Label : joy. Score : 0.63422
# Predict ke-272. Label : neutral. Score : 0.51808
# Predict ke-273. Label : disgust. Score : 0.3804
# Predict ke-274. Label : fear. Score : 0.99443
# Predict ke-275. Label : anger. Score : 0.96268
# Predict ke-276. Label : fear. Score : 0.98826
# Predict ke-277. Label : surprise. Score : 0.67448
# Predict ke-278. Label : sadness. Score : 0.95816
# Predict ke-279. Label : neutral. Score : 0.44629
# Predict ke-280. Label : anger. Score : 0.39491
# Predict ke-281. Label : fear. Score : 0.65938
# Predict ke-282. Label : anger. Score : 0.32452
# Predict ke-283. Label : sadness. Score : 0.79312
# Predict ke-284. Label : fear. Score : 0.92748
# Predict ke-285. Label : sadness. Score : 0.97239
# Predict ke-286. Label : sadness. Score : 0.98395
# Predict ke-287. Label : sadness. Score : 0.97613
# Predict ke-288. Label : sadness. Score : 0.78376
# Predict ke-289. Label : joy. Score : 0.94627
# Predict ke-290. Label : sadness. Score : 0.89467
# Predict ke-291. Label : surprise. Score : 0.85847
# Predict ke-292. Label : disgust. Score : 0.41805
# Predict ke-293. Label : fear. Score : 0.49237
# Predict ke-294. Label : fear. Score : 0.99205
# Predict ke-295. Label : fear. Score : 0.89
# Predict ke-296. Label : surprise. Score : 0.94075
# Predict ke-297. Label : fear. Score : 0.81095
# Predict ke-298. Label : sadness. Score : 0.96526
# Predict ke-299. Label : fear. Score : 0.4588
# Predict ke-300. Label : fear. Score : 0.99157
# Predict ke-301. Label : sadness. Score : 0.59059
# Predict ke-302. Label : sadness. Score : 0.46585
# Predict ke-303. Label : sadness. Score : 0.83767
# Predict ke-304. Label : fear. Score : 0.88692
# Predict ke-305. Label : sadness. Score : 0.561
# Predict ke-306. Label : sadness. Score : 0.57373
# Predict ke-307. Label : sadness. Score : 0.92966
# Predict ke-308. Label : joy. Score : 0.89877
# Predict ke-309. Label : anger. Score : 0.75907
# Predict ke-310. Label : anger. Score : 0.89927
# Predict ke-311. Label : fear. Score : 0.61585
# Predict ke-312. Label : fear. Score : 0.90148
# Predict ke-313. Label : fear. Score : 0.7739
# Predict ke-314. Label : surprise. Score : 0.34535
# Predict ke-315. Label : fear. Score : 0.79749
# Predict ke-316. Label : neutral. Score : 0.92747
# Predict ke-317. Label : fear. Score : 0.98327
# Predict ke-318. Label : sadness. Score : 0.97745
# Predict ke-319. Label : joy. Score : 0.88745
# Predict ke-320. Label : anger. Score : 0.98599
# Predict ke-321. Label : sadness. Score : 0.89681
# Predict ke-322. Label : fear. Score : 0.75713
# Predict ke-323. Label : fear. Score : 0.98915
# Predict ke-324. Label : sadness. Score : 0.61274
# Predict ke-325. Label : joy. Score : 0.80484
# Predict ke-326. Label : anger. Score : 0.93407
# Predict ke-327. Label : anger. Score : 0.62026
# Predict ke-328. Label : neutral. Score : 0.29417
# Predict ke-329. Label : sadness. Score : 0.72916
# Predict ke-330. Label : sadness. Score : 0.97269
# Predict ke-331. Label : anger. Score : 0.98533
# Predict ke-332. Label : sadness. Score : 0.92953
# Predict ke-333. Label : fear. Score : 0.97951
# Predict ke-334. Label : sadness. Score : 0.86297
# Predict ke-335. Label : sadness. Score : 0.9122
# Predict ke-336. Label : sadness. Score : 0.9469
# Predict ke-337. Label : joy. Score : 0.9829
# Predict ke-338. Label : joy. Score : 0.61903
# Predict ke-339. Label : anger. Score : 0.95604
# Predict ke-340. Label : sadness. Score : 0.57863
# Predict ke-341. Label : sadness. Score : 0.96995
# Predict ke-342. Label : sadness. Score : 0.31491
# Predict ke-343. Label : fear. Score : 0.9337
# Predict ke-344. Label : sadness. Score : 0.98278
# Predict ke-345. Label : joy. Score : 0.67982
# Predict ke-346. Label : surprise. Score : 0.5663
# Predict ke-347. Label : fear. Score : 0.98815
# Predict ke-348. Label : sadness. Score : 0.55148
# Predict ke-349. Label : sadness. Score : 0.92154
# Predict ke-350. Label : sadness. Score : 0.55679
# Predict ke-351. Label : anger. Score : 0.49925
# Predict ke-352. Label : neutral. Score : 0.52101
# Predict ke-353. Label : joy. Score : 0.41373
# Predict ke-354. Label : sadness. Score : 0.98287
# Predict ke-355. Label : anger. Score : 0.54229
# Predict ke-356. Label : fear. Score : 0.64786
# Predict ke-357. Label : sadness. Score : 0.97185
# Predict ke-358. Label : anger. Score : 0.98729
# Predict ke-359. Label : anger. Score : 0.63975
# Predict ke-360. Label : fear. Score : 0.39054
# Predict ke-361. Label : sadness. Score : 0.88238
# Predict ke-362. Label : sadness. Score : 0.54198
# Predict ke-363. Label : fear. Score : 0.98479
# Predict ke-364. Label : sadness. Score : 0.62335
# Predict ke-365. Label : anger. Score : 0.75283
# Predict ke-366. Label : fear. Score : 0.92588
# Predict ke-367. Label : joy. Score : 0.96992
# Predict ke-368. Label : anger. Score : 0.87405
# Predict ke-369. Label : joy. Score : 0.53745
# Predict ke-370. Label : joy. Score : 0.73571
# Predict ke-371. Label : sadness. Score : 0.58546
# Predict ke-372. Label : sadness. Score : 0.97102
# Predict ke-373. Label : sadness. Score : 0.98501
# Predict ke-374. Label : joy. Score : 0.4311
# Predict ke-375. Label : sadness. Score : 0.96904
# Predict ke-376. Label : sadness. Score : 0.76423
# Predict ke-377. Label : fear. Score : 0.95912
# Predict ke-378. Label : fear. Score : 0.98916
# Predict ke-379. Label : sadness. Score : 0.95233
# Predict ke-380. Label : sadness. Score : 0.98636
# Predict ke-381. Label : joy. Score : 0.98758
# Predict ke-382. Label : anger. Score : 0.9237
# Predict ke-383. Label : sadness. Score : 0.98312
# Predict ke-384. Label : fear. Score : 0.93873
# Predict ke-385. Label : joy. Score : 0.31624
# Predict ke-386. Label : sadness. Score : 0.98691
# Predict ke-387. Label : sadness. Score : 0.96464
# Predict ke-388. Label : anger. Score : 0.67305
# Predict ke-389. Label : fear. Score : 0.36686
# Predict ke-390. Label : fear. Score : 0.79211
# Predict ke-391. Label : sadness. Score : 0.77508
# Predict ke-392. Label : fear. Score : 0.49194
# Predict ke-393. Label : anger. Score : 0.94116
# Predict ke-394. Label : fear. Score : 0.97794
# Predict ke-395. Label : sadness. Score : 0.85451
# Predict ke-396. Label : anger. Score : 0.87799
# Predict ke-397. Label : joy. Score : 0.82016
# Predict ke-398. Label : sadness. Score : 0.96364
# Predict ke-399. Label : sadness. Score : 0.81569
# Predict ke-400. Label : sadness. Score : 0.98115
# Predict ke-401. Label : sadness. Score : 0.68722
# Predict ke-402. Label : anger. Score : 0.96145
# Predict ke-403. Label : anger. Score : 0.79257
# Predict ke-404. Label : joy. Score : 0.5214
# Predict ke-405. Label : sadness. Score : 0.44487
# Predict ke-406. Label : sadness. Score : 0.98354
# Predict ke-407. Label : joy. Score : 0.97205
# Predict ke-408. Label : joy. Score : 0.87548
# Predict ke-409. Label : fear. Score : 0.88874
# Predict ke-410. Label : fear. Score : 0.70407
# Predict ke-411. Label : sadness. Score : 0.861
# Predict ke-412. Label : sadness. Score : 0.69352
# Predict ke-413. Label : neutral. Score : 0.47361
# Predict ke-414. Label : anger. Score : 0.70352
# Predict ke-415. Label : fear. Score : 0.94044
# Predict ke-416. Label : anger. Score : 0.41937
# Predict ke-417. Label : anger. Score : 0.78858
# Predict ke-418. Label : sadness. Score : 0.48385
# Predict ke-419. Label : sadness. Score : 0.50475
# Predict ke-420. Label : fear. Score : 0.73299
# Predict ke-421. Label : sadness. Score : 0.88465
# Predict ke-422. Label : sadness. Score : 0.98121
# Predict ke-423. Label : anger. Score : 0.97697
# Predict ke-424. Label : anger. Score : 0.66747
# Predict ke-425. Label : joy. Score : 0.97506
# Predict ke-426. Label : sadness. Score : 0.78084
# Predict ke-427. Label : sadness. Score : 0.8273
# Predict ke-428. Label : sadness. Score : 0.95684
# Predict ke-429. Label : sadness. Score : 0.71681
# Predict ke-430. Label : joy. Score : 0.47237
# Predict ke-431. Label : neutral. Score : 0.80299
# Predict ke-432. Label : sadness. Score : 0.98347
# Predict ke-433. Label : sadness. Score : 0.97996
# Predict ke-434. Label : fear. Score : 0.71206
# Predict ke-435. Label : joy. Score : 0.8314
# Predict ke-436. Label : anger. Score : 0.64685
# Predict ke-437. Label : sadness. Score : 0.7053
# Predict ke-438. Label : anger. Score : 0.93586
# Predict ke-439. Label : sadness. Score : 0.61369
# Predict ke-440. Label : sadness. Score : 0.78104
# Predict ke-441. Label : fear. Score : 0.99133
# Predict ke-442. Label : sadness. Score : 0.92435
# Predict ke-443. Label : neutral. Score : 0.37057
# Predict ke-444. Label : joy. Score : 0.45728
# Predict ke-445. Label : sadness. Score : 0.98052
# Predict ke-446. Label : sadness. Score : 0.95944
# Predict ke-447. Label : neutral. Score : 0.51761
# Predict ke-448. Label : sadness. Score : 0.98377
# Predict ke-449. Label : fear. Score : 0.93731
# Predict ke-450. Label : anger. Score : 0.77946
# Predict ke-451. Label : sadness. Score : 0.81153
# Predict ke-452. Label : joy. Score : 0.88609
# Predict ke-453. Label : neutral. Score : 0.5794
# Predict ke-454. Label : sadness. Score : 0.62575
# Predict ke-455. Label : joy. Score : 0.66081
# Predict ke-456. Label : neutral. Score : 0.53885
# Predict ke-457. Label : anger. Score : 0.80194
# Predict ke-458. Label : anger. Score : 0.96788
# Predict ke-459. Label : sadness. Score : 0.50289
# Predict ke-460. Label : sadness. Score : 0.77988
# Predict ke-461. Label : joy. Score : 0.57442
# Predict ke-462. Label : sadness. Score : 0.67038
# Predict ke-463. Label : neutral. Score : 0.42101
# Predict ke-464. Label : fear. Score : 0.44789
# Predict ke-465. Label : fear. Score : 0.94232
# Predict ke-466. Label : anger. Score : 0.34294
# Predict ke-467. Label : anger. Score : 0.57699
# Predict ke-468. Label : sadness. Score : 0.46143
# Predict ke-469. Label : sadness. Score : 0.47486
# Predict ke-470. Label : surprise. Score : 0.34968
# Predict ke-471. Label : fear. Score : 0.85816
# Predict ke-472. Label : anger. Score : 0.80007
# Predict ke-473. Label : joy. Score : 0.43159
# Predict ke-474. Label : anger. Score : 0.8796
# Predict ke-475. Label : joy. Score : 0.83037
# Predict ke-476. Label : sadness. Score : 0.76527
# Predict ke-477. Label : joy. Score : 0.97155
# Predict ke-478. Label : anger. Score : 0.88472
# Predict ke-479. Label : joy. Score : 0.8042
# Predict ke-480. Label : fear. Score : 0.97547
# Predict ke-481. Label : anger. Score : 0.8855
# Predict ke-482. Label : joy. Score : 0.86166
# Predict ke-483. Label : anger. Score : 0.45235
# Predict ke-484. Label : sadness. Score : 0.97847
# Predict ke-485. Label : sadness. Score : 0.91903
# Predict ke-486. Label : surprise. Score : 0.67792
# Predict ke-487. Label : sadness. Score : 0.87555
# Predict ke-488. Label : sadness. Score : 0.84532
# Predict ke-489. Label : joy. Score : 0.85012
# Predict ke-490. Label : sadness. Score : 0.64001
# Predict ke-491. Label : sadness. Score : 0.7917
# Predict ke-492. Label : anger. Score : 0.48531
# Predict ke-493. Label : sadness. Score : 0.90046
# Predict ke-494. Label : joy. Score : 0.89823
# Predict ke-495. Label : sadness. Score : 0.95546
# Predict ke-496. Label : sadness. Score : 0.61031
# Predict ke-497. Label : fear. Score : 0.91582
# Predict ke-498. Label : fear. Score : 0.97884
# Predict ke-499. Label : joy. Score : 0.97979
# Predict ke-500. Label : fear. Score : 0.98989
# Predict ke-501. Label : sadness. Score : 0.58576
# Predict ke-502. Label : anger. Score : 0.44322
# Predict ke-503. Label : anger. Score : 0.73834
# Predict ke-504. Label : neutral. Score : 0.47405
# Predict ke-505. Label : fear. Score : 0.96804
# Predict ke-506. Label : anger. Score : 0.96558
# Predict ke-507. Label : sadness. Score : 0.4239
# Predict ke-508. Label : fear. Score : 0.44417
# Predict ke-509. Label : sadness. Score : 0.9731
# Predict ke-510. Label : fear. Score : 0.93458
# Predict ke-511. Label : sadness. Score : 0.94106
# Predict ke-512. Label : joy. Score : 0.66164
# Predict ke-513. Label : anger. Score : 0.68745
# Predict ke-514. Label : sadness. Score : 0.66131
# Predict ke-515. Label : joy. Score : 0.97282
# Predict ke-516. Label : sadness. Score : 0.68425
# Predict ke-517. Label : sadness. Score : 0.94247
# Predict ke-518. Label : anger. Score : 0.92478
# Predict ke-519. Label : fear. Score : 0.98391
# Predict ke-520. Label : sadness. Score : 0.40252
# Predict ke-521. Label : fear. Score : 0.77083
# Predict ke-522. Label : surprise. Score : 0.62582
# Predict ke-523. Label : fear. Score : 0.87362
# Predict ke-524. Label : sadness. Score : 0.51491
# Predict ke-525. Label : fear. Score : 0.81088
# Predict ke-526. Label : sadness. Score : 0.43369
# Predict ke-527. Label : surprise. Score : 0.79713
# Predict ke-528. Label : joy. Score : 0.95968
# Predict ke-529. Label : sadness. Score : 0.97838
# Predict ke-530. Label : joy. Score : 0.98309
# Predict ke-531. Label : sadness. Score : 0.47871
# Predict ke-532. Label : sadness. Score : 0.58239
# Predict ke-533. Label : fear. Score : 0.98321
# Predict ke-534. Label : sadness. Score : 0.95495
# Predict ke-535. Label : joy. Score : 0.91878
# Predict ke-536. Label : fear. Score : 0.68077
# Predict ke-537. Label : fear. Score : 0.82493
# Predict ke-538. Label : anger. Score : 0.43581
# Predict ke-539. Label : sadness. Score : 0.60874
# Predict ke-540. Label : fear. Score : 0.94687
# Predict ke-541. Label : fear. Score : 0.92721
# Predict ke-542. Label : neutral. Score : 0.48662
# Predict ke-543. Label : anger. Score : 0.9204
# Predict ke-544. Label : joy. Score : 0.95281
# Predict ke-545. Label : anger. Score : 0.7173
# Predict ke-546. Label : surprise. Score : 0.73803
# Predict ke-547. Label : fear. Score : 0.97393
# Predict ke-548. Label : anger. Score : 0.64059
# Predict ke-549. Label : fear. Score : 0.78732
# Predict ke-550. Label : fear. Score : 0.98029
# Predict ke-551. Label : fear. Score : 0.95896
# Predict ke-552. Label : joy. Score : 0.49283
# Predict ke-553. Label : anger. Score : 0.52251
# Predict ke-554. Label : sadness. Score : 0.84823
# Predict ke-555. Label : sadness. Score : 0.97215
# Predict ke-556. Label : neutral. Score : 0.56083
# Predict ke-557. Label : fear. Score : 0.9575
# Predict ke-558. Label : joy. Score : 0.8844
# Predict ke-559. Label : anger. Score : 0.3929
# Predict ke-560. Label : sadness. Score : 0.98153
# Predict ke-561. Label : fear. Score : 0.92703
# Predict ke-562. Label : sadness. Score : 0.43233
# Predict ke-563. Label : fear. Score : 0.99399
# Predict ke-564. Label : sadness. Score : 0.97726
# Predict ke-565. Label : fear. Score : 0.61831
# Predict ke-566. Label : sadness. Score : 0.88628
# Predict ke-567. Label : anger. Score : 0.59755
# Predict ke-568. Label : joy. Score : 0.97764
# Predict ke-569. Label : anger. Score : 0.62966
# Predict ke-570. Label : anger. Score : 0.48401
# Predict ke-571. Label : joy. Score : 0.43797
# Predict ke-572. Label : anger. Score : 0.4088
# Predict ke-573. Label : fear. Score : 0.72822
# Predict ke-574. Label : sadness. Score : 0.86728
# Predict ke-575. Label : fear. Score : 0.69517
# Predict ke-576. Label : sadness. Score : 0.91024
# Predict ke-577. Label : neutral. Score : 0.44842
# Predict ke-578. Label : fear. Score : 0.60015
# Predict ke-579. Label : sadness. Score : 0.96892
# Predict ke-580. Label : fear. Score : 0.99398
# Predict ke-581. Label : sadness. Score : 0.89911
# Predict ke-582. Label : sadness. Score : 0.98328
# Predict ke-583. Label : sadness. Score : 0.91867
# Predict ke-584. Label : joy. Score : 0.98812
# Predict ke-585. Label : sadness. Score : 0.43492
# Predict ke-586. Label : joy. Score : 0.8971
# Predict ke-587. Label : joy. Score : 0.89029
# Predict ke-588. Label : anger. Score : 0.95497
# Predict ke-589. Label : neutral. Score : 0.4676
# Predict ke-590. Label : fear. Score : 0.73505
# Predict ke-591. Label : sadness. Score : 0.95761
# Predict ke-592. Label : joy. Score : 0.79059
# Predict ke-593. Label : sadness. Score : 0.73665
# Predict ke-594. Label : anger. Score : 0.47632
# Predict ke-595. Label : sadness. Score : 0.98828
# Predict ke-596. Label : joy. Score : 0.65429
# Predict ke-597. Label : joy. Score : 0.94384
# Predict ke-598. Label : anger. Score : 0.75753
# Predict ke-599. Label : fear. Score : 0.79662
# Predict ke-600. Label : fear. Score : 0.70923
# Predict ke-601. Label : anger. Score : 0.51407
# Predict ke-602. Label : joy. Score : 0.86865
# Predict ke-603. Label : sadness. Score : 0.66907
# Predict ke-604. Label : disgust. Score : 0.43427
# Predict ke-605. Label : sadness. Score : 0.60757
# Predict ke-606. Label : sadness. Score : 0.78481
# Predict ke-607. Label : joy. Score : 0.66035
# Predict ke-608. Label : joy. Score : 0.54311
# Predict ke-609. Label : sadness. Score : 0.50082
# Predict ke-610. Label : sadness. Score : 0.69109
# Predict ke-611. Label : sadness. Score : 0.73523
# Predict ke-612. Label : surprise. Score : 0.80738
# Predict ke-613. Label : neutral. Score : 0.49095
# Predict ke-614. Label : joy. Score : 0.9762
# Predict ke-615. Label : sadness. Score : 0.92257
# Predict ke-616. Label : sadness. Score : 0.34171
# Predict ke-617. Label : sadness. Score : 0.88015
# Predict ke-618. Label : joy. Score : 0.98632
# Predict ke-619. Label : anger. Score : 0.83595
# Predict ke-620. Label : neutral. Score : 0.73043
# Predict ke-621. Label : neutral. Score : 0.88508
# Predict ke-622. Label : sadness. Score : 0.90558
# Predict ke-623. Label : anger. Score : 0.9726
# Predict ke-624. Label : fear. Score : 0.43203
# Predict ke-625. Label : fear. Score : 0.56861
# Predict ke-626. Label : sadness. Score : 0.97753
# Predict ke-627. Label : sadness. Score : 0.76737
# Predict ke-628. Label : sadness. Score : 0.81774
# Predict ke-629. Label : joy. Score : 0.76452
# Predict ke-630. Label : sadness. Score : 0.93078
# Predict ke-631. Label : joy. Score : 0.86889
# Predict ke-632. Label : fear. Score : 0.84888
# Predict ke-633. Label : anger. Score : 0.94543
# Predict ke-634. Label : sadness. Score : 0.74966
# Predict ke-635. Label : anger. Score : 0.98869
# Predict ke-636. Label : sadness. Score : 0.97746
# Predict ke-637. Label : neutral. Score : 0.82554
# Predict ke-638. Label : sadness. Score : 0.46906
# Predict ke-639. Label : anger. Score : 0.41703
# Predict ke-640. Label : sadness. Score : 0.72002
# Predict ke-641. Label : sadness. Score : 0.62816
# Predict ke-642. Label : joy. Score : 0.79302
# Predict ke-643. Label : fear. Score : 0.83163
# Predict ke-644. Label : fear. Score : 0.86943
# Predict ke-645. Label : sadness. Score : 0.62899
# Predict ke-646. Label : joy. Score : 0.9419
# Predict ke-647. Label : sadness. Score : 0.9649
# Predict ke-648. Label : joy. Score : 0.86333
# Predict ke-649. Label : sadness. Score : 0.92625
# Predict ke-650. Label : anger. Score : 0.9716
# Predict ke-651. Label : fear. Score : 0.98951
# Predict ke-652. Label : sadness. Score : 0.94728
# Predict ke-653. Label : sadness. Score : 0.59099
# Predict ke-654. Label : joy. Score : 0.49033
# Predict ke-655. Label : joy. Score : 0.76254
# Predict ke-656. Label : fear. Score : 0.80044
# Predict ke-657. Label : sadness. Score : 0.35591
# Predict ke-658. Label : sadness. Score : 0.97131
# Predict ke-659. Label : joy. Score : 0.49831
# Predict ke-660. Label : anger. Score : 0.75368
# Predict ke-661. Label : fear. Score : 0.99067
# Predict ke-662. Label : anger. Score : 0.52146
# Predict ke-663. Label : anger. Score : 0.98394
# Predict ke-664. Label : sadness. Score : 0.71884
# Predict ke-665. Label : sadness. Score : 0.98598
# Predict ke-666. Label : sadness. Score : 0.97991
# Predict ke-667. Label : sadness. Score : 0.68952
# Predict ke-668. Label : fear. Score : 0.89923
# Predict ke-669. Label : fear. Score : 0.98492
# Predict ke-670. Label : sadness. Score : 0.53987
# Predict ke-671. Label : sadness. Score : 0.98837
# Predict ke-672. Label : sadness. Score : 0.95045
# Predict ke-673. Label : fear. Score : 0.94903
# Predict ke-674. Label : neutral. Score : 0.34782
# Predict ke-675. Label : fear. Score : 0.98302
# Predict ke-676. Label : sadness. Score : 0.97551
# Predict ke-677. Label : fear. Score : 0.82318
# Predict ke-678. Label : sadness. Score : 0.88563
# Predict ke-679. Label : sadness. Score : 0.65164
# Predict ke-680. Label : fear. Score : 0.98269
# Predict ke-681. Label : fear. Score : 0.99223
# Predict ke-682. Label : neutral. Score : 0.67729
# Predict ke-683. Label : fear. Score : 0.91569
# Predict ke-684. Label : sadness. Score : 0.96603
# Predict ke-685. Label : sadness. Score : 0.94546
# Predict ke-686. Label : sadness. Score : 0.81959
# Predict ke-687. Label : sadness. Score : 0.97975
# Predict ke-688. Label : anger. Score : 0.89842
# Predict ke-689. Label : sadness. Score : 0.73228
# Predict ke-690. Label : sadness. Score : 0.93504
# Predict ke-691. Label : sadness. Score : 0.70895
# Predict ke-692. Label : anger. Score : 0.98296
# Predict ke-693. Label : sadness. Score : 0.50537
# Predict ke-694. Label : sadness. Score : 0.72993
# Predict ke-695. Label : fear. Score : 0.88727
# Predict ke-696. Label : fear. Score : 0.99265
# Predict ke-697. Label : sadness. Score : 0.71189
# Predict ke-698. Label : sadness. Score : 0.37114
# Predict ke-699. Label : sadness. Score : 0.98005
# Predict ke-700. Label : joy. Score : 0.69087
# Predict ke-701. Label : surprise. Score : 0.38056
# Predict ke-702. Label : joy. Score : 0.96527
# Predict ke-703. Label : anger. Score : 0.52792
# Predict ke-704. Label : sadness. Score : 0.92181
# Predict ke-705. Label : fear. Score : 0.33293
# Predict ke-706. Label : fear. Score : 0.83634
# Predict ke-707. Label : joy. Score : 0.9243
# Predict ke-708. Label : sadness. Score : 0.72017
# Predict ke-709. Label : sadness. Score : 0.62823
# Predict ke-710. Label : joy. Score : 0.96507
# Predict ke-711. Label : anger. Score : 0.96488
# Predict ke-712. Label : fear. Score : 0.98772
# Predict ke-713. Label : sadness. Score : 0.96933
# Predict ke-714. Label : fear. Score : 0.98255
# Predict ke-715. Label : anger. Score : 0.71355
# Predict ke-716. Label : fear. Score : 0.95196
# Predict ke-717. Label : sadness. Score : 0.97756
# Predict ke-718. Label : surprise. Score : 0.38913
# Predict ke-719. Label : joy. Score : 0.99184
# Predict ke-720. Label : fear. Score : 0.78819
# Predict ke-721. Label : fear. Score : 0.44574
# Predict ke-722. Label : anger. Score : 0.36622
# Predict ke-723. Label : sadness. Score : 0.57271
# Predict ke-724. Label : sadness. Score : 0.72146
# Predict ke-725. Label : neutral. Score : 0.45022
# Predict ke-726. Label : sadness. Score : 0.97725
# Predict ke-727. Label : fear. Score : 0.98871
# Predict ke-728. Label : anger. Score : 0.8518
# Predict ke-729. Label : fear. Score : 0.8536
# Predict ke-730. Label : joy. Score : 0.83894
# Predict ke-731. Label : fear. Score : 0.85068
# Predict ke-732. Label : anger. Score : 0.85384
# Predict ke-733. Label : fear. Score : 0.95158
# Predict ke-734. Label : sadness. Score : 0.96759
# Predict ke-735. Label : anger. Score : 0.52584
# Predict ke-736. Label : disgust. Score : 0.46846
# Predict ke-737. Label : sadness. Score : 0.47641
# Predict ke-738. Label : anger. Score : 0.41946
# Predict ke-739. Label : sadness. Score : 0.82818
# Predict ke-740. Label : sadness. Score : 0.5976
# Predict ke-741. Label : fear. Score : 0.52849
# Predict ke-742. Label : sadness. Score : 0.39196
# Predict ke-743. Label : sadness. Score : 0.93414
# Predict ke-744. Label : fear. Score : 0.82249
# Predict ke-745. Label : sadness. Score : 0.95018
# Predict ke-746. Label : sadness. Score : 0.96761
# Predict ke-747. Label : joy. Score : 0.57561
# Predict ke-748. Label : neutral. Score : 0.43987
# Predict ke-749. Label : fear. Score : 0.98631
# Predict ke-750. Label : joy. Score : 0.85484
# Predict ke-751. Label : anger. Score : 0.62855
# Predict ke-752. Label : fear. Score : 0.92938
# Predict ke-753. Label : sadness. Score : 0.89585
# Predict ke-754. Label : fear. Score : 0.96878
# Predict ke-755. Label : fear. Score : 0.99303
# Predict ke-756. Label : surprise. Score : 0.53857
# Predict ke-757. Label : joy. Score : 0.97824
# Predict ke-758. Label : fear. Score : 0.62474
# Predict ke-759. Label : anger. Score : 0.42787
# Predict ke-760. Label : anger. Score : 0.46303
# Predict ke-761. Label : sadness. Score : 0.59601
# Predict ke-762. Label : joy. Score : 0.95093
# Predict ke-763. Label : fear. Score : 0.9587
# Predict ke-764. Label : fear. Score : 0.52252
# Predict ke-765. Label : fear. Score : 0.88708
# Predict ke-766. Label : joy. Score : 0.74663
# Predict ke-767. Label : sadness. Score : 0.97107
# Predict ke-768. Label : joy. Score : 0.61647
# Predict ke-769. Label : fear. Score : 0.9897
# Predict ke-770. Label : fear. Score : 0.82571
# Predict ke-771. Label : sadness. Score : 0.684
# Predict ke-772. Label : neutral. Score : 0.6557
# Predict ke-773. Label : anger. Score : 0.93408
# Predict ke-774. Label : sadness. Score : 0.88973
# Predict ke-775. Label : fear. Score : 0.65176
# Predict ke-776. Label : sadness. Score : 0.61177
# Predict ke-777. Label : joy. Score : 0.93475
# Predict ke-778. Label : sadness. Score : 0.64921
# Predict ke-779. Label : sadness. Score : 0.84449
# Predict ke-780. Label : sadness. Score : 0.52651
# Predict ke-781. Label : fear. Score : 0.68157
# Predict ke-782. Label : anger. Score : 0.49724
# Predict ke-783. Label : sadness. Score : 0.98763
# Predict ke-784. Label : joy. Score : 0.91632
# Predict ke-785. Label : sadness. Score : 0.97174
# Predict ke-786. Label : joy. Score : 0.87843
# Predict ke-787. Label : joy. Score : 0.94804
# Predict ke-788. Label : fear. Score : 0.85577
# Predict ke-789. Label : fear. Score : 0.73051
# Predict ke-790. Label : fear. Score : 0.71837
# Predict ke-791. Label : sadness. Score : 0.96228
# Predict ke-792. Label : fear. Score : 0.92804
# Predict ke-793. Label : joy. Score : 0.59695
# Predict ke-794. Label : sadness. Score : 0.53895
# Predict ke-795. Label : fear. Score : 0.98187
# Predict ke-796. Label : anger. Score : 0.97948
# Predict ke-797. Label : neutral. Score : 0.88565
# Predict ke-798. Label : joy. Score : 0.59437
# Predict ke-799. Label : anger. Score : 0.78845
# Predict ke-800. Label : fear. Score : 0.99311
# Predict ke-801. Label : fear. Score : 0.8253
# Predict ke-802. Label : fear. Score : 0.96345
# Predict ke-803. Label : sadness. Score : 0.48901
# Predict ke-804. Label : fear. Score : 0.49318
# Predict ke-805. Label : disgust. Score : 0.46293
# Predict ke-806. Label : fear. Score : 0.98194
# Predict ke-807. Label : anger. Score : 0.95427
# Predict ke-808. Label : fear. Score : 0.98046
# Predict ke-809. Label : joy. Score : 0.76469
# Predict ke-810. Label : sadness. Score : 0.9324
# Predict ke-811. Label : sadness. Score : 0.91901
# Predict ke-812. Label : anger. Score : 0.61129
# Predict ke-813. Label : sadness. Score : 0.94126
# Predict ke-814. Label : joy. Score : 0.86278
# Predict ke-815. Label : sadness. Score : 0.98417
# Predict ke-816. Label : anger. Score : 0.92161
# Predict ke-817. Label : sadness. Score : 0.74675
# Predict ke-818. Label : anger. Score : 0.82574
# Predict ke-819. Label : fear. Score : 0.89882
# Predict ke-820. Label : sadness. Score : 0.61697
# Predict ke-821. Label : anger. Score : 0.35264
# Predict ke-822. Label : joy. Score : 0.97335
# Predict ke-823. Label : fear. Score : 0.99364
# Predict ke-824. Label : sadness. Score : 0.8966
# Predict ke-825. Label : neutral. Score : 0.40245
# Predict ke-826. Label : sadness. Score : 0.55795
# Predict ke-827. Label : neutral. Score : 0.84746
# Predict ke-828. Label : fear. Score : 0.9319
# Predict ke-829. Label : surprise. Score : 0.30584
# Predict ke-830. Label : fear. Score : 0.9893
# Predict ke-831. Label : fear. Score : 0.93544
# Predict ke-832. Label : surprise. Score : 0.32858
# Predict ke-833. Label : joy. Score : 0.94499
# Predict ke-834. Label : sadness. Score : 0.54638
# Predict ke-835. Label : sadness. Score : 0.98395
# Predict ke-836. Label : sadness. Score : 0.86849
# Predict ke-837. Label : fear. Score : 0.78132
# Predict ke-838. Label : sadness. Score : 0.9088
# Predict ke-839. Label : fear. Score : 0.98835
# Predict ke-840. Label : sadness. Score : 0.95668
# Predict ke-841. Label : surprise. Score : 0.4557
# Predict ke-842. Label : anger. Score : 0.94678
# Predict ke-843. Label : anger. Score : 0.9907
# Predict ke-844. Label : sadness. Score : 0.83564
# Predict ke-845. Label : anger. Score : 0.78536
# Predict ke-846. Label : sadness. Score : 0.97602
# Predict ke-847. Label : sadness. Score : 0.6537
# Predict ke-848. Label : fear. Score : 0.57806
# Predict ke-849. Label : fear. Score : 0.71897
# Predict ke-850. Label : fear. Score : 0.93528
# Predict ke-851. Label : joy. Score : 0.4558
# Predict ke-852. Label : joy. Score : 0.80517
# Predict ke-853. Label : fear. Score : 0.9884
# Predict ke-854. Label : sadness. Score : 0.96901
# Predict ke-855. Label : anger. Score : 0.97977
# Predict ke-856. Label : fear. Score : 0.96331
# Predict ke-857. Label : joy. Score : 0.48091
# Predict ke-858. Label : neutral. Score : 0.90752
# Predict ke-859. Label : joy. Score : 0.91194
# Predict ke-860. Label : joy. Score : 0.86417
# Predict ke-861. Label : sadness. Score : 0.94325
# Predict ke-862. Label : fear. Score : 0.59005
# Predict ke-863. Label : anger. Score : 0.60658
# Predict ke-864. Label : anger. Score : 0.96892
# Predict ke-865. Label : sadness. Score : 0.76692
# Predict ke-866. Label : sadness. Score : 0.51146
# Predict ke-867. Label : neutral. Score : 0.45162
# Predict ke-868. Label : sadness. Score : 0.77428
# Predict ke-869. Label : sadness. Score : 0.30075
# Predict ke-870. Label : sadness. Score : 0.83346
# Predict ke-871. Label : joy. Score : 0.50949
# Predict ke-872. Label : fear. Score : 0.91144
# Predict ke-873. Label : anger. Score : 0.61742
# Predict ke-874. Label : sadness. Score : 0.98732
# Predict ke-875. Label : sadness. Score : 0.94044
# Predict ke-876. Label : joy. Score : 0.65004
# Predict ke-877. Label : neutral. Score : 0.69721
# Predict ke-878. Label : neutral. Score : 0.81487
# Predict ke-879. Label : fear. Score : 0.97709
# Predict ke-880. Label : anger. Score : 0.97084
# Predict ke-881. Label : fear. Score : 0.91928
# Predict ke-882. Label : sadness. Score : 0.681
# Predict ke-883. Label : fear. Score : 0.75883
# Predict ke-884. Label : neutral. Score : 0.41673
# Predict ke-885. Label : neutral. Score : 0.75738
# Predict ke-886. Label : sadness. Score : 0.77595
# Predict ke-887. Label : fear. Score : 0.37961
# Predict ke-888. Label : anger. Score : 0.51546
# Predict ke-889. Label : joy. Score : 0.97247
# Predict ke-890. Label : fear. Score : 0.98535
# Predict ke-891. Label : joy. Score : 0.50998
# Predict ke-892. Label : anger. Score : 0.68054
# Predict ke-893. Label : joy. Score : 0.59926
# Predict ke-894. Label : surprise. Score : 0.43296
# Predict ke-895. Label : anger. Score : 0.90421
# Predict ke-896. Label : fear. Score : 0.9525
# Predict ke-897. Label : sadness. Score : 0.60947
# Predict ke-898. Label : disgust. Score : 0.62106
# Predict ke-899. Label : joy. Score : 0.78297
# Predict ke-900. Label : joy. Score : 0.791
# Predict ke-901. Label : neutral. Score : 0.48472
# Predict ke-902. Label : surprise. Score : 0.40102
# Predict ke-903. Label : anger. Score : 0.86404
# Predict ke-904. Label : anger. Score : 0.573
# Predict ke-905. Label : neutral. Score : 0.30545
# Predict ke-906. Label : surprise. Score : 0.50722
# Predict ke-907. Label : sadness. Score : 0.89961
# Predict ke-908. Label : sadness. Score : 0.97863
# Predict ke-909. Label : sadness. Score : 0.97506
# Predict ke-910. Label : anger. Score : 0.95646
# Predict ke-911. Label : surprise. Score : 0.70561
# Predict ke-912. Label : joy. Score : 0.74477
# Predict ke-913. Label : fear. Score : 0.96445
# Predict ke-914. Label : sadness. Score : 0.94673
# Predict ke-915. Label : neutral. Score : 0.95021
# Predict ke-916. Label : neutral. Score : 0.58114
# Predict ke-917. Label : sadness. Score : 0.55995
# Predict ke-918. Label : anger. Score : 0.66555
# Predict ke-919. Label : sadness. Score : 0.92815
# Predict ke-920. Label : fear. Score : 0.98
# Predict ke-921. Label : joy. Score : 0.98516
# Predict ke-922. Label : joy. Score : 0.69591
# Predict ke-923. Label : sadness. Score : 0.91102
# Predict ke-924. Label : fear. Score : 0.70559
# Predict ke-925. Label : sadness. Score : 0.93447
# Predict ke-926. Label : anger. Score : 0.85367
# Predict ke-927. Label : joy. Score : 0.64792
# Predict ke-928. Label : joy. Score : 0.77403
# Predict ke-929. Label : surprise. Score : 0.35876
# Predict ke-930. Label : sadness. Score : 0.9751
# Predict ke-931. Label : sadness. Score : 0.72675
# Predict ke-932. Label : neutral. Score : 0.43314
# Predict ke-933. Label : sadness. Score : 0.98117
# Predict ke-934. Label : sadness. Score : 0.97686
# Predict ke-935. Label : joy. Score : 0.9849
# Predict ke-936. Label : sadness. Score : 0.98883
# Predict ke-937. Label : fear. Score : 0.928
# Predict ke-938. Label : anger. Score : 0.93017
# Predict ke-939. Label : neutral. Score : 0.4678
# Predict ke-940. Label : sadness. Score : 0.79411
# Predict ke-941. Label : sadness. Score : 0.82905
# Predict ke-942. Label : sadness. Score : 0.91179
# Predict ke-943. Label : sadness. Score : 0.96359
# Predict ke-944. Label : joy. Score : 0.858
# Predict ke-945. Label : fear. Score : 0.92711
# Predict ke-946. Label : neutral. Score : 0.4274
# Predict ke-947. Label : sadness. Score : 0.94271
# Predict ke-948. Label : fear. Score : 0.89915
# Predict ke-949. Label : sadness. Score : 0.98102
# Predict ke-950. Label : sadness. Score : 0.78974
# Predict ke-951. Label : anger. Score : 0.38846
# Predict ke-952. Label : sadness. Score : 0.97655
# Predict ke-953. Label : sadness. Score : 0.80663
# Predict ke-954. Label : joy. Score : 0.93949
# Predict ke-955. Label : sadness. Score : 0.93488
# Predict ke-956. Label : sadness. Score : 0.98399
# Predict ke-957. Label : fear. Score : 0.93246
# Predict ke-958. Label : sadness. Score : 0.97252
# Predict ke-959. Label : sadness. Score : 0.94764
# Predict ke-960. Label : sadness. Score : 0.66993
# Predict ke-961. Label : sadness. Score : 0.9773
# Predict ke-962. Label : fear. Score : 0.40383
# Predict ke-963. Label : surprise. Score : 0.95511
# Predict ke-964. Label : sadness. Score : 0.59624
# Predict ke-965. Label : joy. Score : 0.90222
# Predict ke-966. Label : joy. Score : 0.97609
# Predict ke-967. Label : sadness. Score : 0.96246
# Predict ke-968. Label : sadness. Score : 0.98031
# Predict ke-969. Label : anger. Score : 0.9757
# Predict ke-970. Label : sadness. Score : 0.96848
# Predict ke-971. Label : fear. Score : 0.98307
# Predict ke-972. Label : sadness. Score : 0.96752
# Predict ke-973. Label : sadness. Score : 0.95024
# Predict ke-974. Label : sadness. Score : 0.88688
# Predict ke-975. Label : sadness. Score : 0.61632
# Predict ke-976. Label : sadness. Score : 0.98694
# Predict ke-977. Label : fear. Score : 0.98691
# Predict ke-978. Label : fear. Score : 0.55652
# Predict ke-979. Label : joy. Score : 0.55481
# Predict ke-980. Label : anger. Score : 0.93155
# Predict ke-981. Label : sadness. Score : 0.91447
# Predict ke-982. Label : sadness. Score : 0.9703
# Predict ke-983. Label : anger. Score : 0.59887
# Predict ke-984. Label : surprise. Score : 0.82995
# Predict ke-985. Label : surprise. Score : 0.40285
# Predict ke-986. Label : sadness. Score : 0.86359
# Predict ke-987. Label : sadness. Score : 0.78331
# Predict ke-988. Label : joy. Score : 0.92423
# Predict ke-989. Label : sadness. Score : 0.99057
# Predict ke-990. Label : anger. Score : 0.42738
# Predict ke-991. Label : anger. Score : 0.67668
# Predict ke-992. Label : surprise. Score : 0.82047
# Predict ke-993. Label : joy. Score : 0.79149
# Predict ke-994. Label : joy. Score : 0.85521
# Predict ke-995. Label : neutral. Score : 0.76917
# Predict ke-996. Label : sadness. Score : 0.94965
# Predict ke-997. Label : sadness. Score : 0.97671
# Predict ke-998. Label : joy. Score : 0.77222
# Predict ke-999. Label : fear. Score : 0.27787
# Predict ke-1000. Label : neutral. Score : 0.8512
# Predict ke-1001. Label : sadness. Score : 0.98656
# Predict ke-1002. Label : sadness. Score : 0.5233
# Predict ke-1003. Label : anger. Score : 0.43405
# Predict ke-1004. Label : sadness. Score : 0.97882
# Predict ke-1005. Label : fear. Score : 0.96246
# Predict ke-1006. Label : sadness. Score : 0.97086
# Predict ke-1007. Label : joy. Score : 0.72409
# Predict ke-1008. Label : sadness. Score : 0.9889
# Predict ke-1009. Label : neutral. Score : 0.81449
# Predict ke-1010. Label : fear. Score : 0.38131
# ...
# Predict ke-17088. Label : fear. Score : 0.8858
# Predict ke-17089. Label : anger. Score : 0.60135
# Predict ke-17090. Label : sadness. Score : 0.6397
# Predict ke-17091. Label : fear. Score : 0.73674
# Predict ke-17092. Label : sadness. Score : 0.72785
# Predict ke-17093. Label : sadness. Score : 0.98601
# Predict ke-17094. Label : anger. Score : 0.88917
# Predict ke-17095. Label : fear. Score : 0.48662
# Predict ke-17096. Label : joy. Score : 0.98857
# Predict ke-17097. Label : sadness. Score : 0.62526
# Predict ke-17098. Label : joy. Score : 0.49128
# Predict ke-17099. Label : sadness. Score : 0.98549
# Predict ke-17100. Label : neutral. Score : 0.66066
# Predict ke-17101. Label : sadness. Score : 0.97501
# Predict ke-17102. Label : sadness. Score : 0.8867
# Predict ke-17103. Label : sadness. Score : 0.47036
# Predict ke-17104. Label : sadness. Score : 0.93424
# Predict ke-17105. Label : joy. Score : 0.82698
# Predict ke-17106. Label : fear. Score : 0.93626
# Predict ke-17107. Label : joy. Score : 0.50336
# Predict ke-17108. Label : anger. Score : 0.61755
# Predict ke-17109. Label : neutral. Score : 0.69553
# Predict ke-17110. Label : fear. Score : 0.86096
# Predict ke-17111. Label : sadness. Score : 0.55865
# Predict ke-17112. Label : anger. Score : 0.67667
# Predict ke-17113. Label : sadness. Score : 0.98422
# Predict ke-17114. Label : neutral. Score : 0.35141
# Predict ke-17115. Label : sadness. Score : 0.95925
# Predict ke-17116. Label : joy. Score : 0.9616
# Predict ke-17117. Label : sadness. Score : 0.97023
# Predict ke-17118. Label : anger. Score : 0.60135
# Predict ke-17119. Label : surprise. Score : 0.57495
# Predict ke-17120. Label : fear. Score : 0.94359
# Predict ke-17121. Label : anger. Score : 0.97843
# Predict ke-17122. Label : sadness. Score : 0.91509
# Predict ke-17123. Label : sadness. Score : 0.43813
# Predict ke-17124. Label : sadness. Score : 0.41395
# Predict ke-17125. Label : fear. Score : 0.96869
# Predict ke-17126. Label : sadness. Score : 0.9534
# Predict ke-17127. Label : joy. Score : 0.90026
# Predict ke-17128. Label : joy. Score : 0.36419
# Predict ke-17129. Label : fear. Score : 0.58277
# Predict ke-17130. Label : joy. Score : 0.77799
# Predict ke-17131. Label : sadness. Score : 0.39767
# Predict ke-17132. Label : fear. Score : 0.91153
# Predict ke-17133. Label : anger. Score : 0.7595
# Predict ke-17134. Label : fear. Score : 0.98328
# Predict ke-17135. Label : joy. Score : 0.52676
# Predict ke-17136. Label : fear. Score : 0.52772
# Predict ke-17137. Label : fear. Score : 0.7554
# Predict ke-17138. Label : sadness. Score : 0.39033
# Predict ke-17139. Label : fear. Score : 0.9782
# Predict ke-17140. Label : anger. Score : 0.71945
# Predict ke-17141. Label : joy. Score : 0.4015
# Predict ke-17142. Label : anger. Score : 0.98142
# Predict ke-17143. Label : fear. Score : 0.92045
# Predict ke-17144. Label : sadness. Score : 0.36208
# Predict ke-17145. Label : joy. Score : 0.78825
# Predict ke-17146. Label : sadness. Score : 0.97221
# Predict ke-17147. Label : sadness. Score : 0.54614
# Predict ke-17148. Label : neutral. Score : 0.30659
# Predict ke-17149. Label : joy. Score : 0.54263
# Predict ke-17150. Label : sadness. Score : 0.68444
# Predict ke-17151. Label : sadness. Score : 0.62577
# Predict ke-17152. Label : fear. Score : 0.30833
# Predict ke-17153. Label : sadness. Score : 0.9608
# Predict ke-17154. Label : sadness. Score : 0.9734
# Predict ke-17155. Label : sadness. Score : 0.74536
# Predict ke-17156. Label : joy. Score : 0.98286
# Predict ke-17157. Label : sadness. Score : 0.56812
# Predict ke-17158. Label : fear. Score : 0.93508
# Predict ke-17159. Label : anger. Score : 0.64573
# Predict ke-17160. Label : fear. Score : 0.93918
# Predict ke-17161. Label : sadness. Score : 0.61222
# Predict ke-17162. Label : sadness. Score : 0.98109
# Predict ke-17163. Label : fear. Score : 0.57189
# Predict ke-17164. Label : joy. Score : 0.93405
# Predict ke-17165. Label : joy. Score : 0.98679
# Predict ke-17166. Label : sadness. Score : 0.99098
# Predict ke-17167. Label : anger. Score : 0.57552
# Predict ke-17168. Label : fear. Score : 0.90375
# Predict ke-17169. Label : fear. Score : 0.61775
# Predict ke-17170. Label : sadness. Score : 0.9649
# Predict ke-17171. Label : fear. Score : 0.42028
# Predict ke-17172. Label : joy. Score : 0.38499
# Predict ke-17173. Label : fear. Score : 0.94179
# Predict ke-17174. Label : sadness. Score : 0.68695
# Predict ke-17175. Label : fear. Score : 0.9309
# Predict ke-17176. Label : anger. Score : 0.85443
# Predict ke-17177. Label : sadness. Score : 0.65294
# Predict ke-17178. Label : joy. Score : 0.99305
# Predict ke-17179. Label : anger. Score : 0.50379
# Predict ke-17180. Label : anger. Score : 0.79874
# Predict ke-17181. Label : anger. Score : 0.61434
# Predict ke-17182. Label : sadness. Score : 0.46275
# Predict ke-17183. Label : sadness. Score : 0.92765
# Predict ke-17184. Label : fear. Score : 0.98219
# Predict ke-17185. Label : sadness. Score : 0.96081
# Predict ke-17186. Label : sadness. Score : 0.86308
# Predict ke-17187. Label : fear. Score : 0.47355
# Predict ke-17188. Label : sadness. Score : 0.29698
# Predict ke-17189. Label : joy. Score : 0.74519
# Predict ke-17190. Label : sadness. Score : 0.82537
# Predict ke-17191. Label : fear. Score : 0.66894
# Predict ke-17192. Label : joy. Score : 0.96127
# Predict ke-17193. Label : sadness. Score : 0.95774
# Predict ke-17194. Label : sadness. Score : 0.79689
# Predict ke-17195. Label : sadness. Score : 0.35065
# Predict ke-17196. Label : anger. Score : 0.44673
# Predict ke-17197. Label : joy. Score : 0.42812
# Predict ke-17198. Label : surprise. Score : 0.39582
# Predict ke-17199. Label : sadness. Score : 0.66156
# Predict ke-17200. Label : anger. Score : 0.90954
# Predict ke-17201. Label : fear. Score : 0.48812
# Predict ke-17202. Label : joy. Score : 0.54088
# Predict ke-17203. Label : sadness. Score : 0.51777
# Predict ke-17204. Label : sadness. Score : 0.95067
# Predict ke-17205. Label : anger. Score : 0.60763
# Predict ke-17206. Label : joy. Score : 0.89568
# Predict ke-17207. Label : joy. Score : 0.95266
# Predict ke-17208. Label : sadness. Score : 0.98848
# Predict ke-17209. Label : joy. Score : 0.92227
# Predict ke-17210. Label : fear. Score : 0.69664
# Predict ke-17211. Label : fear. Score : 0.97742
# Predict ke-17212. Label : sadness. Score : 0.86899
# Predict ke-17213. Label : sadness. Score : 0.9762
# Predict ke-17214. Label : neutral. Score : 0.88824
# Predict ke-17215. Label : sadness. Score : 0.98361
# Predict ke-17216. Label : fear. Score : 0.96835
# Predict ke-17217. Label : anger. Score : 0.54905
# Predict ke-17218. Label : sadness. Score : 0.40722
# Predict ke-17219. Label : fear. Score : 0.97878
# Predict ke-17220. Label : sadness. Score : 0.98495
# Predict ke-17221. Label : joy. Score : 0.86877
# Predict ke-17222. Label : neutral. Score : 0.51008
# Predict ke-17223. Label : anger. Score : 0.92652
# Predict ke-17224. Label : sadness. Score : 0.98808
# Predict ke-17225. Label : sadness. Score : 0.77923
# Predict ke-17226. Label : fear. Score : 0.60516
# Predict ke-17227. Label : fear. Score : 0.71369
# Predict ke-17228. Label : sadness. Score : 0.96767
# Predict ke-17229. Label : sadness. Score : 0.976
# Predict ke-17230. Label : sadness. Score : 0.98351
# Predict ke-17231. Label : surprise. Score : 0.76045
# Predict ke-17232. Label : anger. Score : 0.82379
# Predict ke-17233. Label : sadness. Score : 0.71727
# Predict ke-17234. Label : joy. Score : 0.96843
# Predict ke-17235. Label : fear. Score : 0.42818
# Predict ke-17236. Label : sadness. Score : 0.9528
# Predict ke-17237. Label : fear. Score : 0.64831
# Predict ke-17238. Label : neutral. Score : 0.65071
# Predict ke-17239. Label : sadness. Score : 0.98764
# Predict ke-17240. Label : anger. Score : 0.6473
# Predict ke-17241. Label : sadness. Score : 0.98265
# Predict ke-17242. Label : sadness. Score : 0.57068
# Predict ke-17243. Label : fear. Score : 0.98657
# Predict ke-17244. Label : neutral. Score : 0.42786
# Predict ke-17245. Label : anger. Score : 0.83257
# Predict ke-17246. Label : anger. Score : 0.57064
# Predict ke-17247. Label : fear. Score : 0.99046
# Predict ke-17248. Label : sadness. Score : 0.94723
# Predict ke-17249. Label : joy. Score : 0.45636
# Predict ke-17250. Label : fear. Score : 0.9426
# Predict ke-17251. Label : sadness. Score : 0.96573
# Predict ke-17252. Label : joy. Score : 0.84837
# Predict ke-17253. Label : anger. Score : 0.96223
# Predict ke-17254. Label : joy. Score : 0.8935
# Predict ke-17255. Label : fear. Score : 0.44433
# Predict ke-17256. Label : anger. Score : 0.90073
# Predict ke-17257. Label : anger. Score : 0.29141
# Predict ke-17258. Label : fear. Score : 0.72451
# Predict ke-17259. Label : joy. Score : 0.77881
# Predict ke-17260. Label : fear. Score : 0.50602
# Predict ke-17261. Label : fear. Score : 0.99218
# Predict ke-17262. Label : joy. Score : 0.86759
# Predict ke-17263. Label : surprise. Score : 0.38553
# Predict ke-17264. Label : neutral. Score : 0.55517
# Predict ke-17265. Label : sadness. Score : 0.98965
# Predict ke-17266. Label : sadness. Score : 0.78669
# Predict ke-17267. Label : sadness. Score : 0.77187
# Predict ke-17268. Label : sadness. Score : 0.96121
# Predict ke-17269. Label : joy. Score : 0.60309
# Predict ke-17270. Label : sadness. Score : 0.80702
# Predict ke-17271. Label : joy. Score : 0.81752
# Predict ke-17272. Label : anger. Score : 0.92818
# Predict ke-17273. Label : sadness. Score : 0.96387
# Predict ke-17274. Label : neutral. Score : 0.46406
# Predict ke-17275. Label : fear. Score : 0.80555
# Predict ke-17276. Label : fear. Score : 0.99266
# Predict ke-17277. Label : anger. Score : 0.78154
# Predict ke-17278. Label : joy. Score : 0.48702
# Predict ke-17279. Label : anger. Score : 0.86048
# Predict ke-17280. Label : sadness. Score : 0.83671
# Predict ke-17281. Label : sadness. Score : 0.98204
# Predict ke-17282. Label : joy. Score : 0.66032
# Predict ke-17283. Label : joy. Score : 0.97711
# Predict ke-17284. Label : joy. Score : 0.89899
# Predict ke-17285. Label : sadness. Score : 0.96496
# Predict ke-17286. Label : sadness. Score : 0.77493
# Predict ke-17287. Label : sadness. Score : 0.98975
# Predict ke-17288. Label : sadness. Score : 0.93552
# Predict ke-17289. Label : sadness. Score : 0.76866
# Predict ke-17290. Label : fear. Score : 0.62701
# Predict ke-17291. Label : sadness. Score : 0.98372
# Predict ke-17292. Label : fear. Score : 0.91628
# Predict ke-17293. Label : joy. Score : 0.95879
# Predict ke-17294. Label : sadness. Score : 0.57894
# Predict ke-17295. Label : sadness. Score : 0.96682
# Predict ke-17296. Label : sadness. Score : 0.9832
# Predict ke-17297. Label : anger. Score : 0.38121
# Predict ke-17298. Label : anger. Score : 0.98419
# Predict ke-17299. Label : joy. Score : 0.92524
# Predict ke-17300. Label : surprise. Score : 0.47005
# Predict ke-17301. Label : sadness. Score : 0.95332
# Predict ke-17302. Label : sadness. Score : 0.98965
# Predict ke-17303. Label : fear. Score : 0.6777
# Predict ke-17304. Label : joy. Score : 0.9213
# Predict ke-17305. Label : anger. Score : 0.90487
# Predict ke-17306. Label : sadness. Score : 0.79441
# Predict ke-17307. Label : anger. Score : 0.90639
# Predict ke-17308. Label : sadness. Score : 0.7363
# Predict ke-17309. Label : surprise. Score : 0.50476
# Predict ke-17310. Label : joy. Score : 0.79357
# Predict ke-17311. Label : sadness. Score : 0.48827
# Predict ke-17312. Label : joy. Score : 0.5277
# Predict ke-17313. Label : sadness. Score : 0.79687
# Predict ke-17314. Label : joy. Score : 0.90489
# Predict ke-17315. Label : sadness. Score : 0.95659
# Predict ke-17316. Label : fear. Score : 0.51514
# Predict ke-17317. Label : joy. Score : 0.67317
# Predict ke-17318. Label : fear. Score : 0.96751
# Predict ke-17319. Label : sadness. Score : 0.96047
# Predict ke-17320. Label : joy. Score : 0.96173
# Predict ke-17321. Label : joy. Score : 0.87138
# Predict ke-17322. Label : fear. Score : 0.99296
# Predict ke-17323. Label : disgust. Score : 0.85419
# Predict ke-17324. Label : anger. Score : 0.96815
# Predict ke-17325. Label : sadness. Score : 0.42761
# Predict ke-17326. Label : sadness. Score : 0.98181
# Predict ke-17327. Label : neutral. Score : 0.66866
# Predict ke-17328. Label : anger. Score : 0.65701
# Predict ke-17329. Label : fear. Score : 0.93009
# Predict ke-17330. Label : fear. Score : 0.8389
# Predict ke-17331. Label : sadness. Score : 0.82784
# Predict ke-17332. Label : sadness. Score : 0.96315
# Predict ke-17333. Label : fear. Score : 0.95854
# Predict ke-17334. Label : sadness. Score : 0.91259
# Predict ke-17335. Label : sadness. Score : 0.6446
# Predict ke-17336. Label : fear. Score : 0.96664
# Predict ke-17337. Label : sadness. Score : 0.97625
# Predict ke-17338. Label : sadness. Score : 0.69187
# Predict ke-17339. Label : joy. Score : 0.39945
# Predict ke-17340. Label : fear. Score : 0.87594
# Predict ke-17341. Label : joy. Score : 0.50528
# Predict ke-17342. Label : joy. Score : 0.94987
# Predict ke-17343. Label : joy. Score : 0.86629
# Predict ke-17344. Label : fear. Score : 0.72135
# Predict ke-17345. Label : fear. Score : 0.9851
# Predict ke-17346. Label : anger. Score : 0.38074
# Predict ke-17347. Label : sadness. Score : 0.97478
# Predict ke-17348. Label : sadness. Score : 0.32983
# Predict ke-17349. Label : sadness. Score : 0.54539
# Predict ke-17350. Label : neutral. Score : 0.32023
# Predict ke-17351. Label : sadness. Score : 0.8413
# Predict ke-17352. Label : sadness. Score : 0.54366
# Predict ke-17353. Label : sadness. Score : 0.56973
# Predict ke-17354. Label : anger. Score : 0.92583
# Predict ke-17355. Label : sadness. Score : 0.87576
# Predict ke-17356. Label : sadness. Score : 0.98886
# Predict ke-17357. Label : sadness. Score : 0.66514
# Predict ke-17358. Label : sadness. Score : 0.52047
# Predict ke-17359. Label : anger. Score : 0.4735
# Predict ke-17360. Label : anger. Score : 0.9449
# Predict ke-17361. Label : fear. Score : 0.89567
# Predict ke-17362. Label : fear. Score : 0.96453
# Predict ke-17363. Label : sadness. Score : 0.81089
# Predict ke-17364. Label : sadness. Score : 0.9058
# Predict ke-17365. Label : sadness. Score : 0.97671
# Predict ke-17366. Label : sadness. Score : 0.98945
# Predict ke-17367. Label : joy. Score : 0.80775
# Predict ke-17368. Label : joy. Score : 0.98239
# Predict ke-17369. Label : fear. Score : 0.85797
# Predict ke-17370. Label : joy. Score : 0.89088
# Predict ke-17371. Label : anger. Score : 0.95205
# Predict ke-17372. Label : sadness. Score : 0.97016
# Predict ke-17373. Label : sadness. Score : 0.84126
# Predict ke-17374. Label : joy. Score : 0.47463
# Predict ke-17375. Label : joy. Score : 0.61147
# Predict ke-17376. Label : sadness. Score : 0.88988
# Predict ke-17377. Label : joy. Score : 0.41672
# Predict ke-17378. Label : anger. Score : 0.57951
# Predict ke-17379. Label : fear. Score : 0.70983
# Predict ke-17380. Label : anger. Score : 0.41737
# Predict ke-17381. Label : fear. Score : 0.86062
# Predict ke-17382. Label : joy. Score : 0.95276
# Predict ke-17383. Label : fear. Score : 0.94466
# Predict ke-17384. Label : sadness. Score : 0.95976
# Predict ke-17385. Label : fear. Score : 0.87763
# Predict ke-17386. Label : sadness. Score : 0.94005
# Predict ke-17387. Label : sadness. Score : 0.97191
# Predict ke-17388. Label : fear. Score : 0.83253
# Predict ke-17389. Label : joy. Score : 0.88744
# Predict ke-17390. Label : anger. Score : 0.91385
# Predict ke-17391. Label : fear. Score : 0.69039
# Predict ke-17392. Label : fear. Score : 0.70241
# Predict ke-17393. Label : anger. Score : 0.81312
# Predict ke-17394. Label : sadness. Score : 0.46813
# Predict ke-17395. Label : sadness. Score : 0.73897
# Predict ke-17396. Label : fear. Score : 0.95962
# Predict ke-17397. Label : sadness. Score : 0.9707
# Predict ke-17398. Label : sadness. Score : 0.60942
# Predict ke-17399. Label : joy. Score : 0.93557
# Predict ke-17400. Label : fear. Score : 0.91321
# Predict ke-17401. Label : joy. Score : 0.97372
# Predict ke-17402. Label : neutral. Score : 0.77933
# Predict ke-17403. Label : joy. Score : 0.95933
# Predict ke-17404. Label : fear. Score : 0.85451
# Predict ke-17405. Label : fear. Score : 0.90263
# Predict ke-17406. Label : sadness. Score : 0.96997
# Predict ke-17407. Label : sadness. Score : 0.97296
# Predict ke-17408. Label : sadness. Score : 0.84136
# Predict ke-17409. Label : sadness. Score : 0.96555
# Predict ke-17410. Label : sadness. Score : 0.51668
# Predict ke-17411. Label : sadness. Score : 0.35653
# Merging

# %% [markdown]
# # Labelling Using HuggingFace Model Bhadresh-Savani Distilbert-base

# %%
emotion_classifier = pipeline("text-classification", model="bhadresh-savani/distilbert-base-uncased-emotion")
tokenizer = AutoTokenizer.from_pretrained("bhadresh-savani/distilbert-base-uncased-emotion")
# Out:
# config.json:   0%|          | 0.00/768 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# I0000 00:00:1740012489.139793    2040 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# tokenizer_config.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use 0

# %%
def predictSentimentMergeSavani(df, cleanDf):
    labels = []
    scores = []
    for idx, poem in enumerate(cleanDf.values):
        tokens = tokenizer(poem[0], max_length=512, truncation=True, return_tensors="tf")
        result = emotion_classifier(tokenizer.decode(tokens['input_ids'][0], truncation=True))[0]
        print(f"Predict ke-{idx}. Label : {result['label']}. Score : {round(result['score'], 5)}")
        scores.append(round(result['score'], 5))
        labels.append(result['label'])

    print("Merging")
    pd.concat([df, pd.DataFrame({'label':labels, 'score':scores})], axis=1).to_csv("./dataset/labelled_poem_savani.csv", index=False)

# %%
final = predictSentimentMergeSavani(df, cleanDf)
# Out:
# Predict ke-0. Label : joy. Score : 0.95379
# Predict ke-1. Label : sadness. Score : 0.68797
# Predict ke-2. Label : joy. Score : 0.44294
# Predict ke-3. Label : love. Score : 0.65365
# Predict ke-4. Label : fear. Score : 0.78596
# Predict ke-5. Label : love. Score : 0.43306
# Predict ke-6. Label : joy. Score : 0.76008
# Predict ke-7. Label : fear. Score : 0.99217
# Predict ke-8. Label : love. Score : 0.92609
# Predict ke-9. Label : anger. Score : 0.87743
# Predict ke-10. Label : joy. Score : 0.46513
# Predict ke-11. Label : sadness. Score : 0.99594
# Predict ke-12. Label : sadness. Score : 0.55402
# Predict ke-13. Label : joy. Score : 0.95946
# Predict ke-14. Label : sadness. Score : 0.73611
# Predict ke-15. Label : fear. Score : 0.50621
# Predict ke-16. Label : sadness. Score : 0.9784
# Predict ke-17. Label : sadness. Score : 0.98938
# Predict ke-18. Label : sadness. Score : 0.9985
# Predict ke-19. Label : sadness. Score : 0.99349
# Predict ke-20. Label : sadness. Score : 0.51373
# Predict ke-21. Label : joy. Score : 0.48168
# Predict ke-22. Label : fear. Score : 0.97175
# Predict ke-23. Label : joy. Score : 0.55763
# Predict ke-24. Label : sadness. Score : 0.58798
# Predict ke-25. Label : anger. Score : 0.9901
# Token indices sequence length is longer than the specified maximum sequence length for this model (514 > 512). Running this sequence through the model will result in indexing errors
# Predict ke-26. Label : love. Score : 0.78738
# Predict ke-27. Label : joy. Score : 0.94901
# Predict ke-28. Label : joy. Score : 0.41169
# Predict ke-29. Label : anger. Score : 0.72846
# Predict ke-30. Label : sadness. Score : 0.85425
# Predict ke-31. Label : fear. Score : 0.53317
# Predict ke-32. Label : anger. Score : 0.65419
# Predict ke-33. Label : anger. Score : 0.37558
# Predict ke-34. Label : joy. Score : 0.84776
# Predict ke-35. Label : sadness. Score : 0.43464
# Predict ke-36. Label : anger. Score : 0.77608
# Predict ke-37. Label : joy. Score : 0.9458
# Predict ke-38. Label : anger. Score : 0.82863
# Predict ke-39. Label : anger. Score : 0.61781
# Predict ke-40. Label : sadness. Score : 0.62551
# Predict ke-41. Label : fear. Score : 0.56249
# Predict ke-42. Label : joy. Score : 0.41387
# Predict ke-43. Label : joy. Score : 0.82728
# Predict ke-44. Label : joy. Score : 0.97224
# Predict ke-45. Label : sadness. Score : 0.95176
# Predict ke-46. Label : sadness. Score : 0.90746
# Predict ke-47. Label : joy. Score : 0.68119
# Predict ke-48. Label : sadness. Score : 0.40572
# Predict ke-49. Label : fear. Score : 0.35048
# Predict ke-50. Label : sadness. Score : 0.99675
# Predict ke-51. Label : joy. Score : 0.94829
# Predict ke-52. Label : sadness. Score : 0.85184
# Predict ke-53. Label : love. Score : 0.94246
# Predict ke-54. Label : sadness. Score : 0.85137
# Predict ke-55. Label : joy. Score : 0.97576
# Predict ke-56. Label : sadness. Score : 0.99783
# Predict ke-57. Label : joy. Score : 0.70076
# Predict ke-58. Label : joy. Score : 0.98945
# Predict ke-59. Label : love. Score : 0.47903
# Predict ke-60. Label : joy. Score : 0.58264
# Predict ke-61. Label : anger. Score : 0.9852
# Predict ke-62. Label : love. Score : 0.97293
# Predict ke-63. Label : joy. Score : 0.9945
# Predict ke-64. Label : anger. Score : 0.5013
# Predict ke-65. Label : fear. Score : 0.96518
# Predict ke-66. Label : sadness. Score : 0.95239
# Predict ke-67. Label : joy. Score : 0.99391
# Predict ke-68. Label : sadness. Score : 0.61081
# Predict ke-69. Label : love. Score : 0.71657
# Predict ke-70. Label : joy. Score : 0.96696
# Predict ke-71. Label : sadness. Score : 0.67074
# Predict ke-72. Label : joy. Score : 0.55644
# Predict ke-73. Label : anger. Score : 0.43882
# Predict ke-74. Label : anger. Score : 0.92245
# Predict ke-75. Label : sadness. Score : 0.58769
# Predict ke-76. Label : sadness. Score : 0.92301
# Predict ke-77. Label : anger. Score : 0.84686
# Predict ke-78. Label : sadness. Score : 0.91946
# Predict ke-79. Label : anger. Score : 0.52336
# Predict ke-80. Label : sadness. Score : 0.90025
# Predict ke-81. Label : sadness. Score : 0.91781
# Predict ke-82. Label : joy. Score : 0.98868
# Predict ke-83. Label : sadness. Score : 0.52982
# Predict ke-84. Label : joy. Score : 0.90288
# Predict ke-85. Label : sadness. Score : 0.99797
# Predict ke-86. Label : love. Score : 0.98655
# Predict ke-87. Label : love. Score : 0.83856
# Predict ke-88. Label : joy. Score : 0.60362
# Predict ke-89. Label : joy. Score : 0.99248
# Predict ke-90. Label : sadness. Score : 0.92079
# Predict ke-91. Label : joy. Score : 0.90627
# Predict ke-92. Label : love. Score : 0.96821
# Predict ke-93. Label : joy. Score : 0.98965
# Predict ke-94. Label : joy. Score : 0.95232
# Predict ke-95. Label : anger. Score : 0.98601
# Predict ke-96. Label : sadness. Score : 0.67069
# Predict ke-97. Label : anger. Score : 0.98851
# Predict ke-98. Label : joy. Score : 0.88292
# Predict ke-99. Label : anger. Score : 0.98228
# Predict ke-100. Label : joy. Score : 0.54868
# Predict ke-101. Label : joy. Score : 0.50674
# Predict ke-102. Label : sadness. Score : 0.69917
# Predict ke-103. Label : love. Score : 0.76215
# Predict ke-104. Label : sadness. Score : 0.93773
# Predict ke-105. Label : sadness. Score : 0.87987
# Predict ke-106. Label : anger. Score : 0.67727
# Predict ke-107. Label : joy. Score : 0.98469
# Predict ke-108. Label : sadness. Score : 0.83247
# Predict ke-109. Label : joy. Score : 0.94394
# Predict ke-110. Label : joy. Score : 0.97991
# Predict ke-111. Label : anger. Score : 0.99263
# Predict ke-112. Label : anger. Score : 0.4102
# Predict ke-113. Label : fear. Score : 0.8362
# Predict ke-114. Label : sadness. Score : 0.47029
# Predict ke-115. Label : fear. Score : 0.59755
# Predict ke-116. Label : anger. Score : 0.78757
# Predict ke-117. Label : sadness. Score : 0.61411
# Predict ke-118. Label : fear. Score : 0.95964
# Predict ke-119. Label : fear. Score : 0.84982
# Predict ke-120. Label : anger. Score : 0.93431
# Predict ke-121. Label : anger. Score : 0.78789
# Predict ke-122. Label : joy. Score : 0.88098
# Predict ke-123. Label : joy. Score : 0.58855
# Predict ke-124. Label : fear. Score : 0.54894
# Predict ke-125. Label : love. Score : 0.67315
# Predict ke-126. Label : joy. Score : 0.83524
# Predict ke-127. Label : anger. Score : 0.97829
# Predict ke-128. Label : anger. Score : 0.64806
# Predict ke-129. Label : joy. Score : 0.72185
# Predict ke-130. Label : joy. Score : 0.99118
# Predict ke-131. Label : anger. Score : 0.78021
# Predict ke-132. Label : sadness. Score : 0.93467
# Predict ke-133. Label : joy. Score : 0.97007
# Predict ke-134. Label : fear. Score : 0.49351
# Predict ke-135. Label : fear. Score : 0.82765
# Predict ke-136. Label : sadness. Score : 0.48709
# Predict ke-137. Label : anger. Score : 0.84929
# Predict ke-138. Label : joy. Score : 0.89325
# Predict ke-139. Label : joy. Score : 0.751
# Predict ke-140. Label : fear. Score : 0.97953
# Predict ke-141. Label : fear. Score : 0.93097
# Predict ke-142. Label : sadness. Score : 0.49151
# Predict ke-143. Label : joy. Score : 0.95964
# Predict ke-144. Label : joy. Score : 0.99753
# Predict ke-145. Label : anger. Score : 0.83545
# Predict ke-146. Label : joy. Score : 0.88118
# Predict ke-147. Label : sadness. Score : 0.99297
# Predict ke-148. Label : joy. Score : 0.9725
# Predict ke-149. Label : sadness. Score : 0.46485
# Predict ke-150. Label : anger. Score : 0.53406
# Predict ke-151. Label : love. Score : 0.90086
# Predict ke-152. Label : joy. Score : 0.47778
# Predict ke-153. Label : joy. Score : 0.97136
# Predict ke-154. Label : anger. Score : 0.89415
# Predict ke-155. Label : fear. Score : 0.41872
# Predict ke-156. Label : anger. Score : 0.64831
# Predict ke-157. Label : joy. Score : 0.99354
# Predict ke-158. Label : love. Score : 0.9953
# Predict ke-159. Label : anger. Score : 0.89768
# Predict ke-160. Label : joy. Score : 0.99625
# Predict ke-161. Label : joy. Score : 0.6307
# Predict ke-162. Label : joy. Score : 0.56809
# Predict ke-163. Label : joy. Score : 0.99865
# Predict ke-164. Label : joy. Score : 0.52335
# Predict ke-165. Label : fear. Score : 0.95097
# Predict ke-166. Label : joy. Score : 0.89905
# Predict ke-167. Label : anger. Score : 0.53124
# Predict ke-168. Label : joy. Score : 0.80553
# Predict ke-169. Label : sadness. Score : 0.72243
# Predict ke-170. Label : sadness. Score : 0.8887
# Predict ke-171. Label : joy. Score : 0.97865
# Predict ke-172. Label : joy. Score : 0.95466
# Predict ke-173. Label : joy. Score : 0.99535
# Predict ke-174. Label : fear. Score : 0.67772
# Predict ke-175. Label : joy. Score : 0.96343
# Predict ke-176. Label : love. Score : 0.68398
# Predict ke-177. Label : sadness. Score : 0.37636
# Predict ke-178. Label : sadness. Score : 0.57504
# Predict ke-179. Label : anger. Score : 0.44859
# Predict ke-180. Label : anger. Score : 0.9906
# Predict ke-181. Label : joy. Score : 0.93067
# Predict ke-182. Label : sadness. Score : 0.94186
# Predict ke-183. Label : joy. Score : 0.68528
# Predict ke-184. Label : anger. Score : 0.45865
# Predict ke-185. Label : joy. Score : 0.84673
# Predict ke-186. Label : sadness. Score : 0.99402
# Predict ke-187. Label : joy. Score : 0.93248
# Predict ke-188. Label : joy. Score : 0.49328
# Predict ke-189. Label : sadness. Score : 0.9977
# Predict ke-190. Label : sadness. Score : 0.96274
# Predict ke-191. Label : joy. Score : 0.85755
# Predict ke-192. Label : fear. Score : 0.70552
# Predict ke-193. Label : sadness. Score : 0.46817
# Predict ke-194. Label : sadness. Score : 0.81203
# Predict ke-195. Label : joy. Score : 0.8561
# Predict ke-196. Label : anger. Score : 0.98825
# Predict ke-197. Label : joy. Score : 0.78952
# Predict ke-198. Label : sadness. Score : 0.67186
# Predict ke-199. Label : anger. Score : 0.37939
# Predict ke-200. Label : anger. Score : 0.8979
# Predict ke-201. Label : anger. Score : 0.85651
# Predict ke-202. Label : sadness. Score : 0.77754
# Predict ke-203. Label : anger. Score : 0.67561
# Predict ke-204. Label : joy. Score : 0.86387
# Predict ke-205. Label : sadness. Score : 0.81555
# Predict ke-206. Label : sadness. Score : 0.95901
# Predict ke-207. Label : joy. Score : 0.73617
# Predict ke-208. Label : anger. Score : 0.49699
# Predict ke-209. Label : anger. Score : 0.33563
# Predict ke-210. Label : love. Score : 0.99118
# Predict ke-211. Label : anger. Score : 0.43819
# Predict ke-212. Label : sadness. Score : 0.99019
# Predict ke-213. Label : anger. Score : 0.99737
# Predict ke-214. Label : anger. Score : 0.33254
# Predict ke-215. Label : love. Score : 0.71296
# Predict ke-216. Label : joy. Score : 0.61444
# Predict ke-217. Label : sadness. Score : 0.75003
# Predict ke-218. Label : sadness. Score : 0.98953
# Predict ke-219. Label : joy. Score : 0.3918
# Predict ke-220. Label : joy. Score : 0.45969
# Predict ke-221. Label : sadness. Score : 0.95417
# Predict ke-222. Label : sadness. Score : 0.40227
# Predict ke-223. Label : sadness. Score : 0.97152
# Predict ke-224. Label : joy. Score : 0.98592
# Predict ke-225. Label : anger. Score : 0.47118
# Predict ke-226. Label : joy. Score : 0.54206
# Predict ke-227. Label : joy. Score : 0.9395
# Predict ke-228. Label : anger. Score : 0.6309
# Predict ke-229. Label : joy. Score : 0.52241
# Predict ke-230. Label : fear. Score : 0.80758
# Predict ke-231. Label : sadness. Score : 0.98649
# Predict ke-232. Label : sadness. Score : 0.54443
# Predict ke-233. Label : joy. Score : 0.87567
# Predict ke-234. Label : sadness. Score : 0.99528
# Predict ke-235. Label : fear. Score : 0.96801
# Predict ke-236. Label : sadness. Score : 0.89936
# Predict ke-237. Label : joy. Score : 0.76454
# Predict ke-238. Label : anger. Score : 0.73066
# Predict ke-239. Label : joy. Score : 0.60493
# Predict ke-240. Label : joy. Score : 0.38735
# Predict ke-241. Label : sadness. Score : 0.46463
# Predict ke-242. Label : anger. Score : 0.30623
# Predict ke-243. Label : fear. Score : 0.99537
# Predict ke-244. Label : joy. Score : 0.6368
# Predict ke-245. Label : joy. Score : 0.99768
# Predict ke-246. Label : anger. Score : 0.43031
# Predict ke-247. Label : joy. Score : 0.85211
# Predict ke-248. Label : love. Score : 0.9907
# Predict ke-249. Label : fear. Score : 0.60323
# Predict ke-250. Label : anger. Score : 0.31319
# Predict ke-251. Label : anger. Score : 0.49209
# Predict ke-252. Label : anger. Score : 0.8288
# Predict ke-253. Label : anger. Score : 0.94647
# Predict ke-254. Label : joy. Score : 0.981
# Predict ke-255. Label : joy. Score : 0.99729
# Predict ke-256. Label : anger. Score : 0.61719
# Predict ke-257. Label : joy. Score : 0.63357
# Predict ke-258. Label : love. Score : 0.97649
# Predict ke-259. Label : sadness. Score : 0.65982
# Predict ke-260. Label : anger. Score : 0.44708
# Predict ke-261. Label : joy. Score : 0.98851
# Predict ke-262. Label : sadness. Score : 0.87341
# Predict ke-263. Label : joy. Score : 0.96829
# Predict ke-264. Label : love. Score : 0.57689
# Predict ke-265. Label : anger. Score : 0.87419
# Predict ke-266. Label : sadness. Score : 0.92067
# Predict ke-267. Label : sadness. Score : 0.40432
# Predict ke-268. Label : anger. Score : 0.9713
# Predict ke-269. Label : sadness. Score : 0.99328
# Predict ke-270. Label : joy. Score : 0.51723
# Predict ke-271. Label : joy. Score : 0.67334
# Predict ke-272. Label : joy. Score : 0.96483
# Predict ke-273. Label : joy. Score : 0.50537
# Predict ke-274. Label : sadness. Score : 0.95403
# Predict ke-275. Label : anger. Score : 0.30254
# Predict ke-276. Label : joy. Score : 0.46899
# Predict ke-277. Label : love. Score : 0.96959
# Predict ke-278. Label : sadness. Score : 0.99485
# Predict ke-279. Label : anger. Score : 0.83856
# Predict ke-280. Label : anger. Score : 0.54146
# Predict ke-281. Label : joy. Score : 0.52359
# Predict ke-282. Label : sadness. Score : 0.77635
# Predict ke-283. Label : anger. Score : 0.97216
# Predict ke-284. Label : love. Score : 0.97472
# Predict ke-285. Label : love. Score : 0.8976
# Predict ke-286. Label : joy. Score : 0.65067
# Predict ke-287. Label : sadness. Score : 0.9874
# Predict ke-288. Label : anger. Score : 0.91719
# Predict ke-289. Label : sadness. Score : 0.48242
# Predict ke-290. Label : sadness. Score : 0.97587
# Predict ke-291. Label : fear. Score : 0.86635
# Predict ke-292. Label : anger. Score : 0.63083
# Predict ke-293. Label : anger. Score : 0.43884
# Predict ke-294. Label : fear. Score : 0.99364
# Predict ke-295. Label : anger. Score : 0.40404
# Predict ke-296. Label : sadness. Score : 0.64049
# Predict ke-297. Label : anger. Score : 0.74737
# Predict ke-298. Label : anger. Score : 0.64178
# Predict ke-299. Label : joy. Score : 0.72913
# Predict ke-300. Label : sadness. Score : 0.56557
# Predict ke-301. Label : sadness. Score : 0.57758
# Predict ke-302. Label : love. Score : 0.43695
# Predict ke-303. Label : sadness. Score : 0.42259
# Predict ke-304. Label : joy. Score : 0.64129
# Predict ke-305. Label : anger. Score : 0.56735
# Predict ke-306. Label : joy. Score : 0.46312
# Predict ke-307. Label : love. Score : 0.54081
# Predict ke-308. Label : joy. Score : 0.99509
# Predict ke-309. Label : joy. Score : 0.65576
# Predict ke-310. Label : joy. Score : 0.89436
# Predict ke-311. Label : joy. Score : 0.93839
# Predict ke-312. Label : anger. Score : 0.9953
# Predict ke-313. Label : joy. Score : 0.9609
# Predict ke-314. Label : anger. Score : 0.44325
# Predict ke-315. Label : joy. Score : 0.50448
# Predict ke-316. Label : anger. Score : 0.4052
# Predict ke-317. Label : joy. Score : 0.69497
# Predict ke-318. Label : sadness. Score : 0.96002
# Predict ke-319. Label : sadness. Score : 0.95468
# Predict ke-320. Label : anger. Score : 0.99137
# Predict ke-321. Label : joy. Score : 0.82953
# Predict ke-322. Label : sadness. Score : 0.62235
# Predict ke-323. Label : fear. Score : 0.97524
# Predict ke-324. Label : love. Score : 0.51601
# Predict ke-325. Label : joy. Score : 0.93909
# Predict ke-326. Label : anger. Score : 0.44782
# Predict ke-327. Label : anger. Score : 0.37947
# Predict ke-328. Label : joy. Score : 0.40284
# Predict ke-329. Label : love. Score : 0.85141
# Predict ke-330. Label : sadness. Score : 0.53716
# Predict ke-331. Label : sadness. Score : 0.98823
# Predict ke-332. Label : joy. Score : 0.98949
# Predict ke-333. Label : fear. Score : 0.9827
# Predict ke-334. Label : joy. Score : 0.51518
# Predict ke-335. Label : joy. Score : 0.97017
# Predict ke-336. Label : sadness. Score : 0.82773
# Predict ke-337. Label : joy. Score : 0.58847
# Predict ke-338. Label : joy. Score : 0.31043
# Predict ke-339. Label : sadness. Score : 0.95387
# Predict ke-340. Label : joy. Score : 0.98912
# Predict ke-341. Label : joy. Score : 0.86652
# Predict ke-342. Label : sadness. Score : 0.99837
# Predict ke-343. Label : joy. Score : 0.82493
# Predict ke-344. Label : joy. Score : 0.86075
# Predict ke-345. Label : love. Score : 0.88606
# Predict ke-346. Label : fear. Score : 0.49139
# Predict ke-347. Label : fear. Score : 0.99382
# Predict ke-348. Label : joy. Score : 0.98126
# Predict ke-349. Label : sadness. Score : 0.88064
# Predict ke-350. Label : anger. Score : 0.89659
# Predict ke-351. Label : sadness. Score : 0.99366
# Predict ke-352. Label : joy. Score : 0.95849
# Predict ke-353. Label : joy. Score : 0.82921
# Predict ke-354. Label : sadness. Score : 0.71451
# Predict ke-355. Label : anger. Score : 0.84375
# Predict ke-356. Label : joy. Score : 0.49329
# Predict ke-357. Label : sadness. Score : 0.76426
# Predict ke-358. Label : sadness. Score : 0.95198
# Predict ke-359. Label : anger. Score : 0.86159
# Predict ke-360. Label : sadness. Score : 0.86281
# Predict ke-361. Label : love. Score : 0.92483
# Predict ke-362. Label : joy. Score : 0.90934
# Predict ke-363. Label : anger. Score : 0.53209
# Predict ke-364. Label : love. Score : 0.72142
# Predict ke-365. Label : joy. Score : 0.65382
# Predict ke-366. Label : joy. Score : 0.95437
# Predict ke-367. Label : joy. Score : 0.99544
# Predict ke-368. Label : anger. Score : 0.97672
# Predict ke-369. Label : surprise. Score : 0.72394
# Predict ke-370. Label : love. Score : 0.62666
# Predict ke-371. Label : sadness. Score : 0.99598
# Predict ke-372. Label : joy. Score : 0.63379
# Predict ke-373. Label : sadness. Score : 0.99867
# Predict ke-374. Label : anger. Score : 0.48399
# Predict ke-375. Label : sadness. Score : 0.99219
# Predict ke-376. Label : fear. Score : 0.45032
# Predict ke-377. Label : fear. Score : 0.89696
# Predict ke-378. Label : fear. Score : 0.85452
# Predict ke-379. Label : anger. Score : 0.94301
# Predict ke-380. Label : love. Score : 0.87027
# Predict ke-381. Label : joy. Score : 0.39234
# Predict ke-382. Label : anger. Score : 0.57398
# Predict ke-383. Label : sadness. Score : 0.61855
# Predict ke-384. Label : joy. Score : 0.94344
# Predict ke-385. Label : anger. Score : 0.5059
# Predict ke-386. Label : joy. Score : 0.65995
# Predict ke-387. Label : joy. Score : 0.92824
# Predict ke-388. Label : sadness. Score : 0.30067
# Predict ke-389. Label : anger. Score : 0.91502
# Predict ke-390. Label : joy. Score : 0.95778
# Predict ke-391. Label : sadness. Score : 0.86191
# Predict ke-392. Label : sadness. Score : 0.43322
# Predict ke-393. Label : anger. Score : 0.75554
# Predict ke-394. Label : sadness. Score : 0.98636
# Predict ke-395. Label : sadness. Score : 0.71078
# Predict ke-396. Label : anger. Score : 0.80813
# Predict ke-397. Label : joy. Score : 0.97511
# Predict ke-398. Label : anger. Score : 0.57594
# Predict ke-399. Label : joy. Score : 0.51713
# Predict ke-400. Label : sadness. Score : 0.7158
# Predict ke-401. Label : joy. Score : 0.9545
# Predict ke-402. Label : anger. Score : 0.96613
# Predict ke-403. Label : anger. Score : 0.98961
# Predict ke-404. Label : joy. Score : 0.5381
# Predict ke-405. Label : sadness. Score : 0.97031
# Predict ke-406. Label : sadness. Score : 0.45468
# Predict ke-407. Label : joy. Score : 0.97577
# Predict ke-408. Label : joy. Score : 0.98197
# Predict ke-409. Label : anger. Score : 0.39434
# Predict ke-410. Label : joy. Score : 0.85814
# Predict ke-411. Label : sadness. Score : 0.95473
# Predict ke-412. Label : joy. Score : 0.90691
# Predict ke-413. Label : joy. Score : 0.9738
# Predict ke-414. Label : anger. Score : 0.98976
# Predict ke-415. Label : joy. Score : 0.55327
# Predict ke-416. Label : anger. Score : 0.95042
# Predict ke-417. Label : sadness. Score : 0.61715
# Predict ke-418. Label : joy. Score : 0.56225
# Predict ke-419. Label : anger. Score : 0.4959
# Predict ke-420. Label : joy. Score : 0.91665
# Predict ke-421. Label : joy. Score : 0.79687
# Predict ke-422. Label : sadness. Score : 0.91165
# Predict ke-423. Label : sadness. Score : 0.99226
# Predict ke-424. Label : sadness. Score : 0.90837
# Predict ke-425. Label : joy. Score : 0.99475
# Predict ke-426. Label : love. Score : 0.97441
# Predict ke-427. Label : joy. Score : 0.99699
# Predict ke-428. Label : sadness. Score : 0.41795
# Predict ke-429. Label : fear. Score : 0.64238
# Predict ke-430. Label : joy. Score : 0.95107
# Predict ke-431. Label : anger. Score : 0.50889
# Predict ke-432. Label : sadness. Score : 0.89003
# Predict ke-433. Label : sadness. Score : 0.88356
# Predict ke-434. Label : love. Score : 0.82727
# Predict ke-435. Label : love. Score : 0.61868
# Predict ke-436. Label : anger. Score : 0.33804
# Predict ke-437. Label : fear. Score : 0.77532
# Predict ke-438. Label : sadness. Score : 0.98665
# Predict ke-439. Label : sadness. Score : 0.69684
# Predict ke-440. Label : fear. Score : 0.97612
# Predict ke-441. Label : sadness. Score : 0.37152
# Predict ke-442. Label : sadness. Score : 0.88998
# Predict ke-443. Label : anger. Score : 0.43697
# Predict ke-444. Label : sadness. Score : 0.99639
# Predict ke-445. Label : joy. Score : 0.98623
# Predict ke-446. Label : joy. Score : 0.87752
# Predict ke-447. Label : anger. Score : 0.38088
# Predict ke-448. Label : sadness. Score : 0.96886
# Predict ke-449. Label : sadness. Score : 0.43978
# Predict ke-450. Label : fear. Score : 0.50128
# Predict ke-451. Label : joy. Score : 0.82518
# Predict ke-452. Label : joy. Score : 0.98165
# Predict ke-453. Label : anger. Score : 0.4027
# Predict ke-454. Label : joy. Score : 0.99125
# Predict ke-455. Label : joy. Score : 0.97408
# Predict ke-456. Label : surprise. Score : 0.49216
# Predict ke-457. Label : sadness. Score : 0.99838
# Predict ke-458. Label : joy. Score : 0.77427
# Predict ke-459. Label : joy. Score : 0.9405
# Predict ke-460. Label : joy. Score : 0.33653
# Predict ke-461. Label : sadness. Score : 0.52926
# Predict ke-462. Label : joy. Score : 0.80874
# Predict ke-463. Label : anger. Score : 0.37671
# Predict ke-464. Label : fear. Score : 0.81294
# Predict ke-465. Label : joy. Score : 0.46192
# Predict ke-466. Label : anger. Score : 0.9918
# Predict ke-467. Label : joy. Score : 0.96878
# Predict ke-468. Label : anger. Score : 0.40425
# Predict ke-469. Label : fear. Score : 0.67403
# Predict ke-470. Label : joy. Score : 0.53433
# Predict ke-471. Label : love. Score : 0.44472
# Predict ke-472. Label : anger. Score : 0.94172
# Predict ke-473. Label : joy. Score : 0.95135
# Predict ke-474. Label : sadness. Score : 0.66027
# Predict ke-475. Label : joy. Score : 0.93597
# Predict ke-476. Label : joy. Score : 0.99349
# Predict ke-477. Label : joy. Score : 0.9966
# Predict ke-478. Label : joy. Score : 0.97368
# Predict ke-479. Label : joy. Score : 0.73357
# Predict ke-480. Label : joy. Score : 0.99345
# Predict ke-481. Label : anger. Score : 0.70606
# Predict ke-482. Label : joy. Score : 0.28703
# Predict ke-483. Label : sadness. Score : 0.87337
# Predict ke-484. Label : joy. Score : 0.41554
# Predict ke-485. Label : love. Score : 0.78845
# Predict ke-486. Label : joy. Score : 0.98599
# Predict ke-487. Label : joy. Score : 0.53832
# Predict ke-488. Label : joy. Score : 0.70838
# Predict ke-489. Label : joy. Score : 0.99609
# Predict ke-490. Label : sadness. Score : 0.33615
# Predict ke-491. Label : joy. Score : 0.89019
# Predict ke-492. Label : joy. Score : 0.98694
# Predict ke-493. Label : sadness. Score : 0.99224
# Predict ke-494. Label : joy. Score : 0.99157
# Predict ke-495. Label : sadness. Score : 0.86805
# Predict ke-496. Label : joy. Score : 0.66009
# Predict ke-497. Label : joy. Score : 0.9955
# Predict ke-498. Label : fear. Score : 0.72068
# Predict ke-499. Label : joy. Score : 0.99265
# Predict ke-500. Label : joy. Score : 0.41688
# Predict ke-501. Label : joy. Score : 0.99511
# Predict ke-502. Label : anger. Score : 0.76744
# Predict ke-503. Label : love. Score : 0.66854
# Predict ke-504. Label : anger. Score : 0.74359
# Predict ke-505. Label : anger. Score : 0.95481
# Predict ke-506. Label : anger. Score : 0.52568
# Predict ke-507. Label : joy. Score : 0.65217
# Predict ke-508. Label : sadness. Score : 0.72334
# Predict ke-509. Label : sadness. Score : 0.98198
# Predict ke-510. Label : fear. Score : 0.59529
# Predict ke-511. Label : sadness. Score : 0.99149
# Predict ke-512. Label : joy. Score : 0.89742
# Predict ke-513. Label : anger. Score : 0.9953
# Predict ke-514. Label : joy. Score : 0.48579
# Predict ke-515. Label : joy. Score : 0.99572
# Predict ke-516. Label : joy. Score : 0.72807
# Predict ke-517. Label : joy. Score : 0.50672
# Predict ke-518. Label : anger. Score : 0.85271
# Predict ke-519. Label : joy. Score : 0.7614
# Predict ke-520. Label : fear. Score : 0.72169
# Predict ke-521. Label : sadness. Score : 0.47604
# Predict ke-522. Label : joy. Score : 0.98103
# Predict ke-523. Label : joy. Score : 0.89147
# Predict ke-524. Label : fear. Score : 0.91571
# Predict ke-525. Label : joy. Score : 0.99673
# Predict ke-526. Label : anger. Score : 0.4344
# Predict ke-527. Label : anger. Score : 0.60386
# Predict ke-528. Label : joy. Score : 0.99442
# Predict ke-529. Label : joy. Score : 0.98176
# Predict ke-530. Label : joy. Score : 0.99537
# Predict ke-531. Label : sadness. Score : 0.59915
# Predict ke-532. Label : anger. Score : 0.60052
# Predict ke-533. Label : joy. Score : 0.46508
# Predict ke-534. Label : sadness. Score : 0.98719
# Predict ke-535. Label : joy. Score : 0.8057
# Predict ke-536. Label : anger. Score : 0.70796
# Predict ke-537. Label : anger. Score : 0.74057
# Predict ke-538. Label : joy. Score : 0.99746
# Predict ke-539. Label : fear. Score : 0.91621
# Predict ke-540. Label : joy. Score : 0.98163
# Predict ke-541. Label : joy. Score : 0.81696
# Predict ke-542. Label : joy. Score : 0.98371
# Predict ke-543. Label : joy. Score : 0.62692
# Predict ke-544. Label : joy. Score : 0.94216
# Predict ke-545. Label : joy. Score : 0.30169
# Predict ke-546. Label : joy. Score : 0.98808
# Predict ke-547. Label : joy. Score : 0.63991
# Predict ke-548. Label : joy. Score : 0.52865
# Predict ke-549. Label : surprise. Score : 0.69042
# Predict ke-550. Label : fear. Score : 0.91677
# Predict ke-551. Label : joy. Score : 0.9562
# Predict ke-552. Label : joy. Score : 0.78171
# Predict ke-553. Label : fear. Score : 0.82237
# Predict ke-554. Label : sadness. Score : 0.56078
# Predict ke-555. Label : sadness. Score : 0.78877
# Predict ke-556. Label : anger. Score : 0.73305
# Predict ke-557. Label : anger. Score : 0.51617
# Predict ke-558. Label : joy. Score : 0.94051
# Predict ke-559. Label : love. Score : 0.98157
# Predict ke-560. Label : joy. Score : 0.95956
# Predict ke-561. Label : joy. Score : 0.89065
# Predict ke-562. Label : sadness. Score : 0.67252
# Predict ke-563. Label : sadness. Score : 0.82233
# Predict ke-564. Label : anger. Score : 0.99207
# Predict ke-565. Label : joy. Score : 0.88268
# Predict ke-566. Label : sadness. Score : 0.93196
# Predict ke-567. Label : anger. Score : 0.74646
# Predict ke-568. Label : joy. Score : 0.93708
# Predict ke-569. Label : sadness. Score : 0.9003
# Predict ke-570. Label : love. Score : 0.82981
# Predict ke-571. Label : anger. Score : 0.81648
# Predict ke-572. Label : anger. Score : 0.85871
# Predict ke-573. Label : sadness. Score : 0.88785
# Predict ke-574. Label : joy. Score : 0.77932
# Predict ke-575. Label : joy. Score : 0.52055
# Predict ke-576. Label : anger. Score : 0.79519
# Predict ke-577. Label : love. Score : 0.94168
# Predict ke-578. Label : anger. Score : 0.50603
# Predict ke-579. Label : joy. Score : 0.45989
# Predict ke-580. Label : fear. Score : 0.90358
# Predict ke-581. Label : sadness. Score : 0.97958
# Predict ke-582. Label : anger. Score : 0.51343
# Predict ke-583. Label : joy. Score : 0.77231
# Predict ke-584. Label : joy. Score : 0.99863
# Predict ke-585. Label : anger. Score : 0.39028
# Predict ke-586. Label : sadness. Score : 0.68347
# Predict ke-587. Label : joy. Score : 0.70076
# Predict ke-588. Label : sadness. Score : 0.59159
# Predict ke-589. Label : joy. Score : 0.98625
# Predict ke-590. Label : sadness. Score : 0.89453
# Predict ke-591. Label : sadness. Score : 0.95233
# Predict ke-592. Label : joy. Score : 0.97339
# Predict ke-593. Label : joy. Score : 0.99093
# Predict ke-594. Label : sadness. Score : 0.41852
# Predict ke-595. Label : sadness. Score : 0.99795
# Predict ke-596. Label : joy. Score : 0.98955
# Predict ke-597. Label : joy. Score : 0.98844
# Predict ke-598. Label : sadness. Score : 0.43379
# Predict ke-599. Label : anger. Score : 0.47
# Predict ke-600. Label : anger. Score : 0.72248
# Predict ke-601. Label : joy. Score : 0.87018
# Predict ke-602. Label : joy. Score : 0.83481
# Predict ke-603. Label : sadness. Score : 0.81881
# Predict ke-604. Label : joy. Score : 0.60963
# Predict ke-605. Label : joy. Score : 0.96747
# Predict ke-606. Label : sadness. Score : 0.99737
# Predict ke-607. Label : joy. Score : 0.82096
# Predict ke-608. Label : joy. Score : 0.9976
# Predict ke-609. Label : sadness. Score : 0.87476
# Predict ke-610. Label : anger. Score : 0.65054
# Predict ke-611. Label : sadness. Score : 0.93586
# Predict ke-612. Label : fear. Score : 0.91111
# Predict ke-613. Label : anger. Score : 0.6247
# Predict ke-614. Label : joy. Score : 0.98977
# Predict ke-615. Label : sadness. Score : 0.91905
# Predict ke-616. Label : joy. Score : 0.65745
# Predict ke-617. Label : sadness. Score : 0.80866
# Predict ke-618. Label : sadness. Score : 0.98625
# Predict ke-619. Label : anger. Score : 0.93691
# Predict ke-620. Label : joy. Score : 0.97804
# Predict ke-621. Label : joy. Score : 0.66211
# Predict ke-622. Label : sadness. Score : 0.97323
# Predict ke-623. Label : anger. Score : 0.9687
# Predict ke-624. Label : fear. Score : 0.46065
# Predict ke-625. Label : love. Score : 0.95454
# Predict ke-626. Label : sadness. Score : 0.57926
# Predict ke-627. Label : sadness. Score : 0.49361
# Predict ke-628. Label : joy. Score : 0.80539
# Predict ke-629. Label : joy. Score : 0.52466
# Predict ke-630. Label : anger. Score : 0.99485
# Predict ke-631. Label : love. Score : 0.90639
# Predict ke-632. Label : sadness. Score : 0.4846
# Predict ke-633. Label : joy. Score : 0.69145
# Predict ke-634. Label : joy. Score : 0.90879
# Predict ke-635. Label : anger. Score : 0.81835
# Predict ke-636. Label : sadness. Score : 0.40137
# Predict ke-637. Label : joy. Score : 0.61737
# Predict ke-638. Label : sadness. Score : 0.86437
# Predict ke-639. Label : fear. Score : 0.811
# Predict ke-640. Label : sadness. Score : 0.9857
# Predict ke-641. Label : sadness. Score : 0.99606
# Predict ke-642. Label : joy. Score : 0.99679
# Predict ke-643. Label : sadness. Score : 0.95785
# Predict ke-644. Label : fear. Score : 0.87556
# Predict ke-645. Label : joy. Score : 0.99248
# Predict ke-646. Label : joy. Score : 0.56581
# Predict ke-647. Label : joy. Score : 0.97764
# Predict ke-648. Label : joy. Score : 0.9932
# Predict ke-649. Label : sadness. Score : 0.9579
# Predict ke-650. Label : anger. Score : 0.85536
# Predict ke-651. Label : fear. Score : 0.54198
# Predict ke-652. Label : sadness. Score : 0.57448
# Predict ke-653. Label : sadness. Score : 0.9275
# Predict ke-654. Label : joy. Score : 0.97341
# Predict ke-655. Label : joy. Score : 0.99306
# Predict ke-656. Label : anger. Score : 0.99565
# Predict ke-657. Label : joy. Score : 0.57913
# Predict ke-658. Label : joy. Score : 0.78856
# Predict ke-659. Label : joy. Score : 0.77486
# Predict ke-660. Label : joy. Score : 0.95529
# Predict ke-661. Label : fear. Score : 0.50972
# Predict ke-662. Label : anger. Score : 0.51439
# Predict ke-663. Label : anger. Score : 0.91687
# Predict ke-664. Label : sadness. Score : 0.96574
# Predict ke-665. Label : joy. Score : 0.71864
# Predict ke-666. Label : sadness. Score : 0.7711
# Predict ke-667. Label : joy. Score : 0.97214
# Predict ke-668. Label : fear. Score : 0.94253
# Predict ke-669. Label : joy. Score : 0.77441
# Predict ke-670. Label : sadness. Score : 0.99105
# Predict ke-671. Label : joy. Score : 0.75183
# Predict ke-672. Label : sadness. Score : 0.97942
# Predict ke-673. Label : joy. Score : 0.98378
# Predict ke-674. Label : joy. Score : 0.96181
# Predict ke-675. Label : fear. Score : 0.44428
# Predict ke-676. Label : joy. Score : 0.66029
# Predict ke-677. Label : sadness. Score : 0.50124
# Predict ke-678. Label : fear. Score : 0.42771
# Predict ke-679. Label : sadness. Score : 0.96841
# Predict ke-680. Label : fear. Score : 0.59333
# Predict ke-681. Label : joy. Score : 0.75479
# Predict ke-682. Label : joy. Score : 0.84255
# Predict ke-683. Label : fear. Score : 0.93516
# Predict ke-684. Label : joy. Score : 0.97059
# Predict ke-685. Label : sadness. Score : 0.85796
# Predict ke-686. Label : joy. Score : 0.91828
# Predict ke-687. Label : sadness. Score : 0.99625
# Predict ke-688. Label : joy. Score : 0.94059
# Predict ke-689. Label : joy. Score : 0.99065
# Predict ke-690. Label : anger. Score : 0.56717
# Predict ke-691. Label : joy. Score : 0.95496
# Predict ke-692. Label : anger. Score : 0.52821
# Predict ke-693. Label : joy. Score : 0.92831
# Predict ke-694. Label : joy. Score : 0.93943
# Predict ke-695. Label : anger. Score : 0.53256
# Predict ke-696. Label : love. Score : 0.46895
# Predict ke-697. Label : fear. Score : 0.40727
# Predict ke-698. Label : joy. Score : 0.34117
# Predict ke-699. Label : sadness. Score : 0.99881
# Predict ke-700. Label : joy. Score : 0.9638
# Predict ke-701. Label : joy. Score : 0.78379
# Predict ke-702. Label : joy. Score : 0.98791
# Predict ke-703. Label : joy. Score : 0.4744
# Predict ke-704. Label : sadness. Score : 0.88389
# Predict ke-705. Label : fear. Score : 0.49554
# Predict ke-706. Label : fear. Score : 0.91747
# Predict ke-707. Label : joy. Score : 0.95471
# Predict ke-708. Label : fear. Score : 0.77224
# Predict ke-709. Label : sadness. Score : 0.94899
# Predict ke-710. Label : joy. Score : 0.9969
# Predict ke-711. Label : joy. Score : 0.94911
# Predict ke-712. Label : anger. Score : 0.51909
# Predict ke-713. Label : joy. Score : 0.98349
# Predict ke-714. Label : sadness. Score : 0.96448
# Predict ke-715. Label : joy. Score : 0.97248
# Predict ke-716. Label : love. Score : 0.48891
# Predict ke-717. Label : sadness. Score : 0.79012
# Predict ke-718. Label : anger. Score : 0.39583
# Predict ke-719. Label : anger. Score : 0.4875
# Predict ke-720. Label : joy. Score : 0.94365
# Predict ke-721. Label : joy. Score : 0.56354
# Predict ke-722. Label : anger. Score : 0.75745
# Predict ke-723. Label : sadness. Score : 0.89559
# Predict ke-724. Label : joy. Score : 0.98549
# Predict ke-725. Label : joy. Score : 0.99556
# Predict ke-726. Label : sadness. Score : 0.99029
# Predict ke-727. Label : fear. Score : 0.9506
# Predict ke-728. Label : joy. Score : 0.41907
# Predict ke-729. Label : joy. Score : 0.99197
# Predict ke-730. Label : joy. Score : 0.99384
# Predict ke-731. Label : anger. Score : 0.63155
# Predict ke-732. Label : sadness. Score : 0.94189
# Predict ke-733. Label : joy. Score : 0.31557
# Predict ke-734. Label : joy. Score : 0.99639
# Predict ke-735. Label : anger. Score : 0.85596
# Predict ke-736. Label : sadness. Score : 0.49636
# Predict ke-737. Label : joy. Score : 0.57141
# Predict ke-738. Label : anger. Score : 0.40761
# Predict ke-739. Label : sadness. Score : 0.95599
# Predict ke-740. Label : anger. Score : 0.52696
# Predict ke-741. Label : joy. Score : 0.72087
# Predict ke-742. Label : sadness. Score : 0.98198
# Predict ke-743. Label : joy. Score : 0.96227
# Predict ke-744. Label : sadness. Score : 0.38007
# Predict ke-745. Label : sadness. Score : 0.99778
# Predict ke-746. Label : sadness. Score : 0.95923
# Predict ke-747. Label : love. Score : 0.86966
# Predict ke-748. Label : joy. Score : 0.72713
# Predict ke-749. Label : fear. Score : 0.62928
# Predict ke-750. Label : sadness. Score : 0.58804
# Predict ke-751. Label : sadness. Score : 0.96714
# Predict ke-752. Label : joy. Score : 0.92072
# Predict ke-753. Label : sadness. Score : 0.9796
# Predict ke-754. Label : fear. Score : 0.99251
# Predict ke-755. Label : sadness. Score : 0.51921
# Predict ke-756. Label : fear. Score : 0.96014
# Predict ke-757. Label : joy. Score : 0.96051
# Predict ke-758. Label : sadness. Score : 0.90251
# Predict ke-759. Label : sadness. Score : 0.9418
# Predict ke-760. Label : joy. Score : 0.54253
# Predict ke-761. Label : joy. Score : 0.6465
# Predict ke-762. Label : joy. Score : 0.98802
# Predict ke-763. Label : fear. Score : 0.85769
# Predict ke-764. Label : joy. Score : 0.92561
# Predict ke-765. Label : anger. Score : 0.9186
# Predict ke-766. Label : joy. Score : 0.89814
# Predict ke-767. Label : joy. Score : 0.98799
# Predict ke-768. Label : joy. Score : 0.80081
# Predict ke-769. Label : joy. Score : 0.64367
# Predict ke-770. Label : anger. Score : 0.76869
# Predict ke-771. Label : sadness. Score : 0.84354
# Predict ke-772. Label : joy. Score : 0.88931
# Predict ke-773. Label : anger. Score : 0.89993
# Predict ke-774. Label : sadness. Score : 0.98376
# Predict ke-775. Label : fear. Score : 0.97402
# Predict ke-776. Label : joy. Score : 0.79518
# Predict ke-777. Label : joy. Score : 0.99819
# Predict ke-778. Label : joy. Score : 0.77419
# Predict ke-779. Label : joy. Score : 0.65294
# Predict ke-780. Label : love. Score : 0.855
# Predict ke-781. Label : joy. Score : 0.58616
# Predict ke-782. Label : joy. Score : 0.59561
# Predict ke-783. Label : sadness. Score : 0.93989
# Predict ke-784. Label : love. Score : 0.95286
# Predict ke-785. Label : sadness. Score : 0.98589
# Predict ke-786. Label : joy. Score : 0.87273
# Predict ke-787. Label : love. Score : 0.91852
# Predict ke-788. Label : sadness. Score : 0.90556
# Predict ke-789. Label : joy. Score : 0.79256
# Predict ke-790. Label : fear. Score : 0.90308
# Predict ke-791. Label : sadness. Score : 0.59901
# Predict ke-792. Label : anger. Score : 0.37936
# Predict ke-793. Label : joy. Score : 0.99298
# Predict ke-794. Label : anger. Score : 0.93423
# Predict ke-795. Label : sadness. Score : 0.7287
# Predict ke-796. Label : anger. Score : 0.56554
# Predict ke-797. Label : fear. Score : 0.38942
# Predict ke-798. Label : sadness. Score : 0.6047
# Predict ke-799. Label : anger. Score : 0.43347
# Predict ke-800. Label : fear. Score : 0.72554
# Predict ke-801. Label : fear. Score : 0.94803
# Predict ke-802. Label : anger. Score : 0.88787
# Predict ke-803. Label : joy. Score : 0.96772
# Predict ke-804. Label : joy. Score : 0.96652
# Predict ke-805. Label : joy. Score : 0.59891
# Predict ke-806. Label : joy. Score : 0.49407
# Predict ke-807. Label : anger. Score : 0.90245
# Predict ke-808. Label : joy. Score : 0.46787
# Predict ke-809. Label : joy. Score : 0.96378
# Predict ke-810. Label : sadness. Score : 0.87987
# Predict ke-811. Label : joy. Score : 0.972
# Predict ke-812. Label : anger. Score : 0.33077
# Predict ke-813. Label : love. Score : 0.66683
# Predict ke-814. Label : joy. Score : 0.40638
# Predict ke-815. Label : joy. Score : 0.9573
# Predict ke-816. Label : fear. Score : 0.49989
# Predict ke-817. Label : anger. Score : 0.62021
# Predict ke-818. Label : anger. Score : 0.9954
# Predict ke-819. Label : sadness. Score : 0.55167
# Predict ke-820. Label : joy. Score : 0.76927
# Predict ke-821. Label : joy. Score : 0.9921
# Predict ke-822. Label : joy. Score : 0.95228
# Predict ke-823. Label : joy. Score : 0.7324
# Predict ke-824. Label : sadness. Score : 0.77028
# Predict ke-825. Label : anger. Score : 0.38894
# Predict ke-826. Label : joy. Score : 0.93976
# Predict ke-827. Label : joy. Score : 0.99631
# Predict ke-828. Label : fear. Score : 0.91571
# Predict ke-829. Label : fear. Score : 0.62004
# Predict ke-830. Label : anger. Score : 0.39203
# Predict ke-831. Label : love. Score : 0.727
# Predict ke-832. Label : joy. Score : 0.90484
# Predict ke-833. Label : joy. Score : 0.9595
# Predict ke-834. Label : sadness. Score : 0.70348
# Predict ke-835. Label : fear. Score : 0.51754
# Predict ke-836. Label : joy. Score : 0.97391
# Predict ke-837. Label : anger. Score : 0.99783
# Predict ke-838. Label : joy. Score : 0.7428
# Predict ke-839. Label : fear. Score : 0.65719
# Predict ke-840. Label : sadness. Score : 0.93704
# Predict ke-841. Label : anger. Score : 0.36348
# Predict ke-842. Label : anger. Score : 0.99382
# Predict ke-843. Label : joy. Score : 0.90306
# Predict ke-844. Label : sadness. Score : 0.61666
# Predict ke-845. Label : joy. Score : 0.64746
# Predict ke-846. Label : sadness. Score : 0.70277
# Predict ke-847. Label : anger. Score : 0.66151
# Predict ke-848. Label : joy. Score : 0.62847
# Predict ke-849. Label : fear. Score : 0.6691
# Predict ke-850. Label : anger. Score : 0.48194
# Predict ke-851. Label : fear. Score : 0.52924
# Predict ke-852. Label : love. Score : 0.96746
# Predict ke-853. Label : fear. Score : 0.34925
# Predict ke-854. Label : joy. Score : 0.72474
# Predict ke-855. Label : anger. Score : 0.35885
# Predict ke-856. Label : fear. Score : 0.93253
# Predict ke-857. Label : love. Score : 0.57622
# Predict ke-858. Label : fear. Score : 0.74897
# Predict ke-859. Label : joy. Score : 0.93278
# Predict ke-860. Label : joy. Score : 0.99386
# Predict ke-861. Label : sadness. Score : 0.45675
# Predict ke-862. Label : sadness. Score : 0.52798
# Predict ke-863. Label : sadness. Score : 0.92887
# Predict ke-864. Label : anger. Score : 0.53113
# Predict ke-865. Label : sadness. Score : 0.95304
# Predict ke-866. Label : fear. Score : 0.94745
# Predict ke-867. Label : joy. Score : 0.77302
# Predict ke-868. Label : sadness. Score : 0.64524
# Predict ke-869. Label : joy. Score : 0.6489
# Predict ke-870. Label : joy. Score : 0.58371
# Predict ke-871. Label : joy. Score : 0.94528
# Predict ke-872. Label : anger. Score : 0.99034
# Predict ke-873. Label : fear. Score : 0.96215
# Predict ke-874. Label : sadness. Score : 0.99532
# Predict ke-875. Label : sadness. Score : 0.62055
# Predict ke-876. Label : joy. Score : 0.96593
# Predict ke-877. Label : fear. Score : 0.46034
# Predict ke-878. Label : anger. Score : 0.46063
# Predict ke-879. Label : sadness. Score : 0.67565
# Predict ke-880. Label : joy. Score : 0.69087
# Predict ke-881. Label : fear. Score : 0.98374
# Predict ke-882. Label : sadness. Score : 0.44799
# Predict ke-883. Label : anger. Score : 0.42105
# Predict ke-884. Label : anger. Score : 0.36944
# Predict ke-885. Label : joy. Score : 0.73498
# Predict ke-886. Label : sadness. Score : 0.7847
# Predict ke-887. Label : joy. Score : 0.38506
# Predict ke-888. Label : love. Score : 0.98587
# Predict ke-889. Label : joy. Score : 0.92059
# Predict ke-890. Label : joy. Score : 0.47026
# Predict ke-891. Label : joy. Score : 0.74588
# Predict ke-892. Label : sadness. Score : 0.86358
# Predict ke-893. Label : joy. Score : 0.7732
# Predict ke-894. Label : joy. Score : 0.96046
# Predict ke-895. Label : sadness. Score : 0.351
# Predict ke-896. Label : joy. Score : 0.41952
# Predict ke-897. Label : joy. Score : 0.97581
# Predict ke-898. Label : anger. Score : 0.57433
# Predict ke-899. Label : joy. Score : 0.88936
# Predict ke-900. Label : joy. Score : 0.78884
# Predict ke-901. Label : anger. Score : 0.40023
# Predict ke-902. Label : anger. Score : 0.71784
# Predict ke-903. Label : anger. Score : 0.71857
# Predict ke-904. Label : anger. Score : 0.62677
# Predict ke-905. Label : joy. Score : 0.96974
# Predict ke-906. Label : joy. Score : 0.82047
# Predict ke-907. Label : fear. Score : 0.47019
# Predict ke-908. Label : sadness. Score : 0.70568
# Predict ke-909. Label : love. Score : 0.45129
# Predict ke-910. Label : sadness. Score : 0.99238
# Predict ke-911. Label : love. Score : 0.49308
# Predict ke-912. Label : joy. Score : 0.80769
# Predict ke-913. Label : anger. Score : 0.69517
# Predict ke-914. Label : sadness. Score : 0.72475
# Predict ke-915. Label : anger. Score : 0.78243
# Predict ke-916. Label : joy. Score : 0.2678
# Predict ke-917. Label : sadness. Score : 0.59224
# Predict ke-918. Label : anger. Score : 0.80053
# Predict ke-919. Label : anger. Score : 0.69521
# Predict ke-920. Label : sadness. Score : 0.63163
# Predict ke-921. Label : anger. Score : 0.97305
# Predict ke-922. Label : love. Score : 0.74617
# Predict ke-923. Label : sadness. Score : 0.8134
# Predict ke-924. Label : sadness. Score : 0.97446
# Predict ke-925. Label : anger. Score : 0.40202
# Predict ke-926. Label : joy. Score : 0.98129
# Predict ke-927. Label : sadness. Score : 0.85432
# Predict ke-928. Label : joy. Score : 0.7333
# Predict ke-929. Label : sadness. Score : 0.38498
# Predict ke-930. Label : sadness. Score : 0.97194
# Predict ke-931. Label : joy. Score : 0.48558
# Predict ke-932. Label : anger. Score : 0.38638
# Predict ke-933. Label : sadness. Score : 0.97937
# Predict ke-934. Label : sadness. Score : 0.9702
# Predict ke-935. Label : joy. Score : 0.98224
# Predict ke-936. Label : sadness. Score : 0.99558
# Predict ke-937. Label : sadness. Score : 0.97183
# Predict ke-938. Label : anger. Score : 0.98349
# Predict ke-939. Label : joy. Score : 0.62011
# Predict ke-940. Label : sadness. Score : 0.62967
# Predict ke-941. Label : joy. Score : 0.39231
# Predict ke-942. Label : fear. Score : 0.51251
# Predict ke-943. Label : sadness. Score : 0.87193
# Predict ke-944. Label : joy. Score : 0.99557
# Predict ke-945. Label : joy. Score : 0.54888
# Predict ke-946. Label : anger. Score : 0.29173
# Predict ke-947. Label : anger. Score : 0.64074
# Predict ke-948. Label : anger. Score : 0.39679
# Predict ke-949. Label : joy. Score : 0.71651
# Predict ke-950. Label : joy. Score : 0.99606
# Predict ke-951. Label : joy. Score : 0.5553
# Predict ke-952. Label : sadness. Score : 0.98462
# Predict ke-953. Label : sadness. Score : 0.52188
# Predict ke-954. Label : joy. Score : 0.68336
# Predict ke-955. Label : anger. Score : 0.82077
# Predict ke-956. Label : sadness. Score : 0.54221
# Predict ke-957. Label : anger. Score : 0.77822
# Predict ke-958. Label : joy. Score : 0.35551
# Predict ke-959. Label : joy. Score : 0.94785
# Predict ke-960. Label : sadness. Score : 0.99646
# Predict ke-961. Label : love. Score : 0.81967
# Predict ke-962. Label : joy. Score : 0.56664
# Predict ke-963. Label : anger. Score : 0.4046
# Predict ke-964. Label : sadness. Score : 0.90234
# Predict ke-965. Label : love. Score : 0.902
# Predict ke-966. Label : joy. Score : 0.95947
# Predict ke-967. Label : anger. Score : 0.85191
# Predict ke-968. Label : love. Score : 0.94647
# Predict ke-969. Label : anger. Score : 0.76142
# Predict ke-970. Label : surprise. Score : 0.79432
# Predict ke-971. Label : fear. Score : 0.99679
# Predict ke-972. Label : sadness. Score : 0.56362
# Predict ke-973. Label : love. Score : 0.43939
# Predict ke-974. Label : joy. Score : 0.66134
# Predict ke-975. Label : love. Score : 0.87364
# Predict ke-976. Label : sadness. Score : 0.89986
# Predict ke-977. Label : fear. Score : 0.93398
# Predict ke-978. Label : joy. Score : 0.86885
# Predict ke-979. Label : joy. Score : 0.95977
# Predict ke-980. Label : anger. Score : 0.97304
# Predict ke-981. Label : joy. Score : 0.98121
# Predict ke-982. Label : love. Score : 0.98662
# Predict ke-983. Label : joy. Score : 0.98601
# Predict ke-984. Label : joy. Score : 0.97379
# Predict ke-985. Label : joy. Score : 0.98612
# Predict ke-986. Label : joy. Score : 0.8588
# Predict ke-987. Label : sadness. Score : 0.87287
# Predict ke-988. Label : anger. Score : 0.99303
# Predict ke-989. Label : sadness. Score : 0.99825
# Predict ke-990. Label : sadness. Score : 0.6491
# Predict ke-991. Label : joy. Score : 0.57439
# Predict ke-992. Label : sadness. Score : 0.91543
# Predict ke-993. Label : joy. Score : 0.50848
# Predict ke-994. Label : sadness. Score : 0.52633
# Predict ke-995. Label : joy. Score : 0.85668
# Predict ke-996. Label : sadness. Score : 0.97752
# Predict ke-997. Label : sadness. Score : 0.76939
# Predict ke-998. Label : joy. Score : 0.98378
# Predict ke-999. Label : anger. Score : 0.42165
# Predict ke-1000. Label : anger. Score : 0.45181
# Predict ke-1001. Label : joy. Score : 0.5457
# Predict ke-1002. Label : joy. Score : 0.60666
# Predict ke-1003. Label : joy. Score : 0.45749
# Predict ke-1004. Label : sadness. Score : 0.64794
# Predict ke-1005. Label : sadness. Score : 0.60222
# Predict ke-1006. Label : sadness. Score : 0.94311
# Predict ke-1007. Label : sadness. Score : 0.46941
# Predict ke-1008. Label : anger. Score : 0.60882
# Predict ke-1009. Label : joy. Score : 0.51873
# Predict ke-1010. Label : sadness. Score : 0.71531
# Predict ke-1011. Label : sadness. Score : 0.97875
# Predict ke-1012. Label : joy. Score : 0.86594
# Predict ke-1013. Label : fear. Score : 0.8156
# Predict ke-1014. Label : joy. Score : 0.98565
# Predict ke-1015. Label : anger. Score : 0.64326
# Predict ke-1016. Label : fear. Score : 0.31935
# Predict ke-1017. Label : anger. Score : 0.69929
# Predict ke-1018. Label : anger. Score : 0.82713
# Predict ke-1019. Label : fear. Score : 0.99547
# Predict ke-1020. Label : joy. Score : 0.61284
# Predict ke-1021. Label : joy. Score : 0.94057
# Predict ke-1022. Label : anger. Score : 0.77976
# Predict ke-1023. Label : fear. Score : 0.45976
# Predict ke-1024. Label : fear. Score : 0.94784
# Predict ke-1025. Label : anger. Score : 0.38271
# Predict ke-1026. Label : joy. Score : 0.91125
# Predict ke-1027. Label : anger. Score : 0.65934
# Predict ke-1028. Label : anger. Score : 0.9215
# Predict ke-1029. Label : anger. Score : 0.9942
# ...
# Predict ke-17082. Label : anger. Score : 0.48794
# Predict ke-17083. Label : sadness. Score : 0.77008
# Predict ke-17084. Label : joy. Score : 0.65354
# Predict ke-17085. Label : sadness. Score : 0.98356
# Predict ke-17086. Label : sadness. Score : 0.87607
# Predict ke-17087. Label : sadness. Score : 0.99156
# Predict ke-17088. Label : sadness. Score : 0.46078
# Predict ke-17089. Label : joy. Score : 0.5389
# Predict ke-17090. Label : anger. Score : 0.83869
# Predict ke-17091. Label : joy. Score : 0.83831
# Predict ke-17092. Label : sadness. Score : 0.99081
# Predict ke-17093. Label : joy. Score : 0.52853
# Predict ke-17094. Label : anger. Score : 0.89253
# Predict ke-17095. Label : joy. Score : 0.80902
# Predict ke-17096. Label : joy. Score : 0.9957
# Predict ke-17097. Label : joy. Score : 0.99346
# Predict ke-17098. Label : joy. Score : 0.99107
# Predict ke-17099. Label : joy. Score : 0.62557
# Predict ke-17100. Label : joy. Score : 0.94899
# Predict ke-17101. Label : sadness. Score : 0.87543
# Predict ke-17102. Label : joy. Score : 0.81376
# Predict ke-17103. Label : love. Score : 0.52187
# Predict ke-17104. Label : joy. Score : 0.97841
# Predict ke-17105. Label : joy. Score : 0.97882
# Predict ke-17106. Label : sadness. Score : 0.82504
# Predict ke-17107. Label : joy. Score : 0.98042
# Predict ke-17108. Label : joy. Score : 0.99588
# Predict ke-17109. Label : anger. Score : 0.83154
# Predict ke-17110. Label : fear. Score : 0.97193
# Predict ke-17111. Label : anger. Score : 0.9284
# Predict ke-17112. Label : sadness. Score : 0.92352
# Predict ke-17113. Label : joy. Score : 0.92003
# Predict ke-17114. Label : joy. Score : 0.98504
# Predict ke-17115. Label : joy. Score : 0.70781
# Predict ke-17116. Label : joy. Score : 0.90014
# Predict ke-17117. Label : joy. Score : 0.82466
# Predict ke-17118. Label : fear. Score : 0.93327
# Predict ke-17119. Label : anger. Score : 0.66416
# Predict ke-17120. Label : anger. Score : 0.87939
# Predict ke-17121. Label : sadness. Score : 0.98296
# Predict ke-17122. Label : joy. Score : 0.73894
# Predict ke-17123. Label : joy. Score : 0.98171
# Predict ke-17124. Label : sadness. Score : 0.51953
# Predict ke-17125. Label : anger. Score : 0.46346
# Predict ke-17126. Label : sadness. Score : 0.99722
# Predict ke-17127. Label : joy. Score : 0.99406
# Predict ke-17128. Label : joy. Score : 0.71216
# Predict ke-17129. Label : anger. Score : 0.5299
# Predict ke-17130. Label : joy. Score : 0.9914
# Predict ke-17131. Label : fear. Score : 0.49032
# Predict ke-17132. Label : fear. Score : 0.6362
# Predict ke-17133. Label : love. Score : 0.90829
# Predict ke-17134. Label : fear. Score : 0.55105
# Predict ke-17135. Label : joy. Score : 0.99813
# Predict ke-17136. Label : sadness. Score : 0.57699
# Predict ke-17137. Label : joy. Score : 0.96137
# Predict ke-17138. Label : anger. Score : 0.50935
# Predict ke-17139. Label : sadness. Score : 0.98154
# Predict ke-17140. Label : joy. Score : 0.86244
# Predict ke-17141. Label : love. Score : 0.72831
# Predict ke-17142. Label : anger. Score : 0.70767
# Predict ke-17143. Label : sadness. Score : 0.89577
# Predict ke-17144. Label : joy. Score : 0.80825
# Predict ke-17145. Label : joy. Score : 0.65169
# Predict ke-17146. Label : fear. Score : 0.90269
# Predict ke-17147. Label : fear. Score : 0.90286
# Predict ke-17148. Label : sadness. Score : 0.70191
# Predict ke-17149. Label : love. Score : 0.59389
# Predict ke-17150. Label : sadness. Score : 0.79183
# Predict ke-17151. Label : love. Score : 0.42961
# Predict ke-17152. Label : anger. Score : 0.46111
# Predict ke-17153. Label : anger. Score : 0.57446
# Predict ke-17154. Label : joy. Score : 0.75429
# Predict ke-17155. Label : sadness. Score : 0.96632
# Predict ke-17156. Label : joy. Score : 0.97873
# Predict ke-17157. Label : anger. Score : 0.85172
# Predict ke-17158. Label : sadness. Score : 0.43841
# Predict ke-17159. Label : anger. Score : 0.90356
# Predict ke-17160. Label : joy. Score : 0.42671
# Predict ke-17161. Label : joy. Score : 0.67358
# Predict ke-17162. Label : joy. Score : 0.55127
# Predict ke-17163. Label : anger. Score : 0.96514
# Predict ke-17164. Label : love. Score : 0.53848
# Predict ke-17165. Label : joy. Score : 0.98384
# Predict ke-17166. Label : sadness. Score : 0.56446
# Predict ke-17167. Label : sadness. Score : 0.99069
# Predict ke-17168. Label : joy. Score : 0.65892
# Predict ke-17169. Label : love. Score : 0.41482
# Predict ke-17170. Label : joy. Score : 0.97764
# Predict ke-17171. Label : joy. Score : 0.46083
# Predict ke-17172. Label : joy. Score : 0.9942
# Predict ke-17173. Label : anger. Score : 0.47425
# Predict ke-17174. Label : sadness. Score : 0.87447
# Predict ke-17175. Label : anger. Score : 0.53341
# Predict ke-17176. Label : anger. Score : 0.54569
# Predict ke-17177. Label : love. Score : 0.87308
# Predict ke-17178. Label : joy. Score : 0.99846
# Predict ke-17179. Label : sadness. Score : 0.93385
# Predict ke-17180. Label : anger. Score : 0.89417
# Predict ke-17181. Label : joy. Score : 0.75252
# Predict ke-17182. Label : joy. Score : 0.47176
# Predict ke-17183. Label : love. Score : 0.38
# Predict ke-17184. Label : joy. Score : 0.33247
# Predict ke-17185. Label : joy. Score : 0.49608
# Predict ke-17186. Label : joy. Score : 0.9248
# Predict ke-17187. Label : sadness. Score : 0.87138
# Predict ke-17188. Label : joy. Score : 0.70741
# Predict ke-17189. Label : joy. Score : 0.39283
# Predict ke-17190. Label : sadness. Score : 0.73257
# Predict ke-17191. Label : sadness. Score : 0.67036
# Predict ke-17192. Label : fear. Score : 0.93429
# Predict ke-17193. Label : sadness. Score : 0.56469
# Predict ke-17194. Label : joy. Score : 0.48896
# Predict ke-17195. Label : joy. Score : 0.48771
# Predict ke-17196. Label : anger. Score : 0.96035
# Predict ke-17197. Label : sadness. Score : 0.60507
# Predict ke-17198. Label : sadness. Score : 0.38065
# Predict ke-17199. Label : joy. Score : 0.78209
# Predict ke-17200. Label : joy. Score : 0.97245
# Predict ke-17201. Label : sadness. Score : 0.55114
# Predict ke-17202. Label : joy. Score : 0.88249
# Predict ke-17203. Label : sadness. Score : 0.66199
# Predict ke-17204. Label : joy. Score : 0.71038
# Predict ke-17205. Label : joy. Score : 0.90425
# Predict ke-17206. Label : joy. Score : 0.9357
# Predict ke-17207. Label : joy. Score : 0.92215
# Predict ke-17208. Label : sadness. Score : 0.95055
# Predict ke-17209. Label : joy. Score : 0.99582
# Predict ke-17210. Label : anger. Score : 0.9096
# Predict ke-17211. Label : joy. Score : 0.80061
# Predict ke-17212. Label : sadness. Score : 0.79251
# Predict ke-17213. Label : joy. Score : 0.86748
# Predict ke-17214. Label : joy. Score : 0.47178
# Predict ke-17215. Label : love. Score : 0.74507
# Predict ke-17216. Label : love. Score : 0.90952
# Predict ke-17217. Label : anger. Score : 0.997
# Predict ke-17218. Label : love. Score : 0.84555
# Predict ke-17219. Label : joy. Score : 0.55471
# Predict ke-17220. Label : fear. Score : 0.45402
# Predict ke-17221. Label : joy. Score : 0.85947
# Predict ke-17222. Label : anger. Score : 0.35245
# Predict ke-17223. Label : joy. Score : 0.97206
# Predict ke-17224. Label : sadness. Score : 0.4808
# Predict ke-17225. Label : love. Score : 0.51403
# Predict ke-17226. Label : sadness. Score : 0.61442
# Predict ke-17227. Label : joy. Score : 0.97717
# Predict ke-17228. Label : anger. Score : 0.84837
# Predict ke-17229. Label : sadness. Score : 0.90888
# Predict ke-17230. Label : love. Score : 0.72224
# Predict ke-17231. Label : joy. Score : 0.8506
# Predict ke-17232. Label : anger. Score : 0.50399
# Predict ke-17233. Label : anger. Score : 0.43425
# Predict ke-17234. Label : joy. Score : 0.95579
# Predict ke-17235. Label : sadness. Score : 0.93625
# Predict ke-17236. Label : anger. Score : 0.38927
# Predict ke-17237. Label : joy. Score : 0.35616
# Predict ke-17238. Label : joy. Score : 0.6194
# Predict ke-17239. Label : sadness. Score : 0.99557
# Predict ke-17240. Label : anger. Score : 0.41403
# Predict ke-17241. Label : sadness. Score : 0.83287
# Predict ke-17242. Label : sadness. Score : 0.32811
# Predict ke-17243. Label : joy. Score : 0.72193
# Predict ke-17244. Label : joy. Score : 0.90128
# Predict ke-17245. Label : sadness. Score : 0.7942
# Predict ke-17246. Label : joy. Score : 0.97054
# Predict ke-17247. Label : fear. Score : 0.96013
# Predict ke-17248. Label : joy. Score : 0.94821
# Predict ke-17249. Label : anger. Score : 0.5265
# Predict ke-17250. Label : joy. Score : 0.73843
# Predict ke-17251. Label : sadness. Score : 0.96532
# Predict ke-17252. Label : joy. Score : 0.97712
# Predict ke-17253. Label : love. Score : 0.91006
# Predict ke-17254. Label : joy. Score : 0.99075
# Predict ke-17255. Label : anger. Score : 0.4635
# Predict ke-17256. Label : joy. Score : 0.80312
# Predict ke-17257. Label : anger. Score : 0.47593
# Predict ke-17258. Label : sadness. Score : 0.74465
# Predict ke-17259. Label : joy. Score : 0.99788
# Predict ke-17260. Label : joy. Score : 0.41687
# Predict ke-17261. Label : love. Score : 0.9289
# Predict ke-17262. Label : joy. Score : 0.98832
# Predict ke-17263. Label : joy. Score : 0.89999
# Predict ke-17264. Label : joy. Score : 0.76881
# Predict ke-17265. Label : joy. Score : 0.98765
# Predict ke-17266. Label : joy. Score : 0.99846
# Predict ke-17267. Label : sadness. Score : 0.55804
# Predict ke-17268. Label : sadness. Score : 0.3862
# Predict ke-17269. Label : joy. Score : 0.96385
# Predict ke-17270. Label : fear. Score : 0.86168
# Predict ke-17271. Label : joy. Score : 0.93443
# Predict ke-17272. Label : joy. Score : 0.94905
# Predict ke-17273. Label : sadness. Score : 0.99883
# Predict ke-17274. Label : joy. Score : 0.59655
# Predict ke-17275. Label : joy. Score : 0.7481
# Predict ke-17276. Label : fear. Score : 0.98862
# Predict ke-17277. Label : joy. Score : 0.69535
# Predict ke-17278. Label : love. Score : 0.91323
# Predict ke-17279. Label : sadness. Score : 0.40936
# Predict ke-17280. Label : anger. Score : 0.96773
# Predict ke-17281. Label : sadness. Score : 0.91967
# Predict ke-17282. Label : joy. Score : 0.70002
# Predict ke-17283. Label : love. Score : 0.79908
# Predict ke-17284. Label : joy. Score : 0.99236
# Predict ke-17285. Label : joy. Score : 0.7331
# Predict ke-17286. Label : joy. Score : 0.95966
# Predict ke-17287. Label : love. Score : 0.89359
# Predict ke-17288. Label : joy. Score : 0.99202
# Predict ke-17289. Label : joy. Score : 0.551
# Predict ke-17290. Label : anger. Score : 0.46332
# Predict ke-17291. Label : sadness. Score : 0.74637
# Predict ke-17292. Label : joy. Score : 0.86191
# Predict ke-17293. Label : joy. Score : 0.99725
# Predict ke-17294. Label : anger. Score : 0.8308
# Predict ke-17295. Label : anger. Score : 0.43065
# Predict ke-17296. Label : love. Score : 0.79418
# Predict ke-17297. Label : joy. Score : 0.47028
# Predict ke-17298. Label : anger. Score : 0.79101
# Predict ke-17299. Label : anger. Score : 0.9896
# Predict ke-17300. Label : joy. Score : 0.98019
# Predict ke-17301. Label : sadness. Score : 0.99509
# Predict ke-17302. Label : sadness. Score : 0.99633
# Predict ke-17303. Label : joy. Score : 0.40223
# Predict ke-17304. Label : joy. Score : 0.98846
# Predict ke-17305. Label : anger. Score : 0.96239
# Predict ke-17306. Label : joy. Score : 0.99135
# Predict ke-17307. Label : anger. Score : 0.99406
# Predict ke-17308. Label : love. Score : 0.91922
# Predict ke-17309. Label : anger. Score : 0.59888
# Predict ke-17310. Label : joy. Score : 0.99003
# Predict ke-17311. Label : anger. Score : 0.4535
# Predict ke-17312. Label : joy. Score : 0.35867
# Predict ke-17313. Label : joy. Score : 0.75175
# Predict ke-17314. Label : joy. Score : 0.99172
# Predict ke-17315. Label : sadness. Score : 0.69756
# Predict ke-17316. Label : anger. Score : 0.95499
# Predict ke-17317. Label : joy. Score : 0.96523
# Predict ke-17318. Label : anger. Score : 0.97828
# Predict ke-17319. Label : joy. Score : 0.42089
# Predict ke-17320. Label : sadness. Score : 0.7872
# Predict ke-17321. Label : love. Score : 0.67661
# Predict ke-17322. Label : fear. Score : 0.96465
# Predict ke-17323. Label : anger. Score : 0.49306
# Predict ke-17324. Label : anger. Score : 0.99047
# Predict ke-17325. Label : joy. Score : 0.9432
# Predict ke-17326. Label : sadness. Score : 0.56429
# Predict ke-17327. Label : joy. Score : 0.99138
# Predict ke-17328. Label : sadness. Score : 0.99571
# Predict ke-17329. Label : sadness. Score : 0.89207
# Predict ke-17330. Label : fear. Score : 0.54661
# Predict ke-17331. Label : sadness. Score : 0.51989
# Predict ke-17332. Label : joy. Score : 0.94335
# Predict ke-17333. Label : joy. Score : 0.92518
# Predict ke-17334. Label : fear. Score : 0.46101
# Predict ke-17335. Label : anger. Score : 0.67256
# Predict ke-17336. Label : sadness. Score : 0.61992
# Predict ke-17337. Label : sadness. Score : 0.95546
# Predict ke-17338. Label : joy. Score : 0.98143
# Predict ke-17339. Label : joy. Score : 0.99689
# Predict ke-17340. Label : joy. Score : 0.98055
# Predict ke-17341. Label : joy. Score : 0.93735
# Predict ke-17342. Label : joy. Score : 0.99181
# Predict ke-17343. Label : joy. Score : 0.97122
# Predict ke-17344. Label : anger. Score : 0.90737
# Predict ke-17345. Label : joy. Score : 0.82388
# Predict ke-17346. Label : joy. Score : 0.61528
# Predict ke-17347. Label : joy. Score : 0.95311
# Predict ke-17348. Label : sadness. Score : 0.94542
# Predict ke-17349. Label : joy. Score : 0.72959
# Predict ke-17350. Label : sadness. Score : 0.38619
# Predict ke-17351. Label : sadness. Score : 0.83426
# Predict ke-17352. Label : joy. Score : 0.44934
# Predict ke-17353. Label : joy. Score : 0.33218
# Predict ke-17354. Label : anger. Score : 0.53488
# Predict ke-17355. Label : joy. Score : 0.97623
# Predict ke-17356. Label : sadness. Score : 0.93832
# Predict ke-17357. Label : joy. Score : 0.73941
# Predict ke-17358. Label : love. Score : 0.70842
# Predict ke-17359. Label : anger. Score : 0.97708
# Predict ke-17360. Label : anger. Score : 0.99485
# Predict ke-17361. Label : sadness. Score : 0.94595
# Predict ke-17362. Label : joy. Score : 0.99808
# Predict ke-17363. Label : joy. Score : 0.92182
# Predict ke-17364. Label : joy. Score : 0.68691
# Predict ke-17365. Label : sadness. Score : 0.95938
# Predict ke-17366. Label : sadness. Score : 0.59709
# Predict ke-17367. Label : joy. Score : 0.98892
# Predict ke-17368. Label : joy. Score : 0.90161
# Predict ke-17369. Label : fear. Score : 0.93449
# Predict ke-17370. Label : love. Score : 0.97134
# Predict ke-17371. Label : sadness. Score : 0.67836
# Predict ke-17372. Label : sadness. Score : 0.29529
# Predict ke-17373. Label : sadness. Score : 0.43485
# Predict ke-17374. Label : joy. Score : 0.96869
# Predict ke-17375. Label : joy. Score : 0.99723
# Predict ke-17376. Label : anger. Score : 0.98064
# Predict ke-17377. Label : joy. Score : 0.62196
# Predict ke-17378. Label : sadness. Score : 0.498
# Predict ke-17379. Label : sadness. Score : 0.63479
# Predict ke-17380. Label : anger. Score : 0.99761
# Predict ke-17381. Label : fear. Score : 0.67803
# Predict ke-17382. Label : anger. Score : 0.68522
# Predict ke-17383. Label : sadness. Score : 0.8688
# Predict ke-17384. Label : joy. Score : 0.75786
# Predict ke-17385. Label : joy. Score : 0.96447
# Predict ke-17386. Label : sadness. Score : 0.90063
# Predict ke-17387. Label : sadness. Score : 0.99345
# Predict ke-17388. Label : joy. Score : 0.74974
# Predict ke-17389. Label : joy. Score : 0.98123
# Predict ke-17390. Label : joy. Score : 0.9802
# Predict ke-17391. Label : joy. Score : 0.76071
# Predict ke-17392. Label : joy. Score : 0.81223
# Predict ke-17393. Label : fear. Score : 0.44273
# Predict ke-17394. Label : joy. Score : 0.91932
# Predict ke-17395. Label : sadness. Score : 0.99555
# Predict ke-17396. Label : sadness. Score : 0.95914
# Predict ke-17397. Label : sadness. Score : 0.55495
# Predict ke-17398. Label : joy. Score : 0.90592
# Predict ke-17399. Label : sadness. Score : 0.82487
# Predict ke-17400. Label : sadness. Score : 0.40598
# Predict ke-17401. Label : joy. Score : 0.53258
# Predict ke-17402. Label : joy. Score : 0.61128
# Predict ke-17403. Label : joy. Score : 0.94022
# Predict ke-17404. Label : sadness. Score : 0.91861
# Predict ke-17405. Label : joy. Score : 0.45046
# Predict ke-17406. Label : joy. Score : 0.6166
# Predict ke-17407. Label : sadness. Score : 0.56035
# Predict ke-17408. Label : sadness. Score : 0.89751
# Predict ke-17409. Label : sadness. Score : 0.50425
# Predict ke-17410. Label : joy. Score : 0.61976
# Predict ke-17411. Label : anger. Score : 0.69619
# Merging

# %% [markdown]
# ## Attention
#
# HuggingFace model used in this project return 2 things:
#
# 1. The `label` indicates the label predicted by model
# 2. The `score` indicates the confident of model predicting the data

# %% [markdown]
# # Labelling Using DeepSeek-Coder-v2-Lite-Instruct via LM Studio

# %%
# Cleaning dulu sebelum dikasih ke model HuggingFace
# Please, CLEANING INI KEWAJIBAN karena main ke model HuggingFace orang lain

def loadCustomDict(path):
    with open(path, 'r') as file:
        return set(line.strip().lower() for line in file if line.strip())

def normalizeWhitespace(text):
    text = unicodedata.normalize('NFKC', text)
    text = contractions.fix(text)
    text = re.sub(r'[\t\r]+', ' ', text) # Menghapus tab
    text = re.sub(r'\b\d+\b', '', text) # Menghilangkan angka
    text = re.sub(r'[^\w\s]', '', text) # Hilangkan symbol punctuation
    text = re.sub(r'\b(\w+)(?:\s+\1\b)+', r'\1', text) #hilangin double
    text = re.sub(r'\s+', ' ', text).strip().lower()
    return text

def removeOtherLanguage(text):
    phrase = ' translated'
    pos = text.find(phrase)
    if pos != -1:
        text = text[:pos].rstrip()
    text = re.sub(r'\b\w*[^\x00-\x7F]\w*\b', '', text)
    text = re.sub(r'\s+', ' ', text).strip().lower()
    return text

def simpleCleaning():
    df = pd.read_csv('./dataset/poem_dataset.csv')
    copyDf = df.copy()
    copyDf['poem'] = copyDf['poem'].apply(normalizeWhitespace)
    copyDf['poem'] = copyDf['poem'].apply(removeOtherLanguage)
    return df, copyDf

# Cleaning dataset
df, cleanDf = simpleCleaning()

# %%
def truncate_text(text, max_length):
    if len(text) <= max_length:
        return text
    return text[:max_length]

def predictSentimentMergeDeepSeek(df, cleanDf):
    labels = []
    for idx, poem in enumerate(cleanDf.values):
        url = "http://192.168.1.10:55500/v1/chat/completions"
        truncated_poem = truncate_text(poem, 4000)
        headers = {
            "Content-Type": "application/json"
        }
        payload = {
            "model": "deepseek-coder-v2-lite-instruct",
            "messages": [
                {
                    "role": "system", 
                    "content": "You are a poem analysis assistant. Your task is to analyze the emotion of a given poem and assign it one of the following labels: love, joy, sadness, hope, or other. You must only respond with one of these labels and nothing else. Do not provide any additional information, context, nor starting and opening sentence."
                },
                {
                    "role": "user",
                    "content": f"Analyze the following poem and assign it one of the following labels: love, joy, sadness, hope, or other. Respond with only the label and nothing else. Poem : {truncated_poem}",
                }
            ],
            "temperature": 0.5, 
            "max_tokens": -1 
        }
        response = requests.post(url, headers=headers, json=payload)
        if response.status_code == 200:
            response_data = response.json()
            reply = response_data['choices'][0]['message']['content']
            print(f"Predict ke-{idx}. Reply : {reply.lower()}")
            labels.append(reply.lower())
        else:
            print(f"Error: {response.status_code} - {response.text}")
            labels.append(' none')

    print("Merging")
    pd.concat([df, pd.DataFrame({'label':labels})], axis=1).to_csv("./dataset/labelled_poem_deepseek2.csv", index=False)

# %%
final = predictSentimentMergeDeepSeek(df, cleanDf)
# Out:
# Predict ke-0. Reply :  love
# Predict ke-1. Reply :  other
# Predict ke-2. Reply :  other.
# Predict ke-3. Reply :  love.
# Predict ke-4. Reply :  sad
# Predict ke-5. Reply :  hope.
# Predict ke-6. Reply :  love
# Predict ke-7. Reply :  other
# Predict ke-8. Reply :  hope.
# Predict ke-9. Reply :  sadness
# Predict ke-10. Reply :  other.
# Predict ke-11. Reply :  other
# Predict ke-12. Reply :  sadness
# Predict ke-13. Reply :  other
# Predict ke-14. Reply :  sadness
# Predict ke-15. Reply :  hope.
# Predict ke-16. Reply :  other
# Predict ke-17. Reply :  other
# Predict ke-18. Reply :  sadness
# Predict ke-19. Reply :  sadness
# Predict ke-20. Reply :  hope.
# Predict ke-21. Reply :  other.
# Predict ke-22. Reply :  other
# Predict ke-23. Reply :  other.
# Predict ke-24. Reply :  joy
# Predict ke-25. Reply :  joy.
# Predict ke-26. Reply :  hope.
# Predict ke-27. Reply :  hope.
# Predict ke-28. Reply :  sadness.
# Predict ke-29. Reply :  joy.
# Predict ke-30. Reply :  other
# Predict ke-31. Reply :  sad
# Predict ke-32. Reply :  hope.
# Predict ke-33. Reply :  other
# Predict ke-34. Reply :  joy
# Predict ke-35. Reply :  hope
# Predict ke-36. Reply :  other
# Predict ke-37. Reply :  sadness.
# Predict ke-38. Reply :  joy.
# Predict ke-39. Reply :  other.
# Predict ke-40. Reply :  hope.
# Predict ke-41. Reply :  sadness.
# Predict ke-42. Reply :  joy.
# Predict ke-43. Reply :  other
# Predict ke-44. Reply :  other
# Predict ke-45. Reply :  sadness
# Predict ke-46. Reply :  sadness.
# Predict ke-47. Reply :  joy.
# Predict ke-48. Reply :  joy.
# Predict ke-49. Reply :  sad
# Predict ke-50. Reply :  hope.
# Predict ke-51. Reply :  sad
# Predict ke-52. Reply :  sadness
# Predict ke-53. Reply :  joy
# Predict ke-54. Reply :  hope.
# Predict ke-55. Reply :  other.
# Predict ke-56. Reply :  sadness.
# Predict ke-57. Reply :  other
# Predict ke-58. Reply :  love.
# Predict ke-59. Reply :  hope.
# Predict ke-60. Reply :  sadness
# Predict ke-61. Reply :  sadness
# Predict ke-62. Reply :  other
# Predict ke-63. Reply :  sad
# Predict ke-64. Reply :  other.
# Predict ke-65. Reply :  joy.
# Predict ke-66. Reply :  sad
# Predict ke-67. Reply :  sad
# Predict ke-68. Reply :  joy.
# Predict ke-69. Reply :  joy
# Predict ke-70. Reply :  sad
# Predict ke-71. Reply :  hope
# Predict ke-72. Reply :  love
# Predict ke-73. Reply :  hope
# Predict ke-74. Reply :  sadness
# Predict ke-75. Reply :  sadness.
# Predict ke-76. Reply :  joy
# Predict ke-77. Reply :  hope
# Predict ke-78. Reply :  other.
# Predict ke-79. Reply :  sadness
# Predict ke-80. Reply :  other
# Predict ke-81. Reply :  sadness
# Predict ke-82. Reply :  other
# Predict ke-83. Reply :  sadness
# Predict ke-84. Reply :  other
# Predict ke-85. Reply :  sadness.
# Predict ke-86. Reply :  joy.
# Predict ke-87. Reply :  hope.
# Predict ke-88. Reply :  joy.
# Predict ke-89. Reply :  sadness.
# Predict ke-90. Reply :  hope
# Predict ke-91. Reply :  hope.
# Predict ke-92. Reply :  sadness
# Predict ke-93. Reply :  joy
# Predict ke-94. Reply :  other
# Predict ke-95. Reply :  sad
# Predict ke-96. Reply :  other
# Predict ke-97. Reply :  other.
# Predict ke-98. Reply :  other.
# Predict ke-99. Reply :  hope.
# Predict ke-100. Reply :  other
# Predict ke-101. Reply :  hope.
# Predict ke-102. Reply :  sadness
# Predict ke-103. Reply :  joy
# Predict ke-104. Reply :  other
# Predict ke-105. Reply :  hope.
# Predict ke-106. Reply :  other
# Predict ke-107. Reply :  other.
# Predict ke-108. Reply :  other
# Predict ke-109. Reply :  other
# Predict ke-110. Reply :  hope
# Predict ke-111. Reply :  sad
# Predict ke-112. Reply :  love
# Predict ke-113. Reply :  sadness
# Predict ke-114. Reply :  sadness
# Predict ke-115. Reply :  other.
# Predict ke-116. Reply :  other.
# Predict ke-117. Reply :  sadness.
# Predict ke-118. Reply :  joy
# Predict ke-119. Reply :  joy
# Predict ke-120. Reply :  other
# Predict ke-121. Reply :  joy
# Predict ke-122. Reply :  sadness
# Predict ke-123. Reply :  hope.
# Predict ke-124. Reply :  other.
# Predict ke-125. Reply :  other.
# Error: 400 - {"error":"Trying to keep the first 4643 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-127. Reply :  other
# Predict ke-128. Reply :  hope.
# Predict ke-129. Reply :  other
# Predict ke-130. Reply :  other.
# Predict ke-131. Reply :  other.
# Predict ke-132. Reply :  other.
# Predict ke-133. Reply :  other
# Predict ke-134. Reply :  sadness.
# Predict ke-135. Reply :  sadness
# Predict ke-136. Reply :  other.
# Predict ke-137. Reply :  sadness.
# Predict ke-138. Reply :  joy.
# Predict ke-139. Reply :  hope.
# Predict ke-140. Reply :  joy
# Predict ke-141. Reply :  sadness.
# Predict ke-142. Reply :  sadness.
# Predict ke-143. Reply :  other
# Predict ke-144. Reply :  hope
# Predict ke-145. Reply :  other.
# Predict ke-146. Reply :  sadness.
# Predict ke-147. Reply :  other.
# Predict ke-148. Reply :  other
# Predict ke-149. Reply :  hope.
# Predict ke-150. Reply :  other
# Predict ke-151. Reply :  sadness
# Predict ke-152. Reply :  other.
# Predict ke-153. Reply :  other.
# Predict ke-154. Reply :  sadness
# Predict ke-155. Reply :  sadness.
# Predict ke-156. Reply :  other
# Predict ke-157. Reply :  joy.
# Predict ke-158. Reply :  sadness
# Predict ke-159. Reply :  sadness
# Predict ke-160. Reply :  other.
# Predict ke-161. Reply :  other
# Predict ke-162. Reply :  other.
# Predict ke-163. Reply :  sadness.
# Predict ke-164. Reply :  sadness.
# Predict ke-165. Reply :  sadness.
# Predict ke-166. Reply :  hope.
# Predict ke-167. Reply :  joy.
# Predict ke-168. Reply :  joy
# Predict ke-169. Reply :  sadness.
# Predict ke-170. Reply :  other
# Predict ke-171. Reply :  sadness.
# Predict ke-172. Reply :  sadness
# Predict ke-173. Reply :  hope
# Predict ke-174. Reply :  sadness
# Predict ke-175. Reply :  other.
# Predict ke-176. Reply :  joy
# Predict ke-177. Reply :  sadness
# Predict ke-178. Reply :  joy.
# Predict ke-179. Reply :  joy.
# Predict ke-180. Reply :  other.
# Predict ke-181. Reply :  hope.
# Predict ke-182. Reply :  sadness.
# Predict ke-183. Reply :  hope.
# Predict ke-184. Reply :  sadness.
# Predict ke-185. Reply :  joy
# Predict ke-186. Reply :  other.
# Predict ke-187. Reply :  other
# Predict ke-188. Reply :  other
# Predict ke-189. Reply :  other.
# Predict ke-190. Reply :  sad
# Predict ke-191. Reply :  sadness
# Predict ke-192. Reply :  hope.
# Predict ke-193. Reply :  other.
# Predict ke-194. Reply :  other
# Predict ke-195. Reply :  other.
# Predict ke-196. Reply :  other.
# Predict ke-197. Reply :  love
# Predict ke-198. Reply :  joy
# Predict ke-199. Reply :  sadness
# Predict ke-200. Reply :  sadness
# Predict ke-201. Reply :  sadness.
# Predict ke-202. Reply :  other.
# Predict ke-203. Reply :  other.
# Predict ke-204. Reply :  sadness
# Predict ke-205. Reply :  joy.
# Predict ke-206. Reply :  other.
# Predict ke-207. Reply :  other
# Predict ke-208. Reply :  other.
# Predict ke-209. Reply :  other
# Predict ke-210. Reply :  joy.
# Predict ke-211. Reply :  other
# Predict ke-212. Reply :  sadness.
# Predict ke-213. Reply :  sadness.
# Predict ke-214. Reply :  other
# Predict ke-215. Reply :  hope.
# Predict ke-216. Reply :  sadness
# Predict ke-217. Reply :  other.
# Predict ke-218. Reply :  hope.
# Predict ke-219. Reply :  sadness.
# Predict ke-220. Reply :  sadness.
# Predict ke-221. Reply :  joy.
# Predict ke-222. Reply :  joy.
# Predict ke-223. Reply :  sad
# Predict ke-224. Reply :  love
# Predict ke-225. Reply :  sad
# Predict ke-226. Reply :  love
# Predict ke-227. Reply :  love
# Predict ke-228. Reply :  other.
# Predict ke-229. Reply :  sad
# Predict ke-230. Reply :  other.
# Predict ke-231. Reply :  hope
# Predict ke-232. Reply :  sadness.
# Predict ke-233. Reply :  hope.
# Predict ke-234. Reply :  other.
# Predict ke-235. Reply :  sadness
# Predict ke-236. Reply :  other.
# Predict ke-237. Reply :  sadness
# Predict ke-238. Reply :  other
# Predict ke-239. Reply :  other.
# Predict ke-240. Reply :  joy
# Predict ke-241. Reply :  sadness.
# Predict ke-242. Reply :  joy
# Predict ke-243. Reply :  joy.
# Predict ke-244. Reply :  other.
# Predict ke-245. Reply :  other
# Predict ke-246. Reply :  other.
# Predict ke-247. Reply :  love.
# Predict ke-248. Reply :  love.
# Predict ke-249. Reply :  other
# Predict ke-250. Reply :  joy.
# Predict ke-251. Reply :  sadness.
# Predict ke-252. Reply :  other
# Predict ke-253. Reply :  other
# Predict ke-254. Reply :  joy
# Predict ke-255. Reply :  other.
# Predict ke-256. Reply :  other.
# Predict ke-257. Reply :  joy.
# Predict ke-258. Reply :  joy.
# Predict ke-259. Reply :  other
# Predict ke-260. Reply :  other
# Predict ke-261. Reply :  other
# Predict ke-262. Reply :  other
# Predict ke-263. Reply :  sadness
# Predict ke-264. Reply :  joy
# Error: 400 - {"error":"Trying to keep the first 9962 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-266. Reply :  other.
# Predict ke-267. Reply :  other.
# Predict ke-268. Reply :  other.
# Predict ke-269. Reply :  other.
# Predict ke-270. Reply :  joy
# Predict ke-271. Reply :  joy.
# Predict ke-272. Reply :  hope.
# Predict ke-273. Reply :  hope
# Predict ke-274. Reply :  hope.
# Predict ke-275. Reply :  love
# Predict ke-276. Reply :  sadness.
# Predict ke-277. Reply :  sadness.
# Predict ke-278. Reply :  other.
# Predict ke-279. Reply :  other.
# Predict ke-280. Reply :  other.
# Predict ke-281. Reply :  other.
# Predict ke-282. Reply :  sadness
# Predict ke-283. Reply :  sad
# Predict ke-284. Reply :  sadness
# Predict ke-285. Reply :  sadness.
# Predict ke-286. Reply :  other.
# Predict ke-287. Reply :  joy
# Predict ke-288. Reply :  sadness.
# Predict ke-289. Reply :  joy.
# Predict ke-290. Reply :  hope.
# Predict ke-291. Reply :  hope
# Predict ke-292. Reply :  sad
# Predict ke-293. Reply :  other.
# Predict ke-294. Reply :  other.
# Predict ke-295. Reply :  hope.
# Predict ke-296. Reply :  sadness.
# Predict ke-297. Reply :  sadness
# Predict ke-298. Reply :  other
# Predict ke-299. Reply :  other
# Predict ke-300. Reply :  joy.
# Predict ke-301. Reply :  other
# Predict ke-302. Reply :  joy.
# Predict ke-303. Reply :  sadness.
# Predict ke-304. Reply :  love.
# Predict ke-305. Reply :  sadness.
# Predict ke-306. Reply :  joy.
# Error: 400 - {"error":"Trying to keep the first 27387 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-308. Reply :  other.
# Predict ke-309. Reply :  other.
# Predict ke-310. Reply :  sadness.
# Predict ke-311. Reply :  other.
# Predict ke-312. Reply :  other.
# Predict ke-313. Reply :  joy.
# Predict ke-314. Reply :  hope.
# Predict ke-315. Reply :  other.
# Predict ke-316. Reply :  other
# Predict ke-317. Reply :  joy
# Predict ke-318. Reply :  sadness.
# Predict ke-319. Reply :  joy.
# Predict ke-320. Reply :  hope.
# Predict ke-321. Reply :  hope.
# Predict ke-322. Reply :  sadness
# Predict ke-323. Reply :  other.
# Predict ke-324. Reply :  other
# Predict ke-325. Reply :  joy.
# Predict ke-326. Reply :  other
# Predict ke-327. Reply :  other.
# Predict ke-328. Reply :  sadness.
# Predict ke-329. Reply :  joy.
# Predict ke-330. Reply :  joy.
# Predict ke-331. Reply :  joy.
# Predict ke-332. Reply :  joy.
# Predict ke-333. Reply :  other
# Predict ke-334. Reply :  other
# Predict ke-335. Reply :  joy.
# Predict ke-336. Reply :  melancholy
# Predict ke-337. Reply :  hope
# Predict ke-338. Reply :  hope.
# Predict ke-339. Reply :  other.
# Predict ke-340. Reply :  other
# Predict ke-341. Reply :  hope.
# Predict ke-342. Reply :  sad
# Predict ke-343. Reply :  hope.
# Predict ke-344. Reply :  hope.
# Predict ke-345. Reply :  joy
# Predict ke-346. Reply :  other
# Predict ke-347. Reply :  other
# Predict ke-348. Reply :  sadness
# Predict ke-349. Reply :  sadness
# Predict ke-350. Reply :  other
# Predict ke-351. Reply :  other.
# Predict ke-352. Reply :  other.
# Predict ke-353. Reply :  joy
# Predict ke-354. Reply :  joy.
# Predict ke-355. Reply :  other.
# Predict ke-356. Reply :  joy.
# Predict ke-357. Reply :  joy.
# Predict ke-358. Reply :  joy.
# Predict ke-359. Reply :  other.
# Predict ke-360. Reply :  other.
# Predict ke-361. Reply :  love.
# Predict ke-362. Reply :  sadness.
# Predict ke-363. Reply :  other
# Predict ke-364. Reply :  sadness.
# Predict ke-365. Reply :  other.
# Predict ke-366. Reply :  hope.
# Predict ke-367. Reply :  hope.
# Predict ke-368. Reply :  other.
# Predict ke-369. Reply :  love
# Predict ke-370. Reply :  love
# Predict ke-371. Reply :  hope
# Predict ke-372. Reply :  other
# Predict ke-373. Reply :  joy.
# Predict ke-374. Reply :  love
# Predict ke-375. Reply :  sadness.
# Predict ke-376. Reply :  sad
# Predict ke-377. Reply :  sadness
# Predict ke-378. Reply :  sadness
# Predict ke-379. Reply :  sadness.
# Predict ke-380. Reply :  other.
# Predict ke-381. Reply :  other
# Predict ke-382. Reply :  joy.
# Predict ke-383. Reply :  sadness
# Predict ke-384. Reply :  other.
# Predict ke-385. Reply :  other
# Predict ke-386. Reply :  love.
# Predict ke-387. Reply :  other
# Predict ke-388. Reply :  sadness
# Predict ke-389. Reply :  other
# Predict ke-390. Reply :  joy.
# Predict ke-391. Reply :  joy.
# Predict ke-392. Reply :  sadness.
# Predict ke-393. Reply :  hope.
# Predict ke-394. Reply :  other.
# Predict ke-395. Reply :  sadness
# Predict ke-396. Reply :  hope.
# Predict ke-397. Reply :  love
# Predict ke-398. Reply :  sadness.
# Predict ke-399. Reply :  joy.
# Predict ke-400. Reply :  other.
# Predict ke-401. Reply :  joy
# Predict ke-402. Reply :  other.
# Predict ke-403. Reply :  sadness
# Predict ke-404. Reply :  other.
# Predict ke-405. Reply :  sad
# Predict ke-406. Reply :  sadness.
# Predict ke-407. Reply :  hope.
# Predict ke-408. Reply :  joy.
# Predict ke-409. Reply :  other.
# Predict ke-410. Reply :  joy.
# Predict ke-411. Reply :  sadness
# Predict ke-412. Reply :  hope.
# Predict ke-413. Reply :  other.
# Predict ke-414. Reply :  love.
# Predict ke-415. Reply :  hope.
# Predict ke-416. Reply :  hope.
# Predict ke-417. Reply :  other
# Predict ke-418. Reply :  other
# Predict ke-419. Reply :  other
# Predict ke-420. Reply :  hope
# Predict ke-421. Reply :  sadness.
# Predict ke-422. Reply :  love.
# Predict ke-423. Reply :  other.
# Predict ke-424. Reply :  sadness.
# Predict ke-425. Reply :  joy.
# Predict ke-426. Reply :  joy
# Predict ke-427. Reply :  other.
# Predict ke-428. Reply :  joy.
# Predict ke-429. Reply :  other.
# Predict ke-430. Reply :  joy
# Predict ke-431. Reply :  sadness
# Predict ke-432. Reply :  sadness
# Predict ke-433. Reply :  joy.
# Predict ke-434. Reply :  sadness.
# Predict ke-435. Reply :  other
# Predict ke-436. Reply :  other.
# Predict ke-437. Reply :  joy.
# Predict ke-438. Reply :  hope.
# Predict ke-439. Reply :  hope
# Predict ke-440. Reply :  other
# Predict ke-441. Reply :  sadness.
# Predict ke-442. Reply :  joy.
# Predict ke-443. Reply :  other
# Predict ke-444. Reply :  hope
# Predict ke-445. Reply :  joy.
# Predict ke-446. Reply :  other.
# Predict ke-447. Reply :  joy
# Predict ke-448. Reply :  sadness
# Predict ke-449. Reply :  hope.
# Predict ke-450. Reply :  other.
# Predict ke-451. Reply :  sad
# Predict ke-452. Reply :  joy.
# Predict ke-453. Reply :  sad
# Predict ke-454. Reply :  hope
# Predict ke-455. Reply :  joy
# Predict ke-456. Reply :  sadness
# Predict ke-457. Reply :  other.
# Predict ke-458. Reply :  joy.
# Predict ke-459. Reply :  joy
# Predict ke-460. Reply :  sadness.
# Predict ke-461. Reply :  joy.
# Predict ke-462. Reply :  other.
# Predict ke-463. Reply :  sadness
# Predict ke-464. Reply :  other.
# Predict ke-465. Reply :  sadness
# Predict ke-466. Reply :  hope.
# Predict ke-467. Reply :  sadness
# Predict ke-468. Reply :  joy
# Predict ke-469. Reply :  joy.
# Predict ke-470. Reply :  other.
# Predict ke-471. Reply :  joy.
# Predict ke-472. Reply :  hope.
# Predict ke-473. Reply :  other.
# Predict ke-474. Reply :  joy.
# Predict ke-475. Reply :  love.
# Predict ke-476. Reply :  other
# Predict ke-477. Reply :  hope.
# Error: 400 - {"error":"Trying to keep the first 15073 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-479. Reply :  love.
# Predict ke-480. Reply :  love.
# Predict ke-481. Reply :  sadness.
# Predict ke-482. Reply :  love.
# Predict ke-483. Reply :  sadness.
# Predict ke-484. Reply :  joy
# Predict ke-485. Reply :  sadness
# Predict ke-486. Reply :  sadness
# Predict ke-487. Reply :  joy.
# Predict ke-488. Reply :  other
# Predict ke-489. Reply :  joy.
# Predict ke-490. Reply :  hope.
# Predict ke-491. Reply :  joy
# Predict ke-492. Reply :  joy.
# Predict ke-493. Reply :  sadness
# Predict ke-494. Reply :  hope
# Predict ke-495. Reply :  hope
# Predict ke-496. Reply :  other
# Predict ke-497. Reply :  love.
# Predict ke-498. Reply :  other.
# Predict ke-499. Reply :  joy.
# Predict ke-500. Reply :  sadness.
# Predict ke-501. Reply :  sadness.
# Predict ke-502. Reply :  sadness.
# Predict ke-503. Reply :  joy.
# Predict ke-504. Reply :  other
# Predict ke-505. Reply :  sadness.
# Predict ke-506. Reply :  other.
# Predict ke-507. Reply :  joy
# Predict ke-508. Reply :  other.
# Predict ke-509. Reply :  sadness.
# Predict ke-510. Reply :  joy.
# Predict ke-511. Reply :  hope.
# Predict ke-512. Reply :  other
# Predict ke-513. Reply :  hope.
# Predict ke-514. Reply :  hope.
# Predict ke-515. Reply :  joy
# Predict ke-516. Reply :  sadness
# Predict ke-517. Reply :  hope.
# Predict ke-518. Reply :  other
# Predict ke-519. Reply :  hope.
# Predict ke-520. Reply :  sad
# Predict ke-521. Reply :  other
# Predict ke-522. Reply :  joy
# Predict ke-523. Reply :  other
# Predict ke-524. Reply :  hope.
# Predict ke-525. Reply :  joy
# Predict ke-526. Reply :  sadness
# Predict ke-527. Reply :  joy.
# Predict ke-528. Reply :  joy.
# Predict ke-529. Reply :  joy.
# Predict ke-530. Reply :  joy
# Predict ke-531. Reply :  sadness
# Predict ke-532. Reply :  joy.
# Predict ke-533. Reply :  other.
# Predict ke-534. Reply :  sadness.
# Predict ke-535. Reply :  hope.
# Predict ke-536. Reply :  sadness.
# Predict ke-537. Reply :  joy.
# Predict ke-538. Reply :  other
# Predict ke-539. Reply :  joy.
# Predict ke-540. Reply :  love.
# Predict ke-541. Reply :  other
# Predict ke-542. Reply :  sadness
# Predict ke-543. Reply :  hope.
# Predict ke-544. Reply :  joy
# Predict ke-545. Reply :  other.
# Predict ke-546. Reply :  love.
# Predict ke-547. Reply :  sadness.
# Predict ke-548. Reply :  other.
# Predict ke-549. Reply :  sadness.
# Predict ke-550. Reply :  hope.
# Predict ke-551. Reply :  hope
# Predict ke-552. Reply :  other
# Predict ke-553. Reply :  hope.
# Predict ke-554. Reply :  sadness.
# Predict ke-555. Reply :  joy.
# Predict ke-556. Reply :  other
# Predict ke-557. Reply :  sadness
# Predict ke-558. Reply :  joy.
# Predict ke-559. Reply :  love.
# Predict ke-560. Reply :  sadness.
# Predict ke-561. Reply :  joy
# Predict ke-562. Reply :  love.
# Predict ke-563. Reply :  hope.
# Predict ke-564. Reply :  sadness.
# Predict ke-565. Reply :  sadness
# Predict ke-566. Reply :  sadness.
# Predict ke-567. Reply :  sadness
# Predict ke-568. Reply :  joy.
# Predict ke-569. Reply :  other.
# Predict ke-570. Reply :  other.
# Predict ke-571. Reply :  sadness.
# Predict ke-572. Reply :  other
# Error: 400 - {"error":"Trying to keep the first 8871 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-574. Reply :  other.
# Predict ke-575. Reply :  other.
# Predict ke-576. Reply :  other.
# Predict ke-577. Reply :  joy
# Predict ke-578. Reply :  sadness.
# Predict ke-579. Reply :  hope
# Predict ke-580. Reply :  hope.
# Predict ke-581. Reply :  love
# Predict ke-582. Reply :  hope.
# Predict ke-583. Reply :  hope
# Predict ke-584. Reply :  joy
# Predict ke-585. Reply :  sadness.
# Predict ke-586. Reply :  hope.
# Predict ke-587. Reply :  other.
# Predict ke-588. Reply :  joy.
# Predict ke-589. Reply :  other
# Predict ke-590. Reply :  other.
# Predict ke-591. Reply :  other.
# Predict ke-592. Reply :  hope.
# Predict ke-593. Reply :  hope.
# Error: 400 - {"error":"Trying to keep the first 12771 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-595. Reply :  other.
# Predict ke-596. Reply :  other
# Predict ke-597. Reply :  joy
# Predict ke-598. Reply :  other.
# Predict ke-599. Reply :  joy.
# Predict ke-600. Reply :  sadness
# Predict ke-601. Reply :  joy.
# Predict ke-602. Reply :  other.
# Predict ke-603. Reply :  sadness
# Predict ke-604. Reply :  joy.
# Predict ke-605. Reply :  other.
# Predict ke-606. Reply :  sadness
# Predict ke-607. Reply :  joy
# Predict ke-608. Reply :  hope.
# Predict ke-609. Reply :  love
# Predict ke-610. Reply :  other.
# Predict ke-611. Reply :  sadness.
# Predict ke-612. Reply :  hope
# Predict ke-613. Reply :  other
# Predict ke-614. Reply :  other.
# Predict ke-615. Reply :  sadness
# Predict ke-616. Reply :  joy.
# Predict ke-617. Reply :  sadness
# Predict ke-618. Reply :  joy
# Predict ke-619. Reply :  other
# Predict ke-620. Reply :  hope
# Predict ke-621. Reply :  love
# Predict ke-622. Reply :  joy.
# Predict ke-623. Reply :  other.
# Predict ke-624. Reply :  joy
# Predict ke-625. Reply :  sadness.
# Predict ke-626. Reply :  other.
# Predict ke-627. Reply :  other.
# Predict ke-628. Reply :  joy.
# Predict ke-629. Reply :  joy.
# Predict ke-630. Reply :  joy.
# Predict ke-631. Reply :  other.
# Error: 400 - {"error":"Trying to keep the first 17071 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-633. Reply :  joy.
# Predict ke-634. Reply :  love
# Predict ke-635. Reply :  hope
# Predict ke-636. Reply :  sadness
# Predict ke-637. Reply :  love
# Predict ke-638. Reply :  hope.
# Predict ke-639. Reply :  hope.
# Predict ke-640. Reply :  love.
# Predict ke-641. Reply :  other
# Predict ke-642. Reply :  other.
# Predict ke-643. Reply :  sadness
# Predict ke-644. Reply :  joy.
# Predict ke-645. Reply :  joy.
# Predict ke-646. Reply :  joy.
# Predict ke-647. Reply :  hope.
# Predict ke-648. Reply :  joy.
# Predict ke-649. Reply :  hope
# Predict ke-650. Reply :  other.
# Predict ke-651. Reply :  sad
# Predict ke-652. Reply :  other.
# Predict ke-653. Reply :  sadness
# Predict ke-654. Reply :  other
# Predict ke-655. Reply :  joy.
# Predict ke-656. Reply :  hope.
# Predict ke-657. Reply :  sorrow
# Predict ke-658. Reply :  sadness.
# Predict ke-659. Reply :  joy.
# Predict ke-660. Reply :  joy
# Predict ke-661. Reply :  sad
# Predict ke-662. Reply :  other
# Predict ke-663. Reply :  hope.
# Predict ke-664. Reply :  sadness
# Predict ke-665. Reply :  love.
# Predict ke-666. Reply :  sadness
# Predict ke-667. Reply :  other.
# Predict ke-668. Reply :  hope.
# Predict ke-669. Reply :  sadness
# Predict ke-670. Reply :  sadness.
# Predict ke-671. Reply :  joy.
# Predict ke-672. Reply :  sadness
# Predict ke-673. Reply :  other.
# Predict ke-674. Reply :  joy.
# Predict ke-675. Reply :  love
# Predict ke-676. Reply :  other.
# Predict ke-677. Reply :  sadness
# Predict ke-678. Reply :  joy
# Predict ke-679. Reply :  joy
# Predict ke-680. Reply :  other.
# Predict ke-681. Reply :  other
# Predict ke-682. Reply :  hope
# Predict ke-683. Reply :  love
# Predict ke-684. Reply :  hope
# Predict ke-685. Reply :  sadness
# Predict ke-686. Reply :  sadness.
# Predict ke-687. Reply :  sadness.
# Predict ke-688. Reply :  other.
# Predict ke-689. Reply :  hope.
# Predict ke-690. Reply :  sadness
# Predict ke-691. Reply :  other.
# Predict ke-692. Reply :  hope.
# Predict ke-693. Reply :  sadness
# Predict ke-694. Reply :  hope
# Predict ke-695. Reply :  other
# Predict ke-696. Reply :  hope.
# Predict ke-697. Reply :  sadness
# Predict ke-698. Reply :  other.
# Predict ke-699. Reply :  joy.
# Predict ke-700. Reply :  hope
# Predict ke-701. Reply :  joy.
# Predict ke-702. Reply :  other
# Predict ke-703. Reply :  joy.
# Predict ke-704. Reply :  hope.
# Predict ke-705. Reply :  sadness
# Predict ke-706. Reply :  joy.
# Predict ke-707. Reply :  sadness
# Predict ke-708. Reply :  hope.
# Predict ke-709. Reply :  joy.
# Predict ke-710. Reply :  hope
# Predict ke-711. Reply :  sadness
# Predict ke-712. Reply :  sadness
# Predict ke-713. Reply :  other.
# Predict ke-714. Reply :  joy
# Predict ke-715. Reply :  hope.
# Predict ke-716. Reply :  sadness.
# Predict ke-717. Reply :  other
# Predict ke-718. Reply :  sadness
# Predict ke-719. Reply :  hope.
# Predict ke-720. Reply :  sadness
# Predict ke-721. Reply :  other
# Predict ke-722. Reply :  sadness.
# Predict ke-723. Reply :  other.
# Predict ke-724. Reply :  sadness.
# Predict ke-725. Reply :  love
# Predict ke-726. Reply :  sadness
# Predict ke-727. Reply :  other
# Predict ke-728. Reply :  sadness
# Predict ke-729. Reply :  joy.
# Predict ke-730. Reply :  joy.
# Predict ke-731. Reply :  sadness.
# Predict ke-732. Reply :  sadness.
# Predict ke-733. Reply :  other
# Predict ke-734. Reply :  hope.
# Predict ke-735. Reply :  joy.
# Predict ke-736. Reply :  other
# Predict ke-737. Reply :  hope.
# Predict ke-738. Reply :  sadness.
# Predict ke-739. Reply :  hope.
# Predict ke-740. Reply :  other.
# Predict ke-741. Reply :  joy.
# Predict ke-742. Reply :  hope
# Predict ke-743. Reply :  other
# Predict ke-744. Reply :  other.
# Predict ke-745. Reply :  sadness
# Predict ke-746. Reply :  joy.
# Predict ke-747. Reply :  love
# Predict ke-748. Reply :  sadness
# Predict ke-749. Reply :  other.
# Predict ke-750. Reply :  hope
# Predict ke-751. Reply :  sadness
# Error: 400 - {"error":"Trying to keep the first 8253 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-753. Reply :  love.
# Predict ke-754. Reply :  joy.
# Predict ke-755. Reply :  joy.
# Predict ke-756. Reply :  joy.
# Predict ke-757. Reply :  joy
# Predict ke-758. Reply :  hope
# Predict ke-759. Reply :  other.
# Predict ke-760. Reply :  hope.
# Predict ke-761. Reply :  other
# Predict ke-762. Reply :  sadness
# Predict ke-763. Reply :  sadness.
# Predict ke-764. Reply :  joy
# Predict ke-765. Reply :  sadness.
# Predict ke-766. Reply :  love.
# Predict ke-767. Reply :  joy
# Predict ke-768. Reply :  joy.
# Predict ke-769. Reply :  hope.
# Predict ke-770. Reply :  love.
# Predict ke-771. Reply :  other.
# Predict ke-772. Reply :  joy.
# Predict ke-773. Reply :  sadness.
# Predict ke-774. Reply :  sadness.
# Predict ke-775. Reply :  other.
# Predict ke-776. Reply :  joy.
# Predict ke-777. Reply :  joy.
# Predict ke-778. Reply :  joy.
# Predict ke-779. Reply :  joy.
# Predict ke-780. Reply :  sadness.
# Predict ke-781. Reply :  other
# Predict ke-782. Reply :  other.
# Predict ke-783. Reply :  joy.
# Predict ke-784. Reply :  joy.
# Predict ke-785. Reply :  other
# Predict ke-786. Reply :  scunge
# Predict ke-787. Reply :  love.
# Predict ke-788. Reply :  other
# Predict ke-789. Reply :  other
# Predict ke-790. Reply :  other.
# Predict ke-791. Reply :  sadness.
# Predict ke-792. Reply :  sadness
# Predict ke-793. Reply :  hope.
# Predict ke-794. Reply :  other
# Predict ke-795. Reply :  sadness
# Predict ke-796. Reply :  sadness
# Predict ke-797. Reply :  other
# Predict ke-798. Reply :  hope.
# Predict ke-799. Reply :  hope.
# Predict ke-800. Reply :  other.
# Predict ke-801. Reply :  other
# Predict ke-802. Reply :  sadness
# Predict ke-803. Reply :  other
# Error: 400 - {"error":"Trying to keep the first 5391 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-805. Reply :  sadness
# Predict ke-806. Reply :  love
# Predict ke-807. Reply :  sadness.
# Predict ke-808. Reply :  other
# Predict ke-809. Reply :  sadness
# Predict ke-810. Reply :  sadness
# Predict ke-811. Reply :  other.
# Predict ke-812. Reply :  other
# Predict ke-813. Reply :  other
# Predict ke-814. Reply :  other.
# Predict ke-815. Reply :  sadness.
# Predict ke-816. Reply :  other.
# Predict ke-817. Reply :  love.
# Predict ke-818. Reply :  other.
# Predict ke-819. Reply :  hope.
# Predict ke-820. Reply :  sadness
# Predict ke-821. Reply :  joy
# Predict ke-822. Reply :  joy
# Predict ke-823. Reply :  sadness
# Predict ke-824. Reply :  sadness
# Predict ke-825. Reply :  sad
# Predict ke-826. Reply :  joy.
# Predict ke-827. Reply :  sad
# Predict ke-828. Reply :  hope.
# Predict ke-829. Reply :  joy.
# Predict ke-830. Reply :  joy.
# Predict ke-831. Reply :  joy.
# Predict ke-832. Reply :  joy.
# Predict ke-833. Reply :  joy.
# Predict ke-834. Reply :  other.
# Predict ke-835. Reply :  other.
# Predict ke-836. Reply :  joy.
# Predict ke-837. Reply :  other
# Predict ke-838. Reply :  hope.
# Predict ke-839. Reply :  other.
# Predict ke-840. Reply :  sadness.
# Predict ke-841. Reply :  other.
# Predict ke-842. Reply :  other
# Predict ke-843. Reply :  sadness
# Predict ke-844. Reply :  other.
# Predict ke-845. Reply :  other
# Predict ke-846. Reply :  other.
# Predict ke-847. Reply :  love
# Predict ke-848. Reply :  other
# Predict ke-849. Reply :  other.
# Predict ke-850. Reply :  other.
# Predict ke-851. Reply :  joy.
# Predict ke-852. Reply :  joy
# Predict ke-853. Reply :  hope.
# Predict ke-854. Reply :  hope.
# Predict ke-855. Reply :  hope.
# Predict ke-856. Reply :  hope.
# Predict ke-857. Reply :  love
# Predict ke-858. Reply :  other
# Predict ke-859. Reply :  love.
# Predict ke-860. Reply :  other.
# Predict ke-861. Reply :  joy.
# Predict ke-862. Reply :  sadness
# Predict ke-863. Reply :  other
# Predict ke-864. Reply :  sadness
# Predict ke-865. Reply :  sadness
# Predict ke-866. Reply :  hope.
# Predict ke-867. Reply :  other.
# Predict ke-868. Reply :  other.
# Predict ke-869. Reply :  other.
# Predict ke-870. Reply :  sadness.
# Predict ke-871. Reply :  joy
# Predict ke-872. Reply :  sadness.
# Predict ke-873. Reply :  other
# Predict ke-874. Reply :  sadness.
# Predict ke-875. Reply :  sadness.
# Predict ke-876. Reply :  joy.
# Predict ke-877. Reply :  sadness
# Predict ke-878. Reply :  sad
# Predict ke-879. Reply :  other.
# Predict ke-880. Reply :  other.
# Predict ke-881. Reply :  joy.
# Predict ke-882. Reply :  sadness
# Predict ke-883. Reply :  other.
# Predict ke-884. Reply :  joy
# Predict ke-885. Reply :  sadness
# Predict ke-886. Reply :  sadness.
# Predict ke-887. Reply :  joy.
# Predict ke-888. Reply :  other.
# Predict ke-889. Reply :  joy.
# Predict ke-890. Reply :  joy
# Predict ke-891. Reply :  sadness
# Predict ke-892. Reply :  hope.
# Predict ke-893. Reply :  joy.
# Predict ke-894. Reply :  sadness
# Predict ke-895. Reply :  other.
# Predict ke-896. Reply :  hope.
# Predict ke-897. Reply :  joy.
# Predict ke-898. Reply :  sad
# Predict ke-899. Reply :  joy
# Predict ke-900. Reply :  joy
# Predict ke-901. Reply :  sadness.
# Predict ke-902. Reply :  other.
# Predict ke-903. Reply :  other.
# Predict ke-904. Reply :  other.
# Predict ke-905. Reply :  other.
# Predict ke-906. Reply :  hope.
# Predict ke-907. Reply :  joy.
# Predict ke-908. Reply :  joy
# Predict ke-909. Reply :  joy.
# Predict ke-910. Reply :  sadness.
# Predict ke-911. Reply :  joy.
# Predict ke-912. Reply :  other.
# Error: 400 - {"error":"Trying to keep the first 8131 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-914. Reply :  hope.
# Predict ke-915. Reply :  other
# Predict ke-916. Reply :  sad
# Predict ke-917. Reply :  hope.
# Predict ke-918. Reply :  joy
# Predict ke-919. Reply :  other.
# Predict ke-920. Reply :  hope.
# Predict ke-921. Reply :  sad
# Predict ke-922. Reply :  hope
# Predict ke-923. Reply :  other.
# Predict ke-924. Reply :  hope.
# Predict ke-925. Reply :  other
# Predict ke-926. Reply :  hope.
# Predict ke-927. Reply :  sadness.
# Predict ke-928. Reply :  sadness
# Predict ke-929. Reply :  hope
# Predict ke-930. Reply :  sadness.
# Predict ke-931. Reply :  joy.
# Predict ke-932. Reply :  other
# Predict ke-933. Reply :  sadness.
# Predict ke-934. Reply :  love
# Predict ke-935. Reply :  other.
# Predict ke-936. Reply :  love.
# Predict ke-937. Reply :  joy
# Predict ke-938. Reply :  love.
# Predict ke-939. Reply :  other
# Predict ke-940. Reply :  sadness.
# Predict ke-941. Reply :  joy
# Predict ke-942. Reply :  joy.
# Predict ke-943. Reply :  sadness
# Predict ke-944. Reply :  love.
# Predict ke-945. Reply :  other.
# Predict ke-946. Reply :  sad
# Predict ke-947. Reply :  other.
# Predict ke-948. Reply :  sadness
# Predict ke-949. Reply :  other
# Predict ke-950. Reply :  joy
# Predict ke-951. Reply :  other.
# Predict ke-952. Reply :  other.
# Predict ke-953. Reply :  joy.
# Predict ke-954. Reply :  joy
# Predict ke-955. Reply :  joy.
# Predict ke-956. Reply :  joy.
# Predict ke-957. Reply :  other
# Predict ke-958. Reply :  joy.
# Predict ke-959. Reply :  hope
# Predict ke-960. Reply :  sadness
# Predict ke-961. Reply :  hope.
# Predict ke-962. Reply :  other.
# Predict ke-963. Reply :  joy
# Predict ke-964. Reply :  sadness.
# Predict ke-965. Reply :  joy.
# Predict ke-966. Reply :  joy
# Predict ke-967. Reply :  sadness
# Predict ke-968. Reply :  joy
# Predict ke-969. Reply :  sadness
# Predict ke-970. Reply :  joy
# Predict ke-971. Reply :  hope.
# Predict ke-972. Reply :  sadness
# Predict ke-973. Reply :  joy.
# Predict ke-974. Reply :  hope.
# Predict ke-975. Reply :  joy
# Predict ke-976. Reply :  other
# Predict ke-977. Reply :  sadness
# Predict ke-978. Reply :  other.
# Predict ke-979. Reply :  other
# Predict ke-980. Reply :  sadness.
# Predict ke-981. Reply :  sadness
# Predict ke-982. Reply :  love.
# Predict ke-983. Reply :  love
# Predict ke-984. Reply :  other.
# Predict ke-985. Reply :  joy
# Predict ke-986. Reply :  sadness.
# Predict ke-987. Reply :  hope
# Predict ke-988. Reply :  joy.
# Predict ke-989. Reply :  other.
# Predict ke-990. Reply :  other.
# Predict ke-991. Reply :  other
# Predict ke-992. Reply :  other.
# Predict ke-993. Reply :  other.
# Predict ke-994. Reply :  other.
# Predict ke-995. Reply :  sad
# Predict ke-996. Reply :  hope.
# Predict ke-997. Reply :  other.
# Predict ke-998. Reply :  joy
# Predict ke-999. Reply :  other
# Predict ke-1000. Reply :  other
# Predict ke-1001. Reply :  joy
# Predict ke-1002. Reply :  hope.
# Predict ke-1003. Reply :  joy.
# Predict ke-1004. Reply :  love.
# Predict ke-1005. Reply :  joy.
# Predict ke-1006. Reply :  joy
# Predict ke-1007. Reply :  sad
# Predict ke-1008. Reply :  other.
# Predict ke-1009. Reply :  sad
# Predict ke-1010. Reply :  other
# Predict ke-1011. Reply :  sadness
# Predict ke-1012. Reply :  other
# Predict ke-1013. Reply :  sadness.
# Predict ke-1014. Reply :  other
# Predict ke-1015. Reply :  other
# Predict ke-1016. Reply :  other.
# Predict ke-1017. Reply :  hope.
# Predict ke-1018. Reply :  sadness.
# Predict ke-1019. Reply :  love
# Predict ke-1020. Reply :  hope.
# Predict ke-1021. Reply :  hope.
# Predict ke-1022. Reply :  sadness
# Predict ke-1023. Reply :  hope.
# Predict ke-1024. Reply :  joy.
# Predict ke-1025. Reply :  other
# Predict ke-1026. Reply :  other
# Predict ke-1027. Reply :  other.
# Predict ke-1028. Reply :  anger
# Predict ke-1029. Reply :  sadness.
# Predict ke-1030. Reply :  joy
# Predict ke-1031. Reply :  sadness
# Predict ke-1032. Reply :  joy.
# Predict ke-1033. Reply :  hope.
# Predict ke-1034. Reply :  other.
# Predict ke-1035. Reply :  joy.
# Predict ke-1036. Reply :  other
# Predict ke-1037. Reply :  sadness
# Predict ke-1038. Reply :  love.
# Predict ke-1039. Reply :  hope
# Predict ke-1040. Reply :  hope.
# Predict ke-1041. Reply :  other
# Predict ke-1042. Reply :  other
# Predict ke-1043. Reply :  hope
# Predict ke-1044. Reply :  hope.
# Predict ke-1045. Reply :  hope.
# Predict ke-1046. Reply :  other.
# Predict ke-1047. Reply :  joy.
# Predict ke-1048. Reply :  hope
# Predict ke-1049. Reply :  joy.
# Predict ke-1050. Reply :  hope.
# Predict ke-1051. Reply :  other.
# Predict ke-1052. Reply :  sadness
# Predict ke-1053. Reply :  joy.
# Predict ke-1054. Reply :  sadness.
# Predict ke-1055. Reply :  love
# Predict ke-1056. Reply :  other
# Predict ke-1057. Reply :  other.
# Predict ke-1058. Reply :  other
# Predict ke-1059. Reply :  other.
# Predict ke-1060. Reply :  sadness
# Predict ke-1061. Reply :  other
# Predict ke-1062. Reply :  other
# Predict ke-1063. Reply :  other
# Predict ke-1064. Reply :  other.
# Predict ke-1065. Reply :  other
# Predict ke-1066. Reply :  sadness.
# Predict ke-1067. Reply :  sadness
# Predict ke-1068. Reply :  other.
# Predict ke-1069. Reply :  sadness
# Predict ke-1070. Reply :  other
# Predict ke-1071. Reply :  hope.
# Predict ke-1072. Reply :  joy
# Predict ke-1073. Reply :  sadness.
# Predict ke-1074. Reply :  other.
# Predict ke-1075. Reply :  love
# Predict ke-1076. Reply :  other
# Predict ke-1077. Reply :  other.
# Predict ke-1078. Reply :  hope.
# Predict ke-1079. Reply :  love
# Predict ke-1080. Reply :  sadness
# Predict ke-1081. Reply :  cat
# Predict ke-1082. Reply :  sadness
# Predict ke-1083. Reply :  sadness
# Predict ke-1084. Reply :  other
# Predict ke-1085. Reply :  other
# Predict ke-1086. Reply :  joy.
# Predict ke-1087. Reply :  hope.
# Predict ke-1088. Reply :  joy
# Predict ke-1089. Reply :  other
# Predict ke-1090. Reply :  sadness
# Predict ke-1091. Reply :  love.
# Predict ke-1092. Reply :  sadness
# Predict ke-1093. Reply :  other
# Predict ke-1094. Reply :  joy.
# Predict ke-1095. Reply :  sadness.
# Predict ke-1096. Reply :  other.
# Predict ke-1097. Reply :  sadness.
# Error: 400 - {"error":"Trying to keep the first 10851 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-1099. Reply :  hope.
# Predict ke-1100. Reply :  love.
# Predict ke-1101. Reply :  joy.
# Predict ke-1102. Reply :  joy.
# Predict ke-1103. Reply :  other.
# Predict ke-1104. Reply :  other
# Predict ke-1105. Reply :  joy.
# Predict ke-1106. Reply :  sadness.
# Predict ke-1107. Reply :  sadness
# Predict ke-1108. Reply :  other.
# Predict ke-1109. Reply :  sadness.
# Predict ke-1110. Reply :  love.
# Predict ke-1111. Reply :  hope.
# Predict ke-1112. Reply :  other.
# Predict ke-1113. Reply :  joy
# Predict ke-1114. Reply :  sadness
# Predict ke-1115. Reply :  love
# Predict ke-1116. Reply :  other.
# Predict ke-1117. Reply :  other.
# Predict ke-1118. Reply :  hope.
# Predict ke-1119. Reply :  other.
# Predict ke-1120. Reply :  joy.
# Predict ke-1121. Reply :  love.
# Predict ke-1122. Reply :  hope.
# Predict ke-1123. Reply :  hope.
# Predict ke-1124. Reply :  sadness.
# Predict ke-1125. Reply :  sadness.
# Predict ke-1126. Reply :  other.
# Predict ke-1127. Reply :  other.
# Predict ke-1128. Reply :  joy
# Predict ke-1129. Reply :  joy.
# Predict ke-1130. Reply :  joy
# Predict ke-1131. Reply :  sadness
# Predict ke-1132. Reply :  other.
# Predict ke-1133. Reply :  hope.
# Predict ke-1134. Reply :  joy.
# Predict ke-1135. Reply :  love.
# Predict ke-1136. Reply :  other
# Predict ke-1137. Reply :  hope
# Predict ke-1138. Reply :  sadness.
# Predict ke-1139. Reply :  other.
# Predict ke-1140. Reply :  joy
# Predict ke-1141. Reply :  sadness.
# Predict ke-1142. Reply :  sad
# Predict ke-1143. Reply :  love
# Predict ke-1144. Reply :  sadness
# Predict ke-1145. Reply :  other
# Predict ke-1146. Reply :  joy.
# Predict ke-1147. Reply :  hope.
# Predict ke-1148. Reply :  other.
# Predict ke-1149. Reply :  other.
# Predict ke-1150. Reply :  hope.
# Predict ke-1151. Reply :  hope.
# Predict ke-1152. Reply :  other.
# Predict ke-1153. Reply :  sadness.
# Predict ke-1154. Reply :  other
# Predict ke-1155. Reply :  hope.
# Predict ke-1156. Reply :  sadness
# Predict ke-1157. Reply :  joy
# Predict ke-1158. Reply :  hope.
# Predict ke-1159. Reply :  other
# Error: 400 - {"error":"Trying to keep the first 6276 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-1161. Reply :  hope.
# Predict ke-1162. Reply :  sadness
# Predict ke-1163. Reply :  hope.
# Predict ke-1164. Reply :  sadness
# Predict ke-1165. Reply :  other
# Predict ke-1166. Reply :  love.
# Predict ke-1167. Reply :  other.
# Predict ke-1168. Reply :  joy.
# Predict ke-1169. Reply :  hope.
# Predict ke-1170. Reply :  sadness.
# Predict ke-1171. Reply :  hope
# Predict ke-1172. Reply :  other
# Predict ke-1173. Reply :  other.
# Predict ke-1174. Reply :  sadness.
# Predict ke-1175. Reply :  sadness.
# Predict ke-1176. Reply :  other.
# Predict ke-1177. Reply :  joy.
# Predict ke-1178. Reply :  joy
# Predict ke-1179. Reply :  sadness.
# Predict ke-1180. Reply :  other.
# Predict ke-1181. Reply :  hope
# Predict ke-1182. Reply :  sadness.
# Predict ke-1183. Reply :  other
# Predict ke-1184. Reply :  other
# Predict ke-1185. Reply :  other
# Predict ke-1186. Reply :  joy.
# Predict ke-1187. Reply :  hope.
# Predict ke-1188. Reply :  sadness.
# Predict ke-1189. Reply :  other.
# Predict ke-1190. Reply :  other
# Predict ke-1191. Reply :  hope.
# Predict ke-1192. Reply :  love
# Error: 400 - {"error":"Trying to keep the first 12647 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-1194. Reply :  other.
# Predict ke-1195. Reply :  other
# Predict ke-1196. Reply :  other.
# Predict ke-1197. Reply :  joy
# Predict ke-1198. Reply :  other.
# Predict ke-1199. Reply :  joy.
# Predict ke-1200. Reply :  hope.
# Predict ke-1201. Reply :  other
# Predict ke-1202. Reply :  other.
# Predict ke-1203. Reply :  joy.
# Predict ke-1204. Reply :  other.
# Predict ke-1205. Reply :  joy.
# Predict ke-1206. Reply :  joy.
# Predict ke-1207. Reply :  hope.
# Predict ke-1208. Reply :  hope.
# Predict ke-1209. Reply :  sadness.
# Predict ke-1210. Reply :  other.
# Predict ke-1211. Reply :  other.
# Predict ke-1212. Reply :  sadness
# Predict ke-1213. Reply :  hope
# Predict ke-1214. Reply :  hope.
# Predict ke-1215. Reply :  joy
# Predict ke-1216. Reply :  sadness
# Predict ke-1217. Reply :  hope.
# Predict ke-1218. Reply :  other.
# Predict ke-1219. Reply :  other
# Predict ke-1220. Reply :  sadness
# Predict ke-1221. Reply :  sadness.
# Predict ke-1222. Reply :  other
# Predict ke-1223. Reply :  sadness
# Predict ke-1224. Reply :  hope.
# Predict ke-1225. Reply :  hope.
# Predict ke-1226. Reply :  joy.
# Predict ke-1227. Reply :  joy.
# Predict ke-1228. Reply :  hope.
# Predict ke-1229. Reply :  other
# Predict ke-1230. Reply :  other.
# Predict ke-1231. Reply :  other
# Predict ke-1232. Reply :  sadness
# Predict ke-1233. Reply :  sadness.
# Predict ke-1234. Reply :  joy
# Predict ke-1235. Reply :  love
# Predict ke-1236. Reply :  hope.
# Predict ke-1237. Reply :  other.
# Predict ke-1238. Reply :  other
# Predict ke-1239. Reply :  other
# Predict ke-1240. Reply :  other
# Predict ke-1241. Reply :  sadness
# Predict ke-1242. Reply :  other.
# Predict ke-1243. Reply :  love.
# Predict ke-1244. Reply :  sadness
# Predict ke-1245. Reply :  joy.
# Predict ke-1246. Reply :  other.
# Predict ke-1247. Reply :  joy.
# Predict ke-1248. Reply :  other.
# Predict ke-1249. Reply :  joy.
# Predict ke-1250. Reply :  love.
# Predict ke-1251. Reply :  sadness
# Predict ke-1252. Reply :  sadness.
# Predict ke-1253. Reply :  joy.
# Predict ke-1254. Reply :  other
# Predict ke-1255. Reply :  joy.
# Predict ke-1256. Reply :  other
# Predict ke-1257. Reply :  other
# Predict ke-1258. Reply :  other.
# Predict ke-1259. Reply :  sadness
# Predict ke-1260. Reply :  other
# Predict ke-1261. Reply :  sadness
# Predict ke-1262. Reply :  joy.
# Predict ke-1263. Reply :  joy.
# Predict ke-1264. Reply :  love.
# Predict ke-1265. Reply :  hope
# Predict ke-1266. Reply :  other.
# Predict ke-1267. Reply :  hope
# Predict ke-1268. Reply :  other.
# Predict ke-1269. Reply :  other.
# Predict ke-1270. Reply :  other
# Predict ke-1271. Reply :  love
# Predict ke-1272. Reply :  other.
# Predict ke-1273. Reply :  love.
# Predict ke-1274. Reply :  hope.
# Predict ke-1275. Reply :  other
# Predict ke-1276. Reply :  other.
# Predict ke-1277. Reply :  joy.
# Predict ke-1278. Reply :  other.
# Predict ke-1279. Reply :  joy
# Predict ke-1280. Reply :  hope
# Predict ke-1281. Reply :  hope.
# Predict ke-1282. Reply :  sadness.
# Predict ke-1283. Reply :  other
# Predict ke-1284. Reply :  love
# Predict ke-1285. Reply :  joy.
# Predict ke-1286. Reply :  joy
# Predict ke-1287. Reply :  hope
# Predict ke-1288. Reply :  love
# Predict ke-1289. Reply :  joy.
# Predict ke-1290. Reply :  love.
# Predict ke-1291. Reply :  other.
# Predict ke-1292. Reply :  hope.
# Predict ke-1293. Reply :  other
# Predict ke-1294. Reply :  love.
# Predict ke-1295. Reply :  sadness
# Predict ke-1296. Reply :  other.
# Predict ke-1297. Reply :  joy.
# Predict ke-1298. Reply :  love.
# Predict ke-1299. Reply :  other.
# Predict ke-1300. Reply :  love.
# Predict ke-1301. Reply :  other.
# Predict ke-1302. Reply :  sadness
# Predict ke-1303. Reply :  hope.
# Predict ke-1304. Reply :  joy
# Predict ke-1305. Reply :  sadness
# Predict ke-1306. Reply :  other.
# Predict ke-1307. Reply :  other.
# Predict ke-1308. Reply :  other.
# Predict ke-1309. Reply :  other.
# Predict ke-1310. Reply :  hope.
# Predict ke-1311. Reply :  joy.
# Predict ke-1312. Reply :  other.
# Predict ke-1313. Reply :  joy.
# Predict ke-1314. Reply :  other
# Predict ke-1315. Reply :  joy
# Predict ke-1316. Reply :  sadness.
# Predict ke-1317. Reply :  other
# Predict ke-1318. Reply :  hope
# Predict ke-1319. Reply :  sadness.
# Predict ke-1320. Reply :  sadness
# Predict ke-1321. Reply :  other.
# Predict ke-1322. Reply :  joy
# Predict ke-1323. Reply :  joy.
# Predict ke-1324. Reply :  hope
# Predict ke-1325. Reply :  sadness.
# Predict ke-1326. Reply :  hope.
# Predict ke-1327. Reply :  hope.
# Predict ke-1328. Reply :  other.
# Predict ke-1329. Reply :  love.
# Predict ke-1330. Reply :  joy
# Predict ke-1331. Reply :  sadness.
# Predict ke-1332. Reply :  love
# Predict ke-1333. Reply :  other
# Predict ke-1334. Reply :  joy.
# Predict ke-1335. Reply :  hope.
# Predict ke-1336. Reply :  other.
# Predict ke-1337. Reply :  other
# Predict ke-1338. Reply :  hope
# Predict ke-1339. Reply :  other.
# Predict ke-1340. Reply :  sadness.
# Predict ke-1341. Reply :  other
# Predict ke-1342. Reply :  joy
# Predict ke-1343. Reply :  other.
# Predict ke-1344. Reply :  other
# Predict ke-1345. Reply :  hope
# Predict ke-1346. Reply :  sadness
# Predict ke-1347. Reply :  love.
# Predict ke-1348. Reply :  hope.
# Predict ke-1349. Reply :  other.
# Predict ke-1350. Reply :  sadness.
# Predict ke-1351. Reply :  sadness.
# Predict ke-1352. Reply :  hope.
# Predict ke-1353. Reply :  love
# Predict ke-1354. Reply :  joy.
# Predict ke-1355. Reply :  sadness
# Predict ke-1356. Reply :  hope
# Predict ke-1357. Reply :  joy
# Predict ke-1358. Reply :  joy
# Predict ke-1359. Reply :  joy
# Predict ke-1360. Reply :  hope
# Predict ke-1361. Reply :  love.
# Predict ke-1362. Reply :  sadness
# Predict ke-1363. Reply :  joy.
# Predict ke-1364. Reply :  sadness
# Predict ke-1365. Reply :  sorrow
# Predict ke-1366. Reply :  love.
# Predict ke-1367. Reply :  sadness.
# Predict ke-1368. Reply :  sadness
# Predict ke-1369. Reply :  other
# Predict ke-1370. Reply :  other
# Predict ke-1371. Reply :  sadness.
# Predict ke-1372. Reply :  joy.
# Predict ke-1373. Reply :  sadness
# Predict ke-1374. Reply :  love
# Predict ke-1375. Reply :  hope.
# Predict ke-1376. Reply :  hope
# Predict ke-1377. Reply :  joy.
# Predict ke-1378. Reply :  joy.
# Predict ke-1379. Reply :  other
# Predict ke-1380. Reply :  hope.
# Predict ke-1381. Reply :  sadness
# Predict ke-1382. Reply :  hope.
# Predict ke-1383. Reply :  hope.
# Predict ke-1384. Reply :  other.
# Predict ke-1385. Reply :  sadness
# Predict ke-1386. Reply :  joy.
# Predict ke-1387. Reply :  joy
# Predict ke-1388. Reply :  sadness.
# Predict ke-1389. Reply :  joy.
# Predict ke-1390. Reply :  joy.
# Predict ke-1391. Reply :  joy.
# Predict ke-1392. Reply :  sad
# Predict ke-1393. Reply :  other
# Predict ke-1394. Reply :  other.
# Predict ke-1395. Reply :  joy
# Predict ke-1396. Reply :  other
# Predict ke-1397. Reply :  hope
# Predict ke-1398. Reply :  other
# Predict ke-1399. Reply :  hope.
# Predict ke-1400. Reply :  joy.
# Predict ke-1401. Reply :  sad
# Predict ke-1402. Reply :  joy
# Predict ke-1403. Reply :  joy
# Predict ke-1404. Reply :  hope.
# Predict ke-1405. Reply :  sadness.
# Predict ke-1406. Reply :  other
# Predict ke-1407. Reply :  hope.
# Predict ke-1408. Reply :  other
# Predict ke-1409. Reply :  other
# Predict ke-1410. Reply :  other.
# Predict ke-1411. Reply :  other
# Predict ke-1412. Reply :  sadness.
# Predict ke-1413. Reply :  other
# Predict ke-1414. Reply :  sadness
# Predict ke-1415. Reply :  sadness.
# Predict ke-1416. Reply :  hope.
# Predict ke-1417. Reply :  joy
# Predict ke-1418. Reply :  other
# Predict ke-1419. Reply :  hope.
# Predict ke-1420. Reply :  sadness
# Predict ke-1421. Reply :  hope.
# Predict ke-1422. Reply :  other
# Predict ke-1423. Reply :  sadness
# Predict ke-1424. Reply :  sadness.
# Predict ke-1425. Reply :  other.
# Predict ke-1426. Reply :  other.
# ...
# Predict ke-16967. Reply :  other
# Predict ke-16968. Reply :  joy
# Predict ke-16969. Reply :  joy.
# Predict ke-16970. Reply :  joy.
# Predict ke-16971. Reply :  sadness
# Predict ke-16972. Reply :  joy
# Predict ke-16973. Reply :  joy.
# Predict ke-16974. Reply :  other.
# Predict ke-16975. Reply :  sadness
# Predict ke-16976. Reply :  love.
# Predict ke-16977. Reply :  love.
# Predict ke-16978. Reply :  joy.
# Predict ke-16979. Reply :  joy.
# Predict ke-16980. Reply :  joy.
# Predict ke-16981. Reply :  sadness.
# Predict ke-16982. Reply :  joy
# Predict ke-16983. Reply :  sadness
# Predict ke-16984. Reply :  other.
# Predict ke-16985. Reply :  sadness.
# Predict ke-16986. Reply :  other.
# Predict ke-16987. Reply :  love.
# Predict ke-16988. Reply :  sadness
# Predict ke-16989. Reply :  sadness.
# Predict ke-16990. Reply :  other.
# Predict ke-16991. Reply :  love.
# Predict ke-16992. Reply :  sadness
# Predict ke-16993. Reply :  other.
# Predict ke-16994. Reply :  sadness
# Predict ke-16995. Reply :  other.
# Predict ke-16996. Reply :  sadness.
# Predict ke-16997. Reply :  sadness
# Predict ke-16998. Reply :  hope.
# Predict ke-16999. Reply :  joy.
# Predict ke-17000. Reply :  other
# Predict ke-17001. Reply :  other.
# Predict ke-17002. Reply :  other.
# Predict ke-17003. Reply :  hope
# Predict ke-17004. Reply :  joy.
# Predict ke-17005. Reply :  sadness.
# Predict ke-17006. Reply :  joy.
# Predict ke-17007. Reply :  sadness
# Predict ke-17008. Reply :  other.
# Predict ke-17009. Reply :  joy
# Predict ke-17010. Reply :  hope
# Error: 400 - {"error":"Trying to keep the first 6429 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-17012. Reply :  love
# Predict ke-17013. Reply :  love.
# Predict ke-17014. Reply :  other
# Predict ke-17015. Reply :  sad
# Predict ke-17016. Reply :  other.
# Predict ke-17017. Reply :  hope
# Predict ke-17018. Reply :  love
# Predict ke-17019. Reply :  hope.
# Predict ke-17020. Reply :  sadness
# Predict ke-17021. Reply :  insomnia
# Predict ke-17022. Reply :  other.
# Predict ke-17023. Reply :  joy.
# Predict ke-17024. Reply :  other.
# Predict ke-17025. Reply :  love.
# Predict ke-17026. Reply :  hope.
# Predict ke-17027. Reply :  hope.
# Predict ke-17028. Reply :  hope.
# Predict ke-17029. Reply :  other.
# Predict ke-17030. Reply :  sadness.
# Predict ke-17031. Reply :  love.
# Predict ke-17032. Reply :  hope.
# Predict ke-17033. Reply :  other.
# Predict ke-17034. Reply :  hope.
# Predict ke-17035. Reply :  sadness
# Predict ke-17036. Reply :  other.
# Predict ke-17037. Reply :  joy.
# Predict ke-17038. Reply :  hope.
# Predict ke-17039. Reply :  sadness.
# Predict ke-17040. Reply :  other
# Predict ke-17041. Reply :  joy.
# Predict ke-17042. Reply :  other
# Predict ke-17043. Reply :  joy.
# Predict ke-17044. Reply :  other.
# Predict ke-17045. Reply :  joy.
# Predict ke-17046. Reply :  hope.
# Predict ke-17047. Reply :  love.
# Predict ke-17048. Reply :  sad
# Predict ke-17049. Reply :  joy.
# Predict ke-17050. Reply :  hope.
# Predict ke-17051. Reply :  sadness.
# Predict ke-17052. Reply :  other.
# Predict ke-17053. Reply :  sadness.
# Predict ke-17054. Reply :  hope
# Predict ke-17055. Reply :  sadness
# Predict ke-17056. Reply :  other
# Predict ke-17057. Reply :  other
# Predict ke-17058. Reply :  hope.
# Predict ke-17059. Reply :  hope.
# Predict ke-17060. Reply :  hope.
# Predict ke-17061. Reply :  hope
# Predict ke-17062. Reply :  other.
# Predict ke-17063. Reply :  hope.
# Predict ke-17064. Reply :  other
# Predict ke-17065. Reply :  joy.
# Predict ke-17066. Reply :  joy
# Predict ke-17067. Reply :  sadness.
# Predict ke-17068. Reply :  hope.
# Predict ke-17069. Reply :  other.
# Predict ke-17070. Reply :  joy.
# Error: 400 - {"error":"Trying to keep the first 6096 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-17072. Reply :  other
# Predict ke-17073. Reply :  sadness
# Predict ke-17074. Reply :  joy.
# Predict ke-17075. Reply :  love
# Predict ke-17076. Reply :  hope.
# Predict ke-17077. Reply :  joy.
# Predict ke-17078. Reply :  other.
# Predict ke-17079. Reply :  joy
# Predict ke-17080. Reply :  other
# Predict ke-17081. Reply :  sadness.
# Predict ke-17082. Reply :  other
# Predict ke-17083. Reply :  other
# Predict ke-17084. Reply :  sadness.
# Predict ke-17085. Reply :  other.
# Predict ke-17086. Reply :  other
# Predict ke-17087. Reply :  sadness.
# Predict ke-17088. Reply :  sadness
# Predict ke-17089. Reply :  joy.
# Predict ke-17090. Reply :  sadness
# Predict ke-17091. Reply :  other.
# Predict ke-17092. Reply :  sadness.
# Predict ke-17093. Reply :  sadness.
# Predict ke-17094. Reply :  other
# Predict ke-17095. Reply :  hope.
# Predict ke-17096. Reply :  joy.
# Predict ke-17097. Reply :  joy.
# Predict ke-17098. Reply :  joy.
# Predict ke-17099. Reply :  joy.
# Predict ke-17100. Reply :  sadness
# Predict ke-17101. Reply :  hope
# Predict ke-17102. Reply :  love.
# Predict ke-17103. Reply :  sadness.
# Predict ke-17104. Reply :  sadness.
# Predict ke-17105. Reply :  sadness
# Predict ke-17106. Reply :  hope
# Predict ke-17107. Reply :  sadness
# Predict ke-17108. Reply :  hope.
# Predict ke-17109. Reply :  sadness
# Predict ke-17110. Reply :  joy
# Predict ke-17111. Reply :  sadness
# Predict ke-17112. Reply :  love
# Predict ke-17113. Reply :  hope.
# Predict ke-17114. Reply :  other
# Predict ke-17115. Reply :  other.
# Predict ke-17116. Reply :  other.
# Predict ke-17117. Reply :  sadness
# Predict ke-17118. Reply :  sadness.
# Predict ke-17119. Reply :  joy.
# Predict ke-17120. Reply :  sadness
# Predict ke-17121. Reply :  other.
# Predict ke-17122. Reply :  hope.
# Predict ke-17123. Reply :  love.
# Predict ke-17124. Reply :  sadness.
# Predict ke-17125. Reply :  other
# Predict ke-17126. Reply :  hope.
# Predict ke-17127. Reply :  other
# Predict ke-17128. Reply :  joy.
# Predict ke-17129. Reply :  other
# Predict ke-17130. Reply :  other.
# Predict ke-17131. Reply :  joy.
# Predict ke-17132. Reply :  other
# Predict ke-17133. Reply :  other.
# Predict ke-17134. Reply :  hope
# Predict ke-17135. Reply :  joy.
# Predict ke-17136. Reply :  joy.
# Predict ke-17137. Reply :  other
# Predict ke-17138. Reply :  sadness.
# Predict ke-17139. Reply :  other.
# Predict ke-17140. Reply :  hope
# Predict ke-17141. Reply :  joy
# Predict ke-17142. Reply :  other.
# Predict ke-17143. Reply :  hope.
# Predict ke-17144. Reply :  sad
# Predict ke-17145. Reply :  joy.
# Predict ke-17146. Reply :  sad
# Predict ke-17147. Reply :  hope
# Predict ke-17148. Reply :  other.
# Predict ke-17149. Reply :  love.
# Predict ke-17150. Reply :  sadness.
# Predict ke-17151. Reply :  other.
# Predict ke-17152. Reply :  hope.
# Predict ke-17153. Reply :  sadness
# Predict ke-17154. Reply :  other.
# Predict ke-17155. Reply :  sad
# Predict ke-17156. Reply :  love.
# Predict ke-17157. Reply :  other
# Predict ke-17158. Reply :  joy.
# Predict ke-17159. Reply :  other
# Predict ke-17160. Reply :  sadness.
# Predict ke-17161. Reply :  sadness
# Predict ke-17162. Reply :  love.
# Predict ke-17163. Reply :  other.
# Predict ke-17164. Reply :  joy.
# Predict ke-17165. Reply :  hope.
# Predict ke-17166. Reply :  sad
# Predict ke-17167. Reply :  sadness.
# Predict ke-17168. Reply :  hope
# Predict ke-17169. Reply :  other.
# Predict ke-17170. Reply :  joy.
# Predict ke-17171. Reply :  hope.
# Predict ke-17172. Reply :  joy.
# Predict ke-17173. Reply :  other
# Predict ke-17174. Reply :  sad
# Predict ke-17175. Reply :  sadness
# Predict ke-17176. Reply :  other.
# Predict ke-17177. Reply :  hope.
# Predict ke-17178. Reply :  love.
# Predict ke-17179. Reply :  other.
# Predict ke-17180. Reply :  other.
# Predict ke-17181. Reply :  love.
# Predict ke-17182. Reply :  sadness
# Predict ke-17183. Reply :  joy.
# Predict ke-17184. Reply :  other.
# Predict ke-17185. Reply :  sadness
# Predict ke-17186. Reply :  joy.
# Predict ke-17187. Reply :  joy
# Predict ke-17188. Reply :  sadness
# Predict ke-17189. Reply :  joy
# Predict ke-17190. Reply :  sad
# Predict ke-17191. Reply :  sadness.
# Predict ke-17192. Reply :  hope.
# Predict ke-17193. Reply :  sadness
# Predict ke-17194. Reply :  hope
# Predict ke-17195. Reply :  joy.
# Predict ke-17196. Reply :  other.
# Predict ke-17197. Reply :  joy.
# Predict ke-17198. Reply :  sad
# Predict ke-17199. Reply :  sadness.
# Predict ke-17200. Reply :  joy.
# Predict ke-17201. Reply :  sad
# Predict ke-17202. Reply :  other.
# Predict ke-17203. Reply :  other.
# Predict ke-17204. Reply :  sadness
# Predict ke-17205. Reply :  joy.
# Predict ke-17206. Reply :  love
# Predict ke-17207. Reply :  hope.
# Predict ke-17208. Reply :  sadness
# Predict ke-17209. Reply :  other.
# Error: 400 - {"error":"Trying to keep the first 5781 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-17211. Reply :  hope.
# Predict ke-17212. Reply :  other.
# Predict ke-17213. Reply :  hope.
# Predict ke-17214. Reply :  sadness.
# Predict ke-17215. Reply :  love.
# Predict ke-17216. Reply :  love
# Predict ke-17217. Reply :  sadness.
# Predict ke-17218. Reply :  hope
# Predict ke-17219. Reply :  joy.
# Predict ke-17220. Reply :  hope.
# Predict ke-17221. Reply :  hope
# Predict ke-17222. Reply :  joy
# Predict ke-17223. Reply :  hope.
# Predict ke-17224. Reply :  hope.
# Predict ke-17225. Reply :  sadness
# Predict ke-17226. Reply :  hope.
# Predict ke-17227. Reply :  joy.
# Predict ke-17228. Reply :  love.
# Predict ke-17229. Reply :  sadness.
# Predict ke-17230. Reply :  hope.
# Predict ke-17231. Reply :  hope.
# Predict ke-17232. Reply :  sadness
# Predict ke-17233. Reply :  love
# Predict ke-17234. Reply :  hope.
# Predict ke-17235. Reply :  other.
# Predict ke-17236. Reply :  other
# Predict ke-17237. Reply :  other
# Predict ke-17238. Reply :  hope.
# Predict ke-17239. Reply :  sadness.
# Predict ke-17240. Reply :  sad
# Predict ke-17241. Reply :  hope.
# Predict ke-17242. Reply :  other.
# Predict ke-17243. Reply :  hope.
# Predict ke-17244. Reply :  other
# Predict ke-17245. Reply :  sadness
# Predict ke-17246. Reply :  joy
# Predict ke-17247. Reply :  sadness
# Predict ke-17248. Reply :  hope.
# Predict ke-17249. Reply :  other
# Predict ke-17250. Reply :  other
# Predict ke-17251. Reply :  joy.
# Predict ke-17252. Reply :  joy.
# Predict ke-17253. Reply :  other
# Predict ke-17254. Reply :  love
# Predict ke-17255. Reply :  hope.
# Predict ke-17256. Reply :  hope.
# Predict ke-17257. Reply :  other.
# Predict ke-17258. Reply :  other.
# Predict ke-17259. Reply :  hope.
# Predict ke-17260. Reply :  sad
# Predict ke-17261. Reply :  joy.
# Predict ke-17262. Reply :  joy
# Predict ke-17263. Reply :  love.
# Predict ke-17264. Reply :  joy
# Predict ke-17265. Reply :  other.
# Predict ke-17266. Reply :  hope.
# Predict ke-17267. Reply :  sadness.
# Predict ke-17268. Reply :  hope
# Predict ke-17269. Reply :  joy.
# Predict ke-17270. Reply :  other
# Predict ke-17271. Reply :  other
# Predict ke-17272. Reply :  other.
# Predict ke-17273. Reply :  sad
# Predict ke-17274. Reply :  sad
# Predict ke-17275. Reply :  joy.
# Predict ke-17276. Reply :  joy.
# Predict ke-17277. Reply :  hope.
# Predict ke-17278. Reply :  joy.
# Predict ke-17279. Reply :  sadness
# Predict ke-17280. Reply :  joy.
# Predict ke-17281. Reply :  other.
# Predict ke-17282. Reply :  joy.
# Predict ke-17283. Reply :  joy
# Predict ke-17284. Reply :  hope.
# Predict ke-17285. Reply :  hope.
# Predict ke-17286. Reply :  sadness
# Predict ke-17287. Reply :  sadness.
# Predict ke-17288. Reply :  joy
# Predict ke-17289. Reply :  other.
# Predict ke-17290. Reply :  other.
# Predict ke-17291. Reply :  sadness
# Predict ke-17292. Reply :  other
# Predict ke-17293. Reply :  joy.
# Predict ke-17294. Reply :  other.
# Predict ke-17295. Reply :  sadness.
# Predict ke-17296. Reply :  sadness
# Predict ke-17297. Reply :  sadness
# Predict ke-17298. Reply :  hope.
# Predict ke-17299. Reply :  sadness
# Predict ke-17300. Reply :  joy.
# Predict ke-17301. Reply :  other.
# Predict ke-17302. Reply :  sadness.
# Predict ke-17303. Reply :  other
# Predict ke-17304. Reply :  other
# Predict ke-17305. Reply :  other.
# Predict ke-17306. Reply :  other.
# Predict ke-17307. Reply :  other
# Predict ke-17308. Reply :  joy
# Predict ke-17309. Reply :  joy.
# Predict ke-17310. Reply :  sad
# Predict ke-17311. Reply :  joy
# Predict ke-17312. Reply :  hope.
# Predict ke-17313. Reply :  joy.
# Predict ke-17314. Reply :  other
# Predict ke-17315. Reply :  other
# Predict ke-17316. Reply :  other.
# Predict ke-17317. Reply :  hope.
# Predict ke-17318. Reply :  other.
# Predict ke-17319. Reply :  other.
# Predict ke-17320. Reply :  sadness
# Predict ke-17321. Reply :  love.
# Predict ke-17322. Reply :  joy.
# Predict ke-17323. Reply :  other
# Predict ke-17324. Reply :  other
# Predict ke-17325. Reply :  other.
# Predict ke-17326. Reply :  sadness
# Predict ke-17327. Reply :  joy.
# Predict ke-17328. Reply :  sadness.
# Predict ke-17329. Reply :  other.
# Predict ke-17330. Reply :  love
# Predict ke-17331. Reply :  love.
# Predict ke-17332. Reply :  hope.
# Predict ke-17333. Reply :  joy
# Predict ke-17334. Reply :  sadness
# Predict ke-17335. Reply :  hope.
# Predict ke-17336. Reply :  joy.
# Predict ke-17337. Reply :  other.
# Predict ke-17338. Reply :  love
# Predict ke-17339. Reply :  hope.
# Predict ke-17340. Reply :  joy.
# Predict ke-17341. Reply :  sadness
# Predict ke-17342. Reply :  love.
# Predict ke-17343. Reply :  love
# Error: 400 - {"error":"Trying to keep the first 6002 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-17345. Reply :  other.
# Predict ke-17346. Reply :  joy
# Predict ke-17347. Reply :  joy.
# Predict ke-17348. Reply :  sadness
# Predict ke-17349. Reply :  other.
# Predict ke-17350. Reply :  other.
# Predict ke-17351. Reply :  other
# Predict ke-17352. Reply :  sadness
# Predict ke-17353. Reply :  joy.
# Predict ke-17354. Reply :  sad
# Predict ke-17355. Reply :  sadness.
# Predict ke-17356. Reply :  sadness.
# Predict ke-17357. Reply :  sadness
# Predict ke-17358. Reply :  other
# Predict ke-17359. Reply :  other
# Predict ke-17360. Reply :  other.
# Predict ke-17361. Reply :  sadness
# Predict ke-17362. Reply :  hope.
# Predict ke-17363. Reply :  joy.
# Error: 400 - {"error":"Trying to keep the first 11751 tokens when context the overflows. However, the model is loaded with context length of only 4096 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input"}
# Predict ke-17365. Reply :  hope
# Predict ke-17366. Reply :  sadness
# Predict ke-17367. Reply :  hope.
# Predict ke-17368. Reply :  sadness
# Predict ke-17369. Reply :  other
# Predict ke-17370. Reply :  joy.
# Predict ke-17371. Reply :  sadness.
# Predict ke-17372. Reply :  other
# Predict ke-17373. Reply :  other
# Predict ke-17374. Reply :  other
# Predict ke-17375. Reply :  joy.
# Predict ke-17376. Reply :  other.
# Predict ke-17377. Reply :  sadness.
# Predict ke-17378. Reply :  sadness
# Predict ke-17379. Reply :  other.
# Predict ke-17380. Reply :  love.
# Predict ke-17381. Reply :  joy.
# Predict ke-17382. Reply :  other.
# Predict ke-17383. Reply :  sadness
# Predict ke-17384. Reply :  sadness
# Predict ke-17385. Reply :  sadness
# Predict ke-17386. Reply :  joy.
# Predict ke-17387. Reply :  other.
# Predict ke-17388. Reply :  love
# Predict ke-17389. Reply :  joy.
# Predict ke-17390. Reply :  other.
# Predict ke-17391. Reply :  hope.
# Predict ke-17392. Reply :  sadness
# Predict ke-17393. Reply :  other.
# Predict ke-17394. Reply :  love.
# Predict ke-17395. Reply :  joy.
# Predict ke-17396. Reply :  other.
# Predict ke-17397. Reply :  other.
# Predict ke-17398. Reply :  other.
# Predict ke-17399. Reply :  hope
# Predict ke-17400. Reply :  other
# Predict ke-17401. Reply :  love.
# Predict ke-17402. Reply :  other
# Predict ke-17403. Reply :  other.
# Predict ke-17404. Reply :  sadness
# Predict ke-17405. Reply :  joy
# Predict ke-17406. Reply :  sadness
# Predict ke-17407. Reply :  hope.
# Predict ke-17408. Reply :  sadness
# Predict ke-17409. Reply :  other.
# Predict ke-17410. Reply :  sadness
# Predict ke-17411. Reply :  sad
# Merging

# %%
tes = ' uio'
tes.replace('.','').replace(' ','')
# Out:
# 'uio'

# %%
import pandas as pd
zz = pd.read_csv('./dataset/labelled_poem_deepseek2.csv')
zz['label'].str.replace('.', '').replace(' ', '').value_counts() #.to_csv('./dataset/tes.csv', index=False)
# Out:
# label
# other               5634
# joy                 3695
# sadness             3512
# hope                2591
# love                1229
# sad                  546
# none                 157
# sorrow                12
# melancholy             3
# anger                  3
# valley                 2
# proud                  2
# cat                    1
# scunge                 1
# sorrowful              1
# jazz                   1
# rose                   1
# cruelty                1
# dancing girl           1
# desolate               1
# democracy              1
# land                   1
# war                    1
# loneliness             1
# innocence              1
# joyful                 1
# rhymerustler           1
# joyless                1
# despair                1
# river                  1
# horror                 1
# wave                   1
# patriotism             1
# rage                   1
# prophet                1
# pioneer                1
# blues and greens       1
# insomnia               1
# Name: count, dtype: int64

# %%
zz = pd.read_csv('./dataset/tes.csv')
zz.value_counts()
# Out:
# label
# melancholy    4860
# hope          1828
# joy           1031
# sad            988
# mourn          719
#               ...
# dank             1
# death            1
# deceit           1
# languid          1
# marvelous        1
# Name: count, Length: 656, dtype: int64
